# %% [markdown]
# import pymongo
# client = pymongo.MongoClient()
# mydb = client['y2buy_1']
# try:
#     mydb.amazon_product_metadata.drop()
# finally:
#     my_amazon_product_metadata = mydb['amazon_product_metadata']
# result = mydb.amazon_product_metadata.create_index([('asin', pymongo.ASCENDING)],unique=True)

# %%
import json 
import gzip 
def parse(path): 
    g = gzip.open(path, 'r') 
    for l in g: 
        yield eval(l)

# %% [markdown]
# #f = open("output.strict", 'w')
# for l in parse("../../download/meta_Cell_Phones_and_Accessories.json.gz"):
#     #print(l + '\n')
#     my_amazon_product_metadata.insert_one(l)

# %%
import pymongo
client = pymongo.MongoClient()
mydb = client['y2buy_1']
try:
    mydb.amazon_product_reviews.drop()
finally:
    my_amazon_product_reviews = mydb['amazon_product_reviews']
    result = my_amazon_product_reviews.create_index([('asin', pymongo.ASCENDING)],unique=False)
    my_amazon_product_reviews.create_index([
    ("asin", pymongo.ASCENDING),
    ("reviewerID", pymongo.ASCENDING),
    ("reviewTime", pymongo.ASCENDING)   
])

# %%
#f = open("output.strict", 'w') 
for l in parse("../../download/reviews_Cell_Phones_and_Accessories_5.json.gz"): 
    #print(l + '\n')
    #TODO: retrieve category from product_mata_data
    product_metadata_cursor = mydb.amazon_product_metadata.find({"asin": l["asin"]})
    first_matching_product_metadata = product_metadata_cursor[0]
    l["categories"] = first_matching_product_metadata["categories"]
    my_amazon_product_reviews.insert_one(l)
# Out:
# {'reviewerID': 'A30TL5EWN6DFXT', 'asin': '120401325X', 'reviewerName': 'christina', 'helpful': [0, 0], 'reviewText': "They look good and stick good! I just don't like the rounded shape because I was always bumping it and Siri kept popping up and it was irritating. I just won't buy a product like this again", 'overall': 4.0, 'summary': 'Looks Good', 'unixReviewTime': 1400630400, 'reviewTime': '05 21, 2014', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'ASY55RVNIL0UD', 'asin': '120401325X', 'reviewerName': 'emily l.', 'helpful': [0, 0], 'reviewText': 'These stickers work like the review says they do. They stick on great and they stay on the phone. They are super stylish and I can share them with my sister. :)', 'overall': 5.0, 'summary': 'Really great product.', 'unixReviewTime': 1389657600, 'reviewTime': '01 14, 2014', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A2TMXE2AFO7ONB', 'asin': '120401325X', 'reviewerName': 'Erica', 'helpful': [0, 0], 'reviewText': 'These are awesome and make my phone look so stylish! I have only used one so far and have had it on for almost a year! CAN YOU BELIEVE THAT! ONE YEAR!! Great quality!', 'overall': 5.0, 'summary': 'LOVE LOVE LOVE', 'unixReviewTime': 1403740800, 'reviewTime': '06 26, 2014', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'AWJ0WZQYMYFQ4', 'asin': '120401325X', 'reviewerName': 'JM', 'helpful': [4, 4], 'reviewText': "Item arrived in great time and was in perfect condition. However, I ordered these buttons because they were a great deal and included a FREE screen protector. I never received one. Though its not a big deal, it would've been nice to get it since they claim it comes with one.", 'overall': 4.0, 'summary': 'Cute!', 'unixReviewTime': 1382313600, 'reviewTime': '10 21, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'ATX7CZYFXI1KW', 'asin': '120401325X', 'reviewerName': 'patrice m rogoza', 'helpful': [2, 3], 'reviewText': 'awesome! stays on, and looks great. can be used on multiple apple products.  especially having nails, it helps to have an elevated key.', 'overall': 5.0, 'summary': 'leopard home button sticker for iphone 4s', 'unixReviewTime': 1359849600, 'reviewTime': '02 3, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'APX47D16JOP7H', 'asin': '120401325X', 'reviewerName': 'RLH', 'helpful': [1, 2], 'reviewText': 'These make using the home button easy. My daughter and I both like them.  I would purchase them again. Well worth the price.', 'overall': 3.0, 'summary': 'Cute', 'unixReviewTime': 1381536000, 'reviewTime': '10 12, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A1JVVYYO7G56DS', 'asin': '120401325X', 'reviewerName': 'Tyler Evans', 'helpful': [0, 0], 'reviewText': "Came just as described.. It doesn't come unstuck and its cute! People ask where I got them from & it's great when driving.", 'overall': 5.0, 'summary': 'best thing ever..', 'unixReviewTime': 1377129600, 'reviewTime': '08 22, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A6FGO4TBZ3QFZ', 'asin': '3998899561', 'reviewerName': 'Abdullah Albyati', 'helpful': [1, 2], 'reviewText': 'it worked for the first week then it only charge my phone to 20%. it is a waste of money.', 'overall': 1.0, 'summary': 'not a good Idea', 'unixReviewTime': 1384992000, 'reviewTime': '11 21, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Batteries', 'Battery Charger Cases'], ['Cell Phones & Accessories', 'Accessories', 'Batteries', 'External Battery Packs'], ['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A2JWEDW5FSVB0F', 'asin': '3998899561', 'reviewerName': 'Adam', 'helpful': [2, 3], 'reviewText': "Good case, solid build. Protects phone all around with good access to buttons. Battery charges with full battery lasts me a full day. I usually leave my house around 7am and return at 10pm. I'm glad that it lasts from start to end. 5/5", 'overall': 5.0, 'summary': 'Solid Case', 'unixReviewTime': 1380067200, 'reviewTime': '09 25, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Batteries', 'Battery Charger Cases'], ['Cell Phones & Accessories', 'Accessories', 'Batteries', 'External Battery Packs'], ['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A8AJS1DW7L3JJ', 'asin': '3998899561', 'reviewerName': 'Agata Majchrzak', 'helpful': [1, 1], 'reviewText': 'This is a fantastic case. Very stylish and protects my phone. Easy access to all buttons and features, without any loss of phone reception. But most importantly, it double power, just as promised. Great buy', 'overall': 5.0, 'summary': 'Perfect Case', 'unixReviewTime': 1396483200, 'reviewTime': '04 3, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Batteries', 'Battery Charger Cases'], ['Cell Phones & Accessories', 'Accessories', 'Batteries', 'External Battery Packs'], ['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A2YO4SCWAWNYBI', 'asin': '3998899561', 'reviewerName': 'Alex Maslakov', 'helpful': [0, 0], 'reviewText': "this case fits perfectly on the s4 and keeps me powerd all day I can't complain! a+ recommend it to all", 'overall': 5.0, 'summary': 'Just what I needed', 'unixReviewTime': 1397347200, 'reviewTime': '04 13, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Batteries', 'Battery Charger Cases'], ['Cell Phones & Accessories', 'Accessories', 'Batteries', 'External Battery Packs'], ['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A3AFELPYTZH90T', 'asin': '3998899561', 'reviewerName': 'Baja Alan', 'helpful': [2, 3], 'reviewText': "This is the first battery case I have had for my Galaxy S4. The S4 fits very well, is slim and doesn't add much weight to the Galaxy S4. It doubles the battery life. You can charge either the battery, the phone or both. There is a handy on-off switch with leds to indicate the level of charge.The battery case came on time and was packaged well. Well worth the price.", 'overall': 5.0, 'summary': 'A Winner', 'unixReviewTime': 1384905600, 'reviewTime': '11 20, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Batteries', 'Battery Charger Cases'], ['Cell Phones & Accessories', 'Accessories', 'Batteries', 'External Battery Packs'], ['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A6Q0P54QSP11J', 'asin': '3998899561', 'reviewerName': 'Olivia \x1aysiak', 'helpful': [3, 3], 'reviewText': "Performs exactly as advertised . It's very  sturdily built,and provides lots of boost . It does exactly what it's supposed too .Easy to insert phone in and out . Definitely a 5 star experience. Don't know what I would do without this case LOVE LOVE LOVE it.", 'overall': 5.0, 'summary': 'Absolutely love the case !!', 'unixReviewTime': 1386201600, 'reviewTime': '12 5, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Batteries', 'Battery Charger Cases'], ['Cell Phones & Accessories', 'Accessories', 'Batteries', 'External Battery Packs'], ['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'ANMATY0L0HX6Y', 'asin': '3998899561', 'reviewerName': 'Sasha Malkin', 'helpful': [12, 16], 'reviewText': "Unlike Most of the Rechargeable Battery cases, PowerBear Lasts up to 2 whole days. It doesn't heat up like most of the other ones, and I was completely fascinated by the ultra light and sleek design for the case. Before I was using the Mophie case but I couldn't wear it often because it was like having a hot brick in your pocket, Hence I had to always leave it at home.On the contrary, with PowerBear, I never take it off because I can't even tell the difference. Also it is build in a super STRONG manner and even though I dropped my phone a few times, its shock resistant technology won't let a single thing happen to the case or the phone. The PowerBear case became an extension to my phone that I never have to take off because when I charge it at night, it charges both my phone and the case, and I have battery life for more than two days. I was also shocked to hear all the positive compliments I was hearing from people at my job, fitness center, and throughout the community. Everybody was loving the case, and what they don't know is that it cost  me 60 % CHEAPER then all the other brand. This is the best purchase I've made on the internet, and I am going to buy more for my family in time for the Holidays. THANK YOU POWERBEAR!!!!!!!!!!!!!!", 'overall': 5.0, 'summary': 'Best Rechargeable Battery Case on the Market!!!!!!!!!! A++++++++', 'unixReviewTime': 1380240000, 'reviewTime': '09 27, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Batteries', 'Battery Charger Cases'], ['Cell Phones & Accessories', 'Accessories', 'Batteries', 'External Battery Packs'], ['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A1XBPVR8FE7TE1', 'asin': '3998899561', 'reviewerName': 'tim g', 'helpful': [1, 1], 'reviewText': "Just what I needed. I needed a phone case for myself and my two sons, but I also needed new replacement batteries. Now this isn't the case, since I got both in one. Awesome thanks A+", 'overall': 5.0, 'summary': 'Exactly what I needed', 'unixReviewTime': 1392940800, 'reviewTime': '02 21, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Batteries', 'Battery Charger Cases'], ['Cell Phones & Accessories', 'Accessories', 'Batteries', 'External Battery Packs'], ['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A35C4777EXZZQH', 'asin': '3998899561', 'reviewerName': 'Viktoriya', 'helpful': [0, 0], 'reviewText': 'When there is no outlets, or chargers near by its Powerbear to the rescue! Ordered one for my husband, and myself. Great purchase!!', 'overall': 5.0, 'summary': '5 star phone case', 'unixReviewTime': 1397779200, 'reviewTime': '04 18, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Batteries', 'Battery Charger Cases'], ['Cell Phones & Accessories', 'Accessories', 'Batteries', 'External Battery Packs'], ['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'ACU3LCRX4A8RV', 'asin': '3998899561', 'reviewerName': 'Zonaldo Reefey "Zonaldo Reefey"', 'helpful': [2, 3], 'reviewText': "It works great. Doesn't heat up like crazy like the other ones I got, and cheaper too! Its definetly the best power case for the S4 you can get, thats why I got one for me and my wife. I wonder why its called power bear..", 'overall': 5.0, 'summary': 'SUPER DUPER QUALITY!', 'unixReviewTime': 1377388800, 'reviewTime': '08 25, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Batteries', 'Battery Charger Cases'], ['Cell Phones & Accessories', 'Accessories', 'Batteries', 'External Battery Packs'], ['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A1ZTTNS6SWFV52', 'asin': '6073894996', 'reviewerName': 'Alexander Graham Bell Very-Junior', 'helpful': [0, 0], 'reviewText': 'Surprisingly, this inexpensive version works just as well and just as reliably as the expensive variety. It has been working for me for months now. No problem. Excellent value.', 'overall': 5.0, 'summary': 'Top Quality. Works like the Expensive Version', 'unixReviewTime': 1368230400, 'reviewTime': '05 11, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A38EHCCO532RYI', 'asin': '6073894996', 'reviewerName': 'amazonfan1', 'helpful': [2, 3], 'reviewText': 'I have tested this against the griffin dual output unit.I checked the charging current.This unit was charging my galaxy note battery with 70 ma.Griffin was charging with 40 ma! And the griffin was 4 times more expensive.I have not used these for very long. I bought 15 of them, because they are so cheap and because they actually do seem to provide high current.No idea how long they last. I assume they will work fine. I have not been using them much. I did the testing , just to stock up on a high current charger. This passed and I stocked up.', 'overall': 5.0, 'summary': 'High power as promised!', 'unixReviewTime': 1348012800, 'reviewTime': '09 19, 2012', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A2INSXDTE08WSJ', 'asin': '6073894996', 'reviewerName': 'Barbie', 'helpful': [0, 0], 'reviewText': 'It worked great for the first couple of weeks then it just stopped completely.. so basically a small waste of money.', 'overall': 1.0, 'summary': 'Horrible', 'unixReviewTime': 1369785600, 'reviewTime': '05 29, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A9NETBZNEW2TP', 'asin': '6073894996', 'reviewerName': 'Bernadette Mitchell "Lady Di"', 'helpful': [0, 0], 'reviewText': 'I love that it has two ports for my phone and ipod. Who wants to be putting too many things in one socket.  Sleek and convenient to store and I just love it.', 'overall': 5.0, 'summary': 'USB Port', 'unixReviewTime': 1402012800, 'reviewTime': '06 6, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A385HZRPXDDFCL', 'asin': '6073894996', 'reviewerName': 'Bob', 'helpful': [0, 0], 'reviewText': 'just what you need, I am always having to charge my phone and then find I have another item to charge also.', 'overall': 5.0, 'summary': 'Works great', 'unixReviewTime': 1385683200, 'reviewTime': '11 29, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'ALZQ9D8V53TI2', 'asin': '6073894996', 'reviewerName': 'Bruce/Emily', 'helpful': [0, 0], 'reviewText': 'does not have the need amps to charge things like ipads, or hp touchpads. but its super small and compact.', 'overall': 3.0, 'summary': 'it works', 'unixReviewTime': 1368835200, 'reviewTime': '05 18, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A3VWU7S29LR2XX', 'asin': '6073894996', 'reviewerName': 'Bryan S', 'helpful': [0, 0], 'reviewText': "They are nothing special for sure, but it's nice that you can tell when it is powered up by the led that glows in it.  able to charge two phones at once in the car which is nice.", 'overall': 4.0, 'summary': 'I like the fact they light up.', 'unixReviewTime': 1402185600, 'reviewTime': '06 8, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A3TOHPW7ES23NZ', 'asin': '6073894996', 'reviewerName': 'Cathy', 'helpful': [0, 0], 'reviewText': 'I have several chargers. Have more than one vehicle so I keep more than one of these in each. Nothing more frustrating than finding all of a sudden one quits working, and you have no way to recharge your phone. That is always when you need it most.  This one works well for any of my products.', 'overall': 4.0, 'summary': 'Works great', 'unixReviewTime': 1389398400, 'reviewTime': '01 11, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A1LGWLFF0YD0KV', 'asin': '6073894996', 'reviewerName': 'Daniel Fernandez', 'helpful': [0, 0], 'reviewText': 'I bought this a little skeptical. After I tried it I bought two more. It works great and so far it has lasted for about 3 months. If that changes I will update this review.', 'overall': 5.0, 'summary': 'Works great', 'unixReviewTime': 1379721600, 'reviewTime': '09 21, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A2YODGM5RUZ7I1', 'asin': '6073894996', 'reviewerName': 'DCGeek1', 'helpful': [0, 0], 'reviewText': "I am disappointed that the 1A didn't work with my iPad.  That's what I get for buying a cheap adapter.", 'overall': 2.0, 'summary': "This doesn't work with my iPad.", 'unixReviewTime': 1403481600, 'reviewTime': '06 23, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A29OXVQRZ154KX', 'asin': '6073894996', 'reviewerName': 'Don Powell', 'helpful': [3, 4], 'reviewText': 'This is a nice charger but you can tell it was made cheaply in China.  When it is charging the phone, the car radio gets LOTS of static.  Not so much that I have to stop charging but like when you are near power lines and the radio station is far away.So, no RF shielding.I gave it 4 stars because it works fine for me, but if you listen to the radio, you might consider it is more like 2 or 3 stars.', 'overall': 4.0, 'summary': 'Solid Charger but RF noisy', 'unixReviewTime': 1363737600, 'reviewTime': '03 20, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A2U5NF3IH4YVKH', 'asin': '6073894996', 'reviewerName': 'ebony winslow', 'helpful': [0, 0], 'reviewText': 'After a week only one side works', 'overall': 2.0, 'summary': 'Two Stars', 'unixReviewTime': 1404345600, 'reviewTime': '07 3, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A34XJA5OE33FP1', 'asin': '6073894996', 'reviewerName': 'Hec', 'helpful': [0, 0], 'reviewText': 'Yo get exactly what you order in a timely fashion. And the item is just as described. Great buy if you ask me', 'overall': 4.0, 'summary': 'Ok', 'unixReviewTime': 1360195200, 'reviewTime': '02 7, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A2DZO8MWVM4WKD', 'asin': '6073894996', 'reviewerName': 'Hekkenschtze "Hekkenschutze"', 'helpful': [0, 0], 'reviewText': "This is a terribly awesome product in my Subaru's console.  Passengers love it, I love it because it emits a blue glow, because it has held up to abuse over the years and performs like new.", 'overall': 5.0, 'summary': 'USB slots in a blue light that never quits', 'unixReviewTime': 1384041600, 'reviewTime': '11 10, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A3VCIEAN3NYO12', 'asin': '6073894996', 'reviewerName': 'Jason M. Faulkner "JMF"', 'helpful': [2, 3], 'reviewText': "I've bough a munch of different things like this over the years. Most wouldn't stay in the jack, or would give out after a few days. This one is GREAT!", 'overall': 5.0, 'summary': 'good', 'unixReviewTime': 1365292800, 'reviewTime': '04 7, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'ASRM2FSLDPXVX', 'asin': '6073894996', 'reviewerName': 'jose', 'helpful': [0, 0], 'reviewText': "Only works one side at a time. When you connect two cables, one side stop working and also overheated burning the fuses. I purchased two of them and it's the same problem. Cheap and bad quality.", 'overall': 1.0, 'summary': "don't waste your money, pay more and buy one at Walgreen s.", 'unixReviewTime': 1398729600, 'reviewTime': '04 29, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A31XHOCG62WJH4', 'asin': '6073894996', 'reviewerName': 'Jose v "Jose velez"', 'helpful': [0, 0], 'reviewText': 'it works great i like i can charge two thing at the same now i dont have to wait for my to finish charging her phone', 'overall': 5.0, 'summary': 'charger', 'unixReviewTime': 1381795200, 'reviewTime': '10 15, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A2I7NEVKSJ5UWR', 'asin': '6073894996', 'reviewerName': 'Jude Chukwuma Benyeogor "jcb"', 'helpful': [0, 0], 'reviewText': 'It came at last, good looking and the price was good and i believe it is worth the time I waited for it to come to me good job', 'overall': 4.0, 'summary': 'good job', 'unixReviewTime': 1395878400, 'reviewTime': '03 27, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A30A04FS5YAES3', 'asin': '6073894996', 'reviewerName': 'Levi Bowen', 'helpful': [0, 0], 'reviewText': "Didn't last very long. Worked great when it worked but it is a cheap piece of plastic crap so I shouldn't have expected it to last.", 'overall': 2.0, 'summary': 'Works for a while.', 'unixReviewTime': 1377216000, 'reviewTime': '08 23, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A2Y937AV46ULWQ', 'asin': '6073894996', 'reviewerName': 'Mayra', 'helpful': [0, 0], 'reviewText': 'excellent product, works great , have easy handling, and good quality as it is announced. reached as is shown time and in very good condition thank you very much for everything', 'overall': 4.0, 'summary': 'good', 'unixReviewTime': 1397347200, 'reviewTime': '04 13, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A2KP65JS3YY5VL', 'asin': '6073894996', 'reviewerName': 'Michael A. Rowley "Nick Danger"', 'helpful': [0, 0], 'reviewText': 'Purchased two and we put one in each car. Now we charge our ipad and iohone together. Can also use to power my Galaxy Note 2 or recharge other USB devices. If you have to think about it you need counseling', 'overall': 5.0, 'summary': 'Works great. Very inexpensive', 'unixReviewTime': 1358035200, 'reviewTime': '01 13, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A2L6BH090TX9O7', 'asin': '6073894996', 'reviewerName': 'M. Johns', 'helpful': [0, 0], 'reviewText': "great charger for 2 devices and i haven't had any problems so far 3yrs now", 'overall': 5.0, 'summary': 'Five Stars', 'unixReviewTime': 1375401600, 'reviewTime': '08 2, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'ABDDX2PV61RMX', 'asin': '6073894996', 'reviewerName': 'MS.J', 'helpful': [0, 0], 'reviewText': 'Purchased product about many a month ago. Pros: Loved it work just fine!! Cool Blue light feature when you plug it into the lighter!! Can plug in two things at one time....Con: Top clear piece came off easily overtime (I just put clear tape around the top) TOTAL: PROS:95% CONS:5%', 'overall': 4.0, 'summary': 'Dual USB Port Car Charger', 'unixReviewTime': 1354147200, 'reviewTime': '11 29, 2012', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A9VL5ER8D0K2Z', 'asin': '6073894996', 'reviewerName': 'Owner', 'helpful': [0, 0], 'reviewText': 'I bought this so that I could use and charge my Tab at the same time. My tab does not recognize the high power port and will either charge while off or use power while on, it will not charge while powered on.', 'overall': 2.0, 'summary': 'not high power', 'unixReviewTime': 1336176000, 'reviewTime': '05 5, 2012', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A2NTV6MHFXP4M', 'asin': '6073894996', 'reviewerName': 'Patricia Hagan', 'helpful': [0, 0], 'reviewText': "I bought this to charge my iphone and tablet in the car. works for iphone but not the tablet. I needed a stronger charge for that but this is still great for both iphoe and ipod together. it's cheap, small and compact", 'overall': 5.0, 'summary': 'works', 'unixReviewTime': 1360281600, 'reviewTime': '02 8, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A10W7D1W5M4CHE', 'asin': '6073894996', 'reviewerName': 'Paul Rowland', 'helpful': [0, 0], 'reviewText': 'Works great. The blue led light is a nice touch in the car. We charge a Samsung and Iphone using this outlet. Nice low profile too.', 'overall': 5.0, 'summary': 'USB Outlet', 'unixReviewTime': 1359676800, 'reviewTime': '02 1, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A2B8HBZPIFYRV1', 'asin': '6073894996', 'reviewerName': 'pissed off', 'helpful': [0, 0], 'reviewText': 'works great and charges ipads, tablets, smartphones as well as bluetooth speakers and headsets. I would recommend it to anyone looking for a universal car charger.', 'overall': 4.0, 'summary': 'Good little charger', 'unixReviewTime': 1390694400, 'reviewTime': '01 26, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A5A4374R8I7NB', 'asin': '6073894996', 'reviewerName': 'PWB Esq', 'helpful': [1, 1], 'reviewText': "I could only give this USB car charger 2 stars because although it worked fine for about 3 months, it subsequently died on me.Pros:-Has 2 USB ports for charging, one (the top) is 2.1 amps.  The bottom slot is lower, presumably 1 or 1.5 amps.-Fits well in my charging socket - holds tight.  I've had some that were loose in my charging socket.-Works well to charge my iPhone in the top slot and the bottom slot works with most Android phones, except the very high end ones.-Has a blue LED light to tell you it is on and ready to charge.-The USB sockets seem to be well made and tightly fit all my cables.-Pretty solid construction.-It cost less than $2.Cons:-It died on me after 3 months.I had really enjoyed using this USB charger.  It rapidly charged my iPhone and worked well with charging the phones of my family and friends.  The two slot design makes this design very handy; with a 1 slot design, no one else can charge their device unless I remove my cord.  Of course, after this charger died, I had to go back to the 1 slot design I was using before.After 3 months, I began to notice the LED light flickering.  It was less than a week later that is quit working permanently.  I'm not sure what the problem was - faulty wiring, bad design, I guess I'll never know.  I thought about getting another since they are so cheap, but then I thought better of it.  Maybe they are so cheap because they are simply disposable after a short period of time.For whatever reason, it died and I was forced to look for another 2 slot design - I haven't found one in my price range yet.", 'overall': 2.0, 'summary': 'Works Fine, But It Died On ME', 'unixReviewTime': 1340582400, 'reviewTime': '06 25, 2012', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A1OWZHEQ5UCSAN', 'asin': '6073894996', 'reviewerName': 'R. Baker', 'helpful': [0, 0], 'reviewText': 'This charger works great and is short, unlike most chargers. It does a great job with charging both my phone and my GPS when I am in the car.  Great value and easy on the wallet.', 'overall': 5.0, 'summary': 'Great Dual Charger', 'unixReviewTime': 1360195200, 'reviewTime': '02 7, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A25TQLMIAPI1T6', 'asin': '6073894996', 'reviewerName': 'Ronaldo', 'helpful': [0, 0], 'reviewText': 'I bought 2 of this and tried to test first ... after few minutes of charging, it felt hot. Pulled it out and the product smelled burnt. Tried the other one too and same thing. Be careful... this one could be fire hazard or could potentially destroy the electrical system', 'overall': 1.0, 'summary': 'Be careful', 'unixReviewTime': 1403395200, 'reviewTime': '06 22, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A382RYVVZOJ8PX', 'asin': '6073894996', 'reviewerName': 'ruthptb "Ruth Root"', 'helpful': [0, 1], 'reviewText': 'This portable USB Port car charger is a must have for people on the go.  Pair this with an extra or spare cord and you are good to go!', 'overall': 5.0, 'summary': 'A must have for people on the go', 'unixReviewTime': 1365120000, 'reviewTime': '04 5, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A3GTTANAYUVSDY', 'asin': '6073894996', 'reviewerName': 'Ryan', 'helpful': [0, 0], 'reviewText': 'I love the way it can charge 2 devices at once!  Seems to charge quicker without GPS on, with it on, it only holds the battery, but better than it dying!!!', 'overall': 4.0, 'summary': 'Works best without location/GPS on device', 'unixReviewTime': 1400803200, 'reviewTime': '05 23, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A16EFGT2PLZT34', 'asin': '6073894996', 'reviewerName': 'S. Coward "MrsCoward"', 'helpful': [0, 0], 'reviewText': 'Bought so we could charge to phones at the same time while in the car from the same port.  Works.', 'overall': 4.0, 'summary': 'Works', 'unixReviewTime': 1378252800, 'reviewTime': '09 4, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A2Q7SZISE1RXQQ', 'asin': '6073894996', 'reviewerName': 'Tore', 'helpful': [0, 0], 'reviewText': 'I received this product before I expected. It looks pretty good and It works with my Iphone (3GS) and my phone (HTC Evo V 3D). It is a good deal because It is not easy to find something like this for this price', 'overall': 4.0, 'summary': 'Pretty good', 'unixReviewTime': 1350518400, 'reviewTime': '10 18, 2012', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A8VI7KMUHI7ZH', 'asin': '6073894996', 'reviewerName': 'Voiceover Guy', 'helpful': [0, 0], 'reviewText': "I have several of these, from various retailers, all the same, each made in some anonymous Chinese factory, all exactly alike.They're great. They really do work, and they do deliver 2.1 and 1.0 power as they say they will do. They do the job.You wouldn't expect much QC for a $2 electrical product, but they each work just fine.They don't last forever-- about a year or two of active daily use seems about par, then they suddenly die. So do have some replacements on hand. At this price, no problem.Yes, they work with both my iPhone and iPad. Also with every other USB device I've needed to charge.The LED light that indicates you are plugged in correctly is very helpful.These are great for rental cars and travel. If you leave one behind, hey, it's only $2.I'm totally pleased with these clever little gems. No complaints. I wouldn't be without a couple, especially for travel.Hope this is helpful. Happy trails, all.", 'overall': 5.0, 'summary': 'Great DC Charger, Works Great, $2 Value', 'unixReviewTime': 1402790400, 'reviewTime': '06 15, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A3HWOEJ6BK7B7M', 'asin': '6073894996', 'reviewerName': 'Wei', 'helpful': [0, 0], 'reviewText': 'good product at low price.purchased this looking for a smaller charger and I love Griffin products.Free shipping just took a little longer', 'overall': 5.0, 'summary': 'good product at low price', 'unixReviewTime': 1399420800, 'reviewTime': '05 7, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A347LTN4RU2FL1', 'asin': '6073894996', 'reviewerName': 'Yeoman Johnson', 'helpful': [0, 0], 'reviewText': 'I use this in my car to charge my phone and my iPod as needed. It works well, but the bright blue light can be annoying when driving at night. Overall, a very good deal.', 'overall': 4.0, 'summary': 'Works as advertised', 'unixReviewTime': 1359417600, 'reviewTime': '01 29, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Car Chargers']]}
# {'reviewerID': 'A2G38P52ZF5TTH', 'asin': '7532385086', 'reviewerName': 'Allana', 'helpful': [3, 3], 'reviewText': "I love this case! It's so pretty.And I love the way the case feels to the touch because of the rubber. Very happy!", 'overall': 5.0, 'summary': 'I recommend', 'unixReviewTime': 1296604800, 'reviewTime': '02 2, 2011', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A3Q6C95EFP4FEX', 'asin': '7532385086', 'reviewerName': 'Brittany', 'helpful': [0, 0], 'reviewText': 'The idea of the design is a sweet idea but it wears off as the paint is over the case and not under a sealant or anything. It has a cool 3D effect but at the cost of the paint rubbing off.It is quite pretty though.', 'overall': 3.0, 'summary': 'Nice', 'unixReviewTime': 1328140800, 'reviewTime': '02 2, 2012', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A2GHDKZBYXGAPY', 'asin': '7532385086', 'reviewerName': 'C. Groves "~The Connie"', 'helpful': [0, 0], 'reviewText': 'I was worried about this order because the picture on the description page kept changing to a less-desireable green/orange cover.  But alas, it came a day earlier than expected, and the beautiful pink product expected!  The "rubberized" cover feels a little greasy (like it was armor-all\'d), but the design is gorgeous and a little 3D looking!', 'overall': 5.0, 'summary': 'Perfect!', 'unixReviewTime': 1342569600, 'reviewTime': '07 18, 2012', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A2Y33PMFKII0VR', 'asin': '7532385086', 'reviewerName': 'Grandma in NH', 'helpful': [0, 0], 'reviewText': 'Another pretty phone case that I really love. I have many as I love t o change them around .thanks', 'overall': 5.0, 'summary': 'Pretty', 'unixReviewTime': 1360886400, 'reviewTime': '02 15, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A3S8BPAUQQLDKU', 'asin': '7532385086', 'reviewerName': 'Krystal', 'helpful': [0, 0], 'reviewText': "The case is not white, its more of a silver. It's still a very pretty case- it fit my phone perfectly. It took too long to arrive.", 'overall': 4.0, 'summary': 'Not what I expected.', 'unixReviewTime': 1354924800, 'reviewTime': '12 8, 2012', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'AKUQOY3DJX96J', 'asin': '7532385086', 'reviewerName': 'Lisa Hall', 'helpful': [0, 0], 'reviewText': "Defintiely worth the price...You should order several.  Most cases are $15 and up especially at the cell phone stores.  I can't believe the mark up on these things!", 'overall': 4.0, 'summary': 'Worth the price', 'unixReviewTime': 1356652800, 'reviewTime': '12 28, 2012', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'AARIXIQYNH38W', 'asin': '7532385086', 'reviewerName': 'Pen', 'helpful': [0, 0], 'reviewText': 'This is a great case... It fit my phone perfectly and I still use it from time to time. Would recommend', 'overall': 5.0, 'summary': 'Great', 'unixReviewTime': 1369958400, 'reviewTime': '05 31, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A11FEJGJ2YK25Z', 'asin': '7532385086', 'reviewerName': 'Sunshine girl', 'helpful': [0, 0], 'reviewText': 'Received this item very quickly. The design is even more vivid than expected. The cover is soft (rubberized) but durable. I have received many compliments. It was an excellent buy! I would recommend this to anyone wanting a "good look" for their phone.', 'overall': 5.0, 'summary': 'better than expected!', 'unixReviewTime': 1339718400, 'reviewTime': '06 15, 2012', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A2NSS0L3NIU6CN', 'asin': '7532385086', 'reviewerName': 'voidedlime', 'helpful': [0, 0], 'reviewText': 'this cover makes an old phone look and feel new. I like that I can order covers for little money and snazzy up my phone.', 'overall': 4.0, 'summary': 'htc evo cover', 'unixReviewTime': 1347148800, 'reviewTime': '09 9, 2012', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A1PMGOX24BWDAZ', 'asin': '7887421268', 'reviewerName': '0902virgo', 'helpful': [0, 0], 'reviewText': 'I loved the case when I first received it but shortly after, the case started to peel off at first i did not know what it was until i looked on the back of the case and it was missing spots. Guess sometimes a good deal is not really a good deal.would not purchase.', 'overall': 2.0, 'summary': 'Loved it at first', 'unixReviewTime': 1344211200, 'reviewTime': '08 6, 2012', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A115GM0PI28KP5', 'asin': '7887421268', 'reviewerName': 'California Love', 'helpful': [0, 0], 'reviewText': 'The color is more dark in person, and this isnt the best protection case. I get a lot of compliments on the case, and it was easy to put on.', 'overall': 4.0, 'summary': 'Cute', 'unixReviewTime': 1362614400, 'reviewTime': '03 7, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A2AOF16F78BQK6', 'asin': '7887421268', 'reviewerName': 'C. Paul Douglas', 'helpful': [0, 0], 'reviewText': 'Simple to install and a great way to help protect your phone.My wife really liked the ability to change the look of her phone.', 'overall': 5.0, 'summary': 'Simple and Attractive Protector', 'unixReviewTime': 1376352000, 'reviewTime': '08 13, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A2LFBAQ1CPDWNY', 'asin': '7887421268', 'reviewerName': 'Davonne', 'helpful': [0, 0], 'reviewText': 'The case is pretty good. It dose have some scratches on one side of the phone but its every little. Other then that i like it. Ive dropped my phone a few times since putting on the case and it didnt break or scratch. Ive gotten many complements on this case and over all it was worth the few bucks I spent.', 'overall': 4.0, 'summary': 'Good Case', 'unixReviewTime': 1337644800, 'reviewTime': '05 22, 2012', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A22PJG27JHKWPA', 'asin': '7887421268', 'reviewerName': 'ddmmt9', 'helpful': [0, 0], 'reviewText': 'This case is afordable and yes it peels very easy but thats to be expected because its a dollor. I bought mine from Electromaster. It snaps on fine for me but if I were to drop my phone the phone would be fine but the case would surely be done for. its only a dollar so do not get your hopes up. it looks great but its for show not for protection. if you want your phone to be protected go the extra mile for an outter box', 'overall': 4.0, 'summary': 'This case is exactly as described', 'unixReviewTime': 1350950400, 'reviewTime': '10 23, 2012', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A2Y33PMFKII0VR', 'asin': '7887421268', 'reviewerName': 'Grandma in NH', 'helpful': [0, 0], 'reviewText': 'This is one of my favorite cases I have this one on my phone I really love the color a lot.', 'overall': 5.0, 'summary': 'Love it!', 'unixReviewTime': 1360886400, 'reviewTime': '02 15, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A3J38WFKNT2MFX', 'asin': '7887421268', 'reviewerName': 'Kelly-Ann Johnson', 'helpful': [0, 0], 'reviewText': 'It looked like it was used! It was broken when it got to be the paint job was horrible.I would never get it again', 'overall': 2.0, 'summary': "Don't waste your money!", 'unixReviewTime': 1373587200, 'reviewTime': '07 12, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A17E8FKH09XAY2', 'asin': '7887421268', 'reviewerName': 'kkkeown', 'helpful': [0, 0], 'reviewText': "This case for some reason is peeling, there isn't much left of the orginal skin, i  loved the case with pink being my favorite color but i wouldn't recommend this specific one for anyone.", 'overall': 1.0, 'summary': 'bad experience', 'unixReviewTime': 1341792000, 'reviewTime': '07 9, 2012', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A1C71EMHZRUWNT', 'asin': '7887421268', 'reviewerName': 'melisa lovewell', 'helpful': [0, 0], 'reviewText': "Its rubberized doesn't look like it in the picture but it is It's really cute I love this case used it for awhile but I switch out cases like I do my shoes.", 'overall': 5.0, 'summary': 'Love it', 'unixReviewTime': 1361232000, 'reviewTime': '02 19, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'AJDJ6SQUDORP6', 'asin': '7887421268', 'reviewerName': 'patricia t. "patricia tolman"', 'helpful': [0, 0], 'reviewText': "Received this in about a weeks time. Very nice actually considering how cheap the price was. It's a pink/purple with black leopard spots and has a very nice feel to it. I haven't tried to remove it yet, but hopefully it won't give me any trouble when I do want to change covers.", 'overall': 5.0, 'summary': 'good deal', 'unixReviewTime': 1319155200, 'reviewTime': '10 21, 2011', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A1Q8EBW9PB0H93', 'asin': '7887421268', 'reviewerName': 'Shelby Beaver', 'helpful': [0, 0], 'reviewText': 'This case was by far the best case I bought for this phone.  It is very stylish and I received many compliments', 'overall': 5.0, 'summary': 'stylish!', 'unixReviewTime': 1400112000, 'reviewTime': '05 15, 2014', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'AY9MQ4QNQDU5B', 'asin': '7887421268', 'reviewerName': 'Super Mom! "GA Peach"', 'helpful': [2, 2], 'reviewText': 'This is the cutest case EVER!  I love it because it was easy to apply.  I had to switch from the rubber one because after so many uses, it wears out like the bottom hem of a sweater that has been stretched.  This case keeps my phone intact and protected at the same time...WOO HOO!!', 'overall': 5.0, 'summary': 'SOOO CUTE AND AFFORDABLE!', 'unixReviewTime': 1323388800, 'reviewTime': '12 9, 2011', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A3UFJDFSLI21AT', 'asin': '7887421268', 'reviewerName': 'xsi user', 'helpful': [0, 0], 'reviewText': 'my daughter liked it for a few days and then i didnt see it anymore on the phone. Use your judgement on that one.', 'overall': 5.0, 'summary': 'plastic with suede', 'unixReviewTime': 1361318400, 'reviewTime': '02 20, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases']]}
# {'reviewerID': 'A205L2POTHUAR7', 'asin': '8199406933', 'reviewerName': 'Ana', 'helpful': [0, 0], 'reviewText': 'very good charger, it woks fine, no complaints!!! I would recommend it!! It was good, but not using it anymore!', 'overall': 4.0, 'summary': 'Good charger!', 'unixReviewTime': 1384128000, 'reviewTime': '11 11, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Batteries', 'Internal Batteries']]}
# {'reviewerID': 'A2CCYTJQNBHFA0', 'asin': '8199406933', 'reviewerName': 'Messy MakeUp Drawer "Michelle MakeUp"', 'helpful': [0, 0], 'reviewText': "This product arrived when promised and in the condition promised. It is a genuine Blackberry charger. It was brand new and worked perfectly. For the price, I don't think you can ask for much more than that!", 'overall': 5.0, 'summary': 'Great buy, great quality', 'unixReviewTime': 1345852800, 'reviewTime': '08 25, 2012', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Batteries', 'Internal Batteries']]}
# {'reviewerID': 'A1STLXG6FB22P2', 'asin': '8199406933', 'reviewerName': 'Natica C.', 'helpful': [0, 0], 'reviewText': 'Great product. Use this with my Galaxy S4. At this price I bought 2 more. One for work and one to keep in the car incase I ever travel and forget my charger.', 'overall': 5.0, 'summary': 'Great charger and great price', 'unixReviewTime': 1384905600, 'reviewTime': '11 20, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Batteries', 'Internal Batteries']]}
# {'reviewerID': 'AZOFNVDHKYKNL', 'asin': '8199406933', 'reviewerName': 'Onir Pernia "Onir Pernia"', 'helpful': [0, 0], 'reviewText': "Honestly I have always loved this specific model, since you can just take it with you on the road not worrying if you end up losing it or leaving it where ever you go. Though it doesn't exactly meet the fast charging needs of high end phones, it works pretty well on all of them, you just need to be patient.", 'overall': 5.0, 'summary': 'Great multipurpose charger!', 'unixReviewTime': 1371600000, 'reviewTime': '06 19, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Batteries', 'Internal Batteries']]}
# {'reviewerID': 'A1W8C6YKUV2DNK', 'asin': '8199406933', 'reviewerName': 'Tyler', 'helpful': [0, 0], 'reviewText': "I've had this charger well over a year now, and it still works perfectly.  Most chargers would have broken by now.  The folding blades make this more portable than the chargers that come with some Blackberry models that have adapters for different countries.", 'overall': 5.0, 'summary': 'Holds up over time', 'unixReviewTime': 1316044800, 'reviewTime': '09 15, 2011', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Batteries', 'Internal Batteries']]}
# {'reviewerID': 'A1ABWKQZJZPXMG', 'asin': '8288853439', 'reviewerName': 'Carolin Mng "carolinm"', 'helpful': [0, 0], 'reviewText': "so far no problems, it charges fast that is what i need it. it doesn' have an USB as it specified, jus a direct wall charger.", 'overall': 5.0, 'summary': 'Working fine', 'unixReviewTime': 1389312000, 'reviewTime': '01 10, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Travel Chargers']]}
# {'reviewerID': 'A2C9H5QRLXXICT', 'asin': '8288853439', 'reviewerName': 'c c', 'helpful': [0, 0], 'reviewText': "Great ! So far.I had this charger before and it seem to last pretty good 3 years fits most phones except Iphone and Galaxy 5  but that phone can still use it in the right side of the portal it will Judy charge it a bit slower. When this charger goes it tends to loose it's fit firmly in usb and has a short.", 'overall': 4.0, 'summary': 'GOOD BUY', 'unixReviewTime': 1402531200, 'reviewTime': '06 12, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Travel Chargers']]}
# {'reviewerID': 'A3KUXQ8TR97MF9', 'asin': '8288853439', 'reviewerName': 'Charles A. Kozlowsky "Book Lover"', 'helpful': [0, 0], 'reviewText': 'Another very good phone charger that does the job and has a  very affordable price that anyone can afford  to buy it.', 'overall': 4.0, 'summary': 'Very good charger.', 'unixReviewTime': 1355356800, 'reviewTime': '12 13, 2012', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Travel Chargers']]}
# {'reviewerID': 'A2A817AADURYEF', 'asin': '8288853439', 'reviewerName': 'David LaBedz "dml"', 'helpful': [0, 0], 'reviewText': 'Works well. We use this for travel and it lives in our luggage most of the year. For the low price having an extra USB charger this works great. Charges our Galaxy S3 and Note 2.', 'overall': 5.0, 'summary': 'Travel charger.', 'unixReviewTime': 1388620800, 'reviewTime': '01 2, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Travel Chargers']]}
# ...
# {'reviewerID': 'A348WQNXBUQ45S', 'asin': 'B000NVNEPE', 'reviewerName': 'edward ko', 'helpful': [0, 0], 'reviewText': 'Alright, I am a guy, and I can confidently say that the black ones belongs to us.My gf lost her iphone 5s and bought a S4, and was looking for a case.As I was shopping for a case for my S4 as well, I bought one from More (Para Vertex) and this back LuxePave black diamond for my gf.Upon receiving the two, I was so disappointed by the product from More which i paid over 40 dollars, this one caught my eyeI installed it on my phone and holy ****. My phone looked so freakin awesome and the fit was perfect.In the end, I stole this one from my gf and started using it. The backside of it has a very nice feel, not slippery at all.I highly recommend this product, if you are a male, get the black one.Great looks, great feel, great protection, great fit, great price5 Stars', 'overall': 5.0, 'summary': 'I was so disappointed by the product from More which i paid over ...', 'unixReviewTime': 1404259200, 'reviewTime': '07 2, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Accessory Kits']]}
# {'reviewerID': 'A25YDPYV1V9NG1', 'asin': 'B000NVNEPE', 'reviewerName': 'Kasandra "The Lady K"', 'helpful': [0, 0], 'reviewText': "I like the product but I'm not excited about it. Very easy to snap on and off.  I haven't tested it out yet because I have other cases that I use as well.", 'overall': 3.0, 'summary': 'Ok product', 'unixReviewTime': 1375056000, 'reviewTime': '07 29, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Accessory Kits']]}
# {'reviewerID': 'A2WQDBFBZQFYF', 'asin': 'B000NVNEPE', 'reviewerName': 'LADYTECH "LT"', 'helpful': [4, 4], 'reviewText': "Not only do I love the quality of BoxWave products but I love the look of these cases. The black you can barely notice the pattern on the lighter colored ones pattern looks awesome. I purchased all 3 colors. The price out of this world. Now one thing I noticed about these cases the back colored panel you see isn't built into the case from the inside it's actually a paste on piece of material which seems that if your careless it can start to peel off. For the price i got em for It's a worthy purchases if you were paying more then maybe not. The case is smooth to the touch so smooth that i thin if your not careful picking up the phone with a rapid motion the phone can go flying off your hands. The cover as well does not cover the phone in full it only covers back mostly, sides are left exposes and corners as well. Don't think you can see this from the pics included. If you drop your phone it's a goner. Now is this a negative review no, because all in all i love the quality, the look and the price. I have over 15 cases so these I can use when playing dress up with phone. If it's your only case and ur looking for protection pass on this does not protect the phone much.", 'overall': 5.0, 'summary': 'love the look', 'unixReviewTime': 1370390400, 'reviewTime': '06 5, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Accessory Kits']]}
# {'reviewerID': 'A14ZFE711UXUXN', 'asin': 'B000NVNEPE', 'reviewerName': 'Thomas Brown', 'helpful': [0, 0], 'reviewText': "I like to have a cover that is not too bulky and this one does that however, it is definitely not for protection. I don't feel like it offers my phone protection it leaves the front completely exposed with no ridges that fold over at all.", 'overall': 4.0, 'summary': 'functional', 'unixReviewTime': 1372377600, 'reviewTime': '06 28, 2013', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Accessory Kits']]}
# {'reviewerID': 'A3CENMWRET76W', 'asin': 'B000NWIU70', 'reviewerName': 'Amazon Customer', 'helpful': [0, 0], 'reviewText': "The HTC One is a great looking phone.  I have the anodized blue Best Buy version so I wanted a case that didn't cover up the good looks of the phone. The back of the phone is protected well.  Holes for the camera, flash and speaker are in the proper locations.  There are cutouts on the right side for the volume rocker and the top and bottom are fully exposed. This includes the top portion of the phone over the speakers.  This is a problem for some and I must admit that it does bother me a little when I'm placing the phone on the table face down.  There is a little bit of an edge on the sides that keep the phone raised off a flat surface (when face down).  The case adds very little bulk to the phone and I think it improves the grip of the phone.  The bare phone is a bit silky and slippery.Typically I'm easy on phones and don't need a whole lot of protection.  The exposed portions on the top of the phone do concern me and I have to remind myself not to place the phone in the same pocket as keys or loose change. Other than that the case does what it's supposed to do.  I can already see the thin scratches from daily wear and can imagine what that would look like if I didn't have the case on.Overall I'm happy with this purchase.", 'overall': 4.0, 'summary': 'What I expected', 'unixReviewTime': 1397174400, 'reviewTime': '04 11, 2014', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases'], ['Cell Phones & Accessories', 'Cases', 'Wallet Cases']]}
# {'reviewerID': 'A1F0XEW2GCWPSC', 'asin': 'B000NWIU70', 'reviewerName': 'Anthony B', 'helpful': [0, 0], 'reviewText': "I have quite a few cases for my beautiful HTC One, and they all have one huge problem; They hide the phone.  This case may not provide the best coverage, but wow does it look nice.  I use this case at work, and when I'm out to dinner.  It really shows off the good looks of the phone.  It's hard plastic so it does pick up scratches, but rather the case than the aluminum.Definitely would buy again.", 'overall': 5.0, 'summary': 'Great case for a great price', 'unixReviewTime': 1369699200, 'reviewTime': '05 28, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases'], ['Cell Phones & Accessories', 'Cases', 'Wallet Cases']]}
# {'reviewerID': 'A2JJ91QMGWWBEC', 'asin': 'B000NWIU70', 'reviewerName': 'Chad in PHX "USA-1"', 'helpful': [0, 0], 'reviewText': 'UPDATE:You will drop your phone using this case and I never dropped my phone before. It\'s very slick with no grip on the edges. Thankfully didn\'t damage the phone, which displays the HTC ONE\'s superior build quality as it was dropped on hard ceramic tile from 36" counter height. Like I said before the clear plastic will and DOES scratch really easily.I did like that you could barely tell that my phone had a case on it and literally had compliments on that fact, but the risk of damage is too great for me.Just reinstalled the stock smoked(color can\'t display the awesome brushed aluminum on back)TPU case for now to protect it.ORIGINAL REVIEW:It does fit snug and snaps into place, but very limited edge coverage so won\'t protect like it should. Feels like it would snap/slip off the edge if dropped, not protecting the phone like it should. Polished hard plastic not the TPU rubber/plastic style so it will scratch easier on the back.', 'overall': 2.0, 'summary': 'Slim design, but minimal protection', 'unixReviewTime': 1383609600, 'reviewTime': '11 5, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases'], ['Cell Phones & Accessories', 'Cases', 'Wallet Cases']]}
# {'reviewerID': 'AJSR97WI3CRQY', 'asin': 'B000NWIU70', 'reviewerName': 'chimpandroid', 'helpful': [0, 1], 'reviewText': "It shows off your HTC One well but has a few drawbacks. The top and the bottom edges are not covered so protection from dings on two of the edges your device is most likely to fall on is non existent. The way the cut out is over the the volume rocker makes it difficult to use, it is fairly easy to get use to it for the volume only but just try and take a screenshot and it is nearly impossible without taking the case completely off. Speaking about taking the case off....pain in the butt. It has a tiny rim around all the edges to secure it on. That rim,  if you have any type of skin on your device will peel that skin right off. If you do have a habit of using a protective skin on your devices don't pick this case also. Not a good combination. Also right now this case is about 2 weeks in use and shows much wear as far as the clarity of the plastic. Many scratches. Not nearly the long lasting scratch resistance I was looking for when I switched to the hard case. I had much better luck with a couple other clear TPU cases. One I really liked and will be going back to is the Supcase http://www.amazon.com/gp/product/B00C3H8WLW/ref=cm_cr_ryp_prd_ttl_sol_170", 'overall': 3.0, 'summary': "It's ok", 'unixReviewTime': 1398211200, 'reviewTime': '04 23, 2014', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases'], ['Cell Phones & Accessories', 'Cases', 'Wallet Cases']]}
# {'reviewerID': 'A2LDQ92M0ZHY9F', 'asin': 'B000NWIU70', 'reviewerName': 'chrissyhu', 'helpful': [9, 11], 'reviewText': "I like this case. the only thing that made me worry was the thin section by the volume rocker, but it has held up well. I like that it doesn't hurt my ear when i talk on my phone. i like that it doesn't interfere when I text. I love that it doesn't add any bulk to the phone and still protects my phone. I have been using this case for about a month. It meets all my requirements. 1 fits 2 works good 3 price is great 4 protects my phone.", 'overall': 4.0, 'summary': 'i like this case', 'unixReviewTime': 1372377600, 'reviewTime': '06 28, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases'], ['Cell Phones & Accessories', 'Cases', 'Wallet Cases']]}
# {'reviewerID': 'AN1I2UOV8CZ6L', 'asin': 'B000NWIU70', 'reviewerName': 'J. Dufrene "JD"', 'helpful': [0, 0], 'reviewText': "Only looking for scratch protection from the back of the phone. It doesn't hide the beauty of the phone and hardly adds bulk at all.Mine is completely void of any logos. The picture showed that the boxwave logo was on the back of the case, but mine arrived without. Just how I would've wanted it.If you aren't prone to dropping your phone, this case is perfect. Well done boxwaveUpdate***After a couple days of using the case, I have found it very uncomfortable.  The top and bottom of the case is not rounded.  It's almost sharp.  It's uncomfortable on the fingers.  I switched back to my other case", 'overall': 2.0, 'summary': 'its perfect if you are ...', 'unixReviewTime': 1369785600, 'reviewTime': '05 29, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases'], ['Cell Phones & Accessories', 'Cases', 'Wallet Cases']]}
# {'reviewerID': 'A2E620Y8Q5HQ9G', 'asin': 'B000NWIU70', 'reviewerName': 'Kara', 'helpful': [0, 0], 'reviewText': "I absolutely LOVE this case! Its super thin, you can hardly feel it on the phone, the volume buttons are easy to access, and I the top and bottom cut outs are one of my favorite features. The only part I don't love is that scratches are easily accumulated and I toss my phone in my purse so I've already acquired quite a few.. But that's the way it does with any hard case. I got one to keep as a backup and I'm ordering one of the soft TPU cases today :)", 'overall': 5.0, 'summary': 'Love this case.', 'unixReviewTime': 1371600000, 'reviewTime': '06 19, 2013', 'categories': [['Cell Phones & Accessories', 'Cases', 'Basic Cases'], ['Cell Phones & Accessories', 'Cases', 'Wallet Cases']]}
# {'reviewerID': 'A1D7ZR0NYWI9FU', 'asin': 'B000O2X2OU', 'reviewerName': 'bblumberg', 'helpful': [0, 0], 'reviewText': 'size and shape are a bit awkward, but this powerXtender is universal, when combined with your iGo products. On its own, not as useful.update 09/2012.This product worked great for basic cell phones. However, it is not capable of charging either of my Android phones (Galaxy SII, Galaxy Nexus) more than ~35% and gets extraordinarily hot in the process. If you want a power extender for a smart phone, go with one of the Lithium batteries like the PowerGen mobile juice pack.', 'overall': 3.0, 'summary': 'good product', 'unixReviewTime': 1276387200, 'reviewTime': '06 13, 2010', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Travel Chargers']]}
# {'reviewerID': 'A2BLFCOPSMBOZ9', 'asin': 'B000O2X2OU', 'reviewerName': 'Dave Edmiston', 'helpful': [0, 0], 'reviewText': "I've used this for a couple of years as a back-up charger for my Kindle or for some of the phones in my family.  I haven't had much luck charging my iPhone with it, but the rest of the phones did OK.  It's perfect for my Kindle though.As some other reviewers pointed out, it sticks straight out of the device that it's charging.  So it isn't very practical to use the device and charge it at the same time.  But if you're stuck in an airport and need to charge something before a flight, it sure beats not having any charge at all.I assume they designed it that way because it's a more efficient use of battery power than a longer cable would have been.  Just a guess...I don't leave home without mine though.  It's in my emergency cable pouch that I always take wherever I go.  I just have to remember to replace the batteries from time to time.", 'overall': 4.0, 'summary': 'Great backup (last resort)', 'unixReviewTime': 1289865600, 'reviewTime': '11 16, 2010', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Travel Chargers']]}
# {'reviewerID': 'A3BIZK29N5RUYU', 'asin': 'B000O2X2OU', 'reviewerName': 'doctor D', 'helpful': [0, 0], 'reviewText': 'very very very nice for the price', 'overall': 5.0, 'summary': 'Five Stars', 'unixReviewTime': 1404518400, 'reviewTime': '07 5, 2014', 'categories': [['Cell Phones & Accessories', 'Accessories', 'Chargers', 'Travel Chargers']]}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-1a1ce35d49cc> in <module>()
#       4     #TODO: retrieve category from product_mata_data
#       5     product_metadata_cursor = mydb.amazon_product_metadata.find({"asin": l["asin"]})
# ----> 6     first_matching_product_metadata = product_metadata_cursor[0]
#       7     l["categories"] = first_matching_product_metadata["categories"]
#       8     print(l)
#
# /media/mister/Extension/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in __getitem__(self, index)
#     581                 raise IndexError("Cursor instances do not support negative "
#     582                                  "indices")
# --> 583             clone = self.clone()
#     584             clone.skip(index + self.__skip)
#     585             clone.limit(-1)  # use a hard limit
#
# /media/mister/Extension/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in clone(self)
#     250         completely evaluated.
#     251         """
# --> 252         return self._clone(True)
#     253
#     254     def _clone(self, deepcopy=True):
#
# /media/mister/Extension/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in _clone(self, deepcopy)
#     263                     if k.startswith('_Cursor__') and k[9:] in values_to_clone)
#     264         if deepcopy:
# --> 265             data = self._deepcopy(data)
#     266         clone.__dict__.update(data)
#     267         return clone
#
# /media/mister/Extension/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in _deepcopy(self, x, memo)
#    1186                 value = self._deepcopy(value, memo)
#    1187             elif not isinstance(value, RE_TYPE):
# -> 1188                 value = copy.deepcopy(value, memo)
#    1189
#    1190             if is_list:
#
# /media/mister/Extension/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     144         return y
#     145
# --> 146     cls = type(x)
#     147
#     148     copier = _deepcopy_dispatch.get(cls)
#
# KeyboardInterrupt:
