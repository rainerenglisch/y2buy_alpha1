# %% [markdown]
# import pymongo
# client = pymongo.MongoClient()
# mydb = client['y2buy_1']
#
# my_amazon_product_reviews = mydb['amazon_product_reviews']

# %%
import json 
import gzip 
def parse(path): 
    g = gzip.open(path, 'r') 
    for l in g: 
        yield eval(l)

# %% [markdown]
# import nltk
# from nltk.stem.wordnet import WordNetLemmatizer
# #from nltk import word_tokenize
# import string
# from nltk.corpus import stopwords
#
#
# class MySentences():
#     def __init__(self):
#         self.reviews_cursor = my_amazon_product_reviews.find()
#         self.sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
#         self.stop = set(stopwords.words('english'))
#         self.exclude = set(string.punctuation)
#         self.lemma = WordNetLemmatizer()
#
#     def __iter__(self):
#         for review_item in self.reviews_cursor:
#             reviewText = review_item["reviewText"]
#             for sentence in self.sent_detector.tokenize(reviewText):
#                 #print(sentence)
#                 tokens = nltk.word_tokenize(sentence.lower())
#                 #tokens = word_tokenize(sentence.lower())
#                 #tokens = sentence.lower().split()
#                 normalized_tokens = [self.lemma.lemmatize(token)
#                                      for token in tokens
#                                      #if token not in self.stop and
#                                      token not in self.exclude
#                                     ]
#                 print(normalized_tokens)
#                 yield normalized_tokens

# %% [markdown]
# import nltk
# from nltk.stem.wordnet import WordNetLemmatizer
# #from nltk import word_tokenize
# import string
# from nltk.corpus import stopwords
#
#
# class MySentences():
#     def __init__(self):
#         #self.reviews_cursor = my_amazon_product_reviews.find()
#         self.sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
#         self.stop = set(stopwords.words('english'))
#         self.exclude = set(string.punctuation)
#         self.lemma = WordNetLemmatizer()
#
#     def __iter__(self):
#         for review_item in parse("../../download/reviews_Cell_Phones_and_Accessories.json.gz"):
#         #for review_item in self.reviews_cursor:
#             reviewText = review_item["reviewText"]
#             for sentence in self.sent_detector.tokenize(reviewText):
#                 #print(sentence)
#                 tokens = nltk.word_tokenize(sentence.lower())
#                 #tokens = word_tokenize(sentence.lower())
#                 #tokens = sentence.lower().split()
#                 normalized_tokens = [self.lemma.lemmatize(token)
#                                      for token in tokens
#                                      #if token not in self.stop and
#                                      if token not in self.exclude
#                                     ]
#                 print(type(normalized_tokens))
#                 yield normalized_tokens

# %%
class MySentences():
    def __init__(self):
        #self.reviews_cursor = my_amazon_product_reviews.find()
        self.sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
        #self.stop = set(stopwords.words('english'))
        #self.exclude = set(string.punctuation)
        #self.lemma = WordNetLemmatizer()
        self.i = 0
        

    def __iter__(self):

        r_i = 0
        review_item_iterator = iter(parse("../../download/reviews_Cell_Phones_and_Accessories.json.gz"))
        #for review_item in parse("../../download/reviews_Cell_Phones_and_Accessories.json.gz"): 
        for it in range(1000000):
            if it%10000==0:
                print("it="+str(it))
            review_item = next(review_item_iterator)
        #for review_item in self.reviews_cursor:
            r_i = r_i + 1
            if r_i%10000==0:
                print(str(r_i)+ " / " + str(self.i))
                print(preprocess_sentence)
            reviewText = review_item["reviewText"]
            s_i = 0  
            for sentence in self.sent_detector.tokenize(reviewText):
                self.i = self.i + 1
                s_i = s_i + 1

                #tokens = nltk.word_tokenize(sentence.lower())
                #normalized_tokens = [self.lemma.lemmatize(token) 
                #                     for token in tokens 
                #                     if token not in self.exclude
                #                    ]

                label = review_item["asin"] + "_" + review_item["reviewerID"] + "_" + str(s_i)
                preprocess_sentence = gensim.utils.simple_preprocess(sentence)
                #print(type(preprocess_sentence))

                #yield gensim.models.doc2vec.LabeledSentence(words=normalized_tokens, tags=[label])
                yield preprocess_sentence

# %% [markdown]
# for sent in sentence():
#     print(sent)

# %%
import gensim
sentences = MySentences()
model = gensim.models.Word2Vec(sentences)
# Out:
# it=0
# 10000 / 36312
# ['like', 'my', 'product', 'but', 'delivery', 'was', 'terrible', 'they', 'just', 'throw', 'my', 'package', 'on', 'the', 'steps', 'will', 'never', 'want', 'any', 'of', 'my', 'packages', 'coming', 'from', 'them', 'try', 'not', 'to', 'use', 'prestige', 'delivery']
# it=10000
# 20000 / 94426
# ['the', 'only', 'complaint', 'have', 'is', 'it', 'could', 'be', 'louder', 'but', 'it', 'serves', 'my', 'purpose']
# it=20000
# 30000 / 146636
# ['but', 'the', 'first', 'two', 'issues', 'are', 'reasons', 'would', 'not', 'recommend', 'these', 'even', 'if', 'the', 'malfunction', 'is', 'just', 'bad', 'unit']
# it=30000
# 40000 / 197864
# ['excellent', 'and', 'about', 'time']
# it=40000
# 50000 / 254984
# ['thanks']
# it=50000
# 60000 / 307995
# ['the', 'clip', 'itself', 'is', 'sturdy', 'buy', 'find', 'that', 'it', 'does', 'not', 'open', 'as', 'far', 'as', 'like', 'it', 'to']
# it=60000
# 70000 / 353570
# ['had', 'hard', 'time', 'finding', 'one', 'but', 'it', 'was', 'worth', 'the', 'wait']
# it=70000
# 80000 / 400340
# ['quality', 'seems', 'ok', 'no', 'problems', 'so', 'far']
# it=80000
# 90000 / 447233
# ['still', 'worth', 'the', 'price', 'for', 'the', 'protection']
# it=90000
# 100000 / 492832
# ['it', 'even', 'comes', 'with', 'miniature', 'clip', 'that', 'can', 'be', 'used', 'to', 'tie', 'up', 'the', 'extra', 'slack', 'which', 'happens', 'all', 'the', 'time', 'to', 'me', 'while', 'driving', 'go', 'ahead', 'and', 'grab', 'one', 'you', 'won', 'be', 'disappointed']
# it=100000
# 110000 / 537302
# ['ie', 'sometimes', 'when', 'grab', 'for', 'the', 'phone', 'pull', 'it', 'out', 'of', 'the', 'case', 'rather', 'than', 'pull', 'the', 'case', 'too']
# it=110000
# 120000 / 584570
# ['it', 'makes', 'my', 'calendar', 'activities', 'easy', 'to', 'keep', 'up', 'with', 'keeps', 'me', 'in', 'touch', 'via', 'email', 'and', 'can', 'use', 'it', 'as', 'an', 'external', 'hdd']
# it=120000
# 130000 / 634276
# ['haven', 'done', 'this', 'yet', 'as', 'family', 'medical', 'emergency', 'took', 'priority']
# it=130000
# 140000 / 674989
# ['the', 'cable', 'worked', 'fine', 'at', 'first', 'but', 'within', 'two', 'weeks', 'it', 'came', 'loose', 'and', 'stopped', 'working', 'the', 'white', 'tube', 'covering', 'the', 'wires', 'was', 'already', 'loose', 'when', 'it', 'arrived', 'then', 'it', 'completely', 'opened', 'and', 'broke']
# it=140000
# 150000 / 719040
# ['thanks', 'again']
# it=150000
# 160000 / 766808
# ['right', 'handed', 'like', 'the', 'design', 'so', 'much', 'll', 'still', 'buy', 'another']
# it=160000
# 170000 / 813538
# ['it', 'seems', 'to', 'be', 'more', 'scratch', 'resistant', 'or', 'atleast', 'hides', 'the', 'scratches', 'better']
# it=170000
# 180000 / 861070
# ['the', 'last', 'unit', 'only', 'lasted', 'months']
# it=180000
# 190000 / 909602
# ['looking', 'for', 'replacement', 'earpiece', 'now']
# it=190000
# 200000 / 955833
# ['my', 'sons', 'now', 'have', 'my', 'wife', 'and', 'my', 'old', 'iphone', 'gs', 'and', 'they', 'have', 'the', 'otterbox', 'defender', 'on', 'them', 'lot', 'of', 'you', 'out', 'there', 'while', 'know', 'why', 'some', 'may', 'even', 'find', 'out', 'later', 'what', 'great', 'case', 'this', 'is', 'with', 'kids', 'always', 'wanting', 'to', 'borrow', 'the', 'phone', 'trust', 'me', 'buy', 'any', 'otterbox', 'case', 'they', 'are', 'well', 'worth', 'the', 'money']
# it=200000
# 210000 / 999524
# ['oh', 'well']
# it=210000
# 220000 / 1045994
# ['these', 'are', 'brand', 'new', 'and', 'are', 'working', 'like', 'charm']
# it=220000
# 230000 / 1085179
# ['my', 'phone', 'is', 'new', 'again']
# it=230000
# 240000 / 1127464
# ['would', 'not', 'recommend']
# it=240000
# 250000 / 1174366
# ['do', 'not', 'recommend', 'this', 'phone', 'this', 'phone', 'sucks', 'version', 'spanish', 'no', 'le', 'compres', 'este', 'telefono', 'al', 'vendedor', 'yo', 'se', 'lo', 'compre', 'porque', 'me', 'parecio', 'que', 'su', 'dise', 'ntilde', 'era', 'muy', 'lindo', 'femenino', 'ademas', 'yo', 'amo', 'los', 'blackberrys', 'recientemente', 'tuve', 'uno', 'el', 'vendedor', 'me', 'envio', 'el', 'telefono', 'con', 'una', 'bateria', 'erronea', 'no', 'encendia', 'cuando', 'lo', 'recibi', 'luego', 'yo', 'compre', 'la', 'bateria', 'adecuada', 'me', 'encendio', 'sin', 'problemas', 'pero', 'cuando', 'intente', 'activar', 'el', 'servicio', 'bis', 'de', 'blackberry', 'el', 'telefono', 'nunca', 'levanto', 'la', 'se', 'ntilde', 'al', 'en', 'edge', 'yo', 'se', 'lo', 'comente', 'al', 'vendedor', 'el', 'me', 'dijo', 'que', 'si', 'quitaba', 'el', 'comentario', 'negativo', 'que', 'hice', 'hacia', 'el', 'el', 'me', 'resolveria', 'el', 'problema', 'hasta', 'me', 'enviaria', 'una', 'bateria', 'nueva', 'pero', 'no', 'fue', 'asi', 'una', 'vez', 'que', 'quite', 'el', 'comentario', 'pocas', 'veces', 'me', 'respondio', 'no', 'resolvio', 'mi', 'problema', 'solo', 'me', 'dijo', 'que', 'tenia', 'que', 'enviar', 'el', 'telefono', 'estados', 'unidos', 'yo', 'soy', 'de', 'venezuela', 'enviarlo', 'estados', 'unidos', 'me', 'saldria', 'muy', 'costoso', 'por', 'lo', 'cual', 'solo', 'le', 'dije', 'que', 'se', 'encargara', 'de', 'liberar', 'el', 'imei', 'del', 'telefono', 'cosa', 'que', 'tampoco', 'hizo', 'fui', 'estafada', 'robada', 'por', 'este', 'vendedor', 'realmente', 'quitando', 'todo', 'eso', 'las', 'caracteristicas', 'del', 'telefono', 'son', 'muy', 'pobres', 'la', 'camara', 'es', 'malisima', 'tiene', 'mal', 'enfoque', 'de', 'lejos', 'el', 'sonido', 'es', 'bueno', 'pero', 'de', 'resto', 'es', 'un', 'telefono', 'inservible', 'no', 'recomiendo', 'este', 'telefono', 'mucho', 'menos', 'para', 'la', 'gente', 'latina', 'ya', 'que', 'se', 'nos', 'hace', 'imposible', 'hacer', 'cubrir', 'la', 'garantia', 'este', 'es', 'el', 'unico', 'modelo', 'que', 'no', 'se', 'puede', 'reparar', 'odio', 'este', 'telefono', 'es', 'la', 'peor', 'compra', 'que', 'he', 'hecho', 'en', 'amazon']
# it=250000
# 260000 / 1224181
# ['works', 'fine', 'now', 'just', 'kind', 'of', 'long', 'wait', 'to', 'get', 'it']
# it=260000
# 270000 / 1267179
# ['it', 'installed', 'easily', 'and', 'didn', 'give', 'it', 'second', 'thought', 'until', 'now']
# it=270000
# 280000 / 1313303
# ['thank', 'you', 'very', 'much']
# it=280000
# 290000 / 1355170
# ['dont', 'know', 'how', 'it', 'works', 'on', 'cases', 'as', 'just', 'carry', 'mine', 'in', 'my', 'pocket', 'but', 'the', 'larger', 'battery', 'does', 'slightly', 'increase', 'the', 'width', 'of', 'the', 'phone']
# it=290000
# 300000 / 1397379
# ['works']
# it=300000
# 310000 / 1441219
# ['of', 'course', 'this', 'doesn', 'offer', 'the', 'most', 'protection', 'but', 'it', 'does', 'offer', 'some', 'and', 'it', 'made', 'little', 'boy', 'very', 'happy']
# it=310000
# 320000 / 1488466
# ['although', 'great', 'concept', 'with', 'good', 'combination', 'of', 'features', 'the', 'samsung', 'flight', 'barely', 'coasts', 'in', 'performance', 'and', 'usability', 'for', 'the', 'full', 'review', 'go', 'to']
# it=320000
# 330000 / 1535052
# ['very', 'pleased']
# it=330000
# 340000 / 1579727
# ['bought', 'in', 'july', 'this', 'year', 'and', 'am', 'buying', 'one', 'more', 'for', 'our', 'other', 'car', 'because', 'it', 'is', 'great', 'if', 'you', 'use', 'the', 'voice', 'dial', 'you', 'just', 'need', 'to', 'press', 'button', 'to', 'make', 'any', 'call', 'and', 'when', 'you', 'receive', 'one', 'call', 'it', 'informs', 'you', 'from', 'what', 'number', 'they', 'are', 'calling', 'you', 'by', 'voice', 'also', 'tried', 'the', 'fm', 'transmitter', 'and', 'it', 'works', 'great', 'with', 'the', 'plus', 'that', 'if', 'call', 'comes', 'it', 'pauses', 'the', 'music', 'so', 'you', 'do', 'not', 'have', 'to', 'turn', 'off', 'your', 'radio', 'it', 'is', 'easy', 'to', 'operate', 'will', 'probably', 'buy', 'third', 'one', 'for', 'my', 'father']
# it=340000
# 350000 / 1621663
# ['saved', 'ton', 'of', 'money', 'by', 'purchasing', 'this', 'package', 'verses', 'buying', 'from', 'local', 'retail', 'or', 'cell', 'phone', 'store']
# it=350000
# 360000 / 1663572
# ['it', 'was', 'cheap', 'and', 'would', 'have', 'cost', 'to', 'much', 'to', 'return', 'it']
# it=360000
# 370000 / 1706038
# ['headphones', 'sound', 'surprisingly', 'better', 'than', 'was', 'expecting', 'for', 'such', 'low', 'price', 'have', 'motorola', 'droid', 'and', 'it', 'works', 'perfectly', 'you', 'can', 'also', 'skip', 'songs', 'by', 'pressing', 'the', 'button', 'on', 'the', 'microphone', 'when', 'you', 're', 'listening', 'to', 'music', 'friends', 'say', 'microphone', 'sounds', 'bit', 'tin', 'canny', 'but', 'they', 'can', 'understand', 'me', 'just', 'fine', 'it', 'not', 'problem', 'can', 'say', 'yet', 'how', 'long', 'they', 're', 'going', 'to', 'last', 'without', 'breaking', 'happy', 'so', 'far']
# it=370000
# 380000 / 1747383
# ['find', 'that', 'sometimes', 'products', 'like', 'this', 'made', 'in', 'china', 'lack', 'quality', 'control', 'so', 'some', 'are', 'good', 'and', 'others', 'not', 'so', 'much']
# it=380000
# 390000 / 1798919
# ['it', 'performs', 'exactly', 'as', 'it', 'should', 'and', 'holds', 'an', 'excellent', 'charge', 'for', 'as', 'long', 'or', 'longer', 'than', 'the', 'original']
# it=390000
# 400000 / 1841316
# ['its', 'cant', 'beat', 'it']
# it=400000
# 410000 / 1880206
# ['highly', 'recommend']
# it=410000
# 420000 / 1927972
# ['would', 'suggest', 'this', 'item', 'and', 'would', 'buy', 'again']
# it=420000
# 430000 / 1970189
# ['would', 'recommend', 'and', 'wish', 'could', 'find', 'for', 'my', 'note', 'ii']
# it=430000
# 440000 / 2015598
# ['at', 'the', 'price', 'of', 'this', 'is', 'great', 'case']
# it=440000
# 450000 / 2058547
# ['did', 'not', 'work', 'in', 'my', 'car', 'could', 'not', 'get', 'it', 'to', 'power', 'up', 'at', 'all', 'do', 'not', 'buy', 'this', 'product']
# it=450000
# 460000 / 2095070
# ['hope', 'someone', 'else', 'has', 'better', 'luck', 'with', 'this', 'thing', 'than', 'did']
# it=460000
# 470000 / 2136337
# ['great', 'case', 'great', 'price']
# it=470000
# 480000 / 2182012
# ['still', 'working', 'great', 'months', 'later']
# it=480000
# 490000 / 2223184
# ['pode', 'comprar']
# it=490000
# 500000 / 2262667
# ['the', 'headphones', 'have', 'great', 'fit', 'sound', 'clear', 'so', 'for', 'listening', 'to', 'music', 'it', 'is', 'nice', 'buy', 'liked', 'it']
# it=500000
# 510000 / 2305050
# ['would', 'suggest', 'that', 'you', 'not', 'buy', 'this', 'item']
# it=510000
# 520000 / 2346037
# ['do', 'not', 'have', 'to', 'worry', 'about', 'carrying', 'an', 'outlet', 'adapter', 'with', 'me', 'and', 'get', 'full', 'charges', 'to', 'both', 'my', 'ipad', 'and', 'iphone', 'at', 'the', 'same', 'time', 'great', 'safety', 'backup', 'battery', 'to', 'have', 'for', 'any', 'reason']
# it=520000
# 530000 / 2401054
# ['liked', 'the', 'phone']
# it=530000
# 540000 / 2443523
# ['co', 'worker', 'saw', 'mine', 'and', 'was', 'impressed', 'enough', 'to', 'buy', 'one', 'also']
# it=540000
# 550000 / 2488632
# ['bought', 'something', 'else', 'at', 'another', 'store']
# it=550000
# 560000 / 2530237
# ['love', 'it', 'because', 'it', 'was', 'in', 'expensive']
# it=560000
# 570000 / 2567659
# ['also', 'this', 'review', 'had', 'to', 'be', 'letters', 'long']
# it=570000
# 580000 / 2610072
# ['this', 'one', 'the', 'light', 'just', 'turns', 'off', 'but', 'at', 'least', 'it', 'holds', 'charge', 'all', 'day', 'without', 'dying', 'or', 'needing', 'to', 'be', 'plugged', 'in', 'again']
# it=580000
# 590000 / 2655159
# ['highly', 'recommend', 'it']
# it=590000
# 600000 / 2695457
# ['you', 'll', 'need', 'decent', 'micro', 'tool', 'set', 'to', 'get', 'the', 'job', 'done', 'right']
# it=600000
# 610000 / 2738234
# ['nice', 'item', 'and', 'used', 'often']
# it=610000
# 620000 / 2779756
# ['we', 'got', 'black', 'case', 'for', 'my', 'husband', 'phone', 'it', 'arrived', 'fine', 'and', 'we', 'like', 'them', 'both']
# it=620000
# 630000 / 2824907
# ['had', 'little', 'difficulty', 'with', 'peeling', 'the', 'screen', 'protector', 'from', 'the', 'paper', 'and', 'keeping', 'my', 'finger', 'prints', 'off', 'the', 'inside', 'trying', 'to', 'place', 'it', 'on', 'the', 'phone', 'correctly', 'but', 'other', 'than', 'that', 'found', 'this', 'to', 'be', 'great', 'product']
# it=630000
# 640000 / 2864986
# ['everyone', 'thinks', 'got', 'an', 'iphone', 'because', 'it', 'has', 'its', 'similarities', 'but', 'dont', 'want', 'an', 'iphone', 'for', 'reason', 'pros', 'love', 'all', 'the', 'featuressmall', 'cutecons', 'drains', 'battery', 'fast', 'most', 'androids', 'do']
# it=640000
# 650000 / 2907527
# ['so', 'if', 'you', 'have', 'the', 'normal', 'tab', 'recommend', 'this']
# it=650000
# 660000 / 2948014
# ['get', 'hissing', 'sound', 'on', 'my', 'jeep', 'the', 'double', 'tap', 'to', 'skip', 'wont', 'work', 'disappointed', 'rather', 'connect', 'my', 'iphone', 'directly', 'waste', 'of', 'money']
# it=660000
# 670000 / 2986856
# ['glued', 'the', 'face', 'plate', 'on', 'my', 'blackberry', 'which', 'doesn', 'concern', 'me', 'much', 'either', 'considering', 'the', 'box', 'will', 'probably', 'outlast', 'the', 'phone']
# it=670000
# 680000 / 3032885
# ['my', 'whole', 'family', 'use', 'them']
# it=680000
# 690000 / 3073555
# ['then', 'again', 'would', 'really', 'fall', 'in', 'love', 'with', 'it', 'if', 'they', 'did', 'new', 'version', 'for', 'left', 'handed', 'folks', 'like', 'me']
# it=690000
# 700000 / 3113761
# ['this', 'is', 'not', 'cellpnone', 'received', 'another', 'cheaper', 'model', 'this', 'is', 'theft']
# it=700000
# 710000 / 3154136
# ['if', 'you', 'need', 'charger', 'case', 'and', 'data', 'cable', 'for', 'cheap', 'price', 'definitely', 'get', 'this', 'one', 'they', 're', 'not', 'cheap', 'at', 'all', 'high', 'quality', 'in', 'my', 'opinion', 'the', 'only', 'reason', 'didn', 'give', 'it', 'five', 'stars', 'is', 'because', 'the', 'case', 'is', 'kind', 'of', 'snug', 'fit', 'so', 'when', 'sliding', 'the', 'keyboard', 'out', 'and', 'back', 'you', 'kinda', 'feel', 'the', 'resistance', 'but', 'barely', 'noticeable', 'so']
# it=710000
# 720000 / 3193550
# ['had', 'to', 'arrange', 'product', 'return', 'with', 'amazon']
# it=720000
# 730000 / 3229699
# ['comfortable', 'and', 'good', 'sound', 'quality', 'recommended', 'purchase']
# it=730000
# 740000 / 3270777
# ['sleek', 'smooth', 'not', 'bulky', 'and', 'offers', 'very', 'good', 'protection', 'with', 'cushioned', 'liner', 'from', 'accidental', 'drops', 'on', 'hard', 'surfaces']
# it=740000
# 750000 / 3316105
# ['also', 'would', 'fit', 'the', 'htc', 'droid', 'eris', 'they', 'both', 'use', 'the', 'same', 'battery']
# it=750000
# 760000 / 3365806
# ['it', 'good', 'for', 'while', 'but', 'after', 'months', 'start', 'do', 'enlarge', 'the', 'rubber', 'protect', 'very', 'good', 'better', 'not', 'to', 'drop', 'your', 'phone', 'give', 'only', 'stars', 'because', 'it', 'look', 'good', 'but', 'the', 'material', 'not', 'really', 'high', 'quality', 'for', 'the', 'money', 'spend', 'maybe', 'different', 'otter', 'box', 'work', 'better', 'not', 'for', 'iphone', 'really', 'sorry', 'not', 'really', 'happy', 'with', 'this']
# it=760000
# 770000 / 3410715
# ['the', 'otterbox', 'iphone', 'red', 'case', 'is', 'as', 'described', 'with', 'the', 'only', 'possible', 'con', 'being', 'that', 'the', 'tone', 'of', 'red', 'is', 'as', 'other', 'reviews', 'have', 'indicated', 'it', 'is', 'more', 'an', 'off', 'red', 'hint', 'of', 'orange', 'rather', 'than', 'full', 'rich', 'red', 'color']
# it=770000
# 780000 / 3447926
# ['muy', 'bueno', 'el', 'tlf', 'cumplio', 'mis', 'expectativas', 'tanto', 'del', 'sistema', 'operativo', 'como', 'de', 'las', 'funciones', 'del', 'telefono', 'lo', 'recomiendo']
# it=780000
# 790000 / 3488909
# ['ve', 'bought', 'another', 'kind', 'of', 'cover', 'and', 'if', 'have', 'no', 'luck', 'with', 'this', 'next', 'one', 'll', 'probably', 'just', 'consider', 'not', 'getting', 'slide', 'out', 'keyboard', 'on', 'my', 'next', 'phone']
# it=790000
# 800000 / 3530991
# ['bought', 'them', 'as', 'disposable', 'because', 'was', 'tired', 'of', 'breaking', 'more', 'expensive', 'products']
# it=800000
# 810000 / 3570188
# ['so', 'am', 'very', 'happy', 'with', 'it']
# it=810000
# 820000 / 3609142
# ['great', 'idea', 'and', 'really', 'like', 'the', 'otterbox', 'case', 'but', 'these', 'things', 'shoulf', 'be', 'stronger', 'or', 'designed', 'differently']
# it=820000
# 830000 / 3647583
# ['will', 'not', 'recommend', 'it', 'to', 'anyone']
# it=830000
# 840000 / 3686396
# ['the', 'digitizer', 'arrived', 'very', 'good', 'and', 'it', 'worked', 'perfectly', 'in', 'htc', 'desire', 'am', 'satisfied', 'with', 'the', 'product', 'and', 'recommend', 'it']
# it=840000
# 850000 / 3726780
# ['got', 'this', 'for', 'my', 'brother', 'and', 'he', 'loved', 'it', 'the', 'band', 'fits', 'great', 'around', 'his', 'arm', 'and', 'his', 'smart', 'phone', 'fits', 'perfectly']
# it=850000
# 860000 / 3767583
# ['they', 'function', 'as', 'you', 'would', 'expect']
# it=860000
# 870000 / 3808406
# ['heat', 'generated', 'from', 'the', 'screen', 'help', 'workout', 'the', 'bubbles', 'and', 'streaks', 'formed', 'from', 'the', 'installation', 'process']
# it=870000
# 880000 / 3848748
# ['cheap', 'cons', 'none']
# it=880000
# 890000 / 3888690
# ['it', 'was', 'cool', 'while', 'it', 'lasted', 'but', 'it', 'didnt', 'last', 'long', 'and', 'the', 'tail', 'would', 'not', 'stay', 'on', 'at', 'all']
# it=890000
# 900000 / 3927556
# ['would', 'recommend', 'to', 'family', 'and', 'friends']
# it=900000
# 910000 / 3978221
# ['very', 'good', 'product']
# it=910000
# 920000 / 4018974
# ['would', 'definitely', 'recommend']
# it=920000
# 930000 / 4056191
# ['all', 'came', 'as', 'it', 'shows', 'no', 'problems', 'with', 'this', 'and', 'works', 'fine', 'easy', 'to', 'install', 'and', 'no', 'need', 'to', 'purchase', 'the', 'tape', 'because', 'its', 'already', 'attached', 'the', 'glass', 'and', 'the', 'lcd']
# it=930000
# 940000 / 4094212
# ['you', 'can', 'slide', 'it', 'into', 'pocket', 'but', 'if', 'you', 'like', 'the', 'otter', 'boxes', 'you', 'll', 'love', 'this', 'because', 'it', 'not', 'as', 'large', 'but', 'protects', 'just', 'as', 'well']
# it=940000
# 950000 / 4136991
# ['it', 'works', 'really', 'well']
# it=950000
# 960000 / 4170104
# ['it', 'sturdy', 'and', 'connects', 'to', 'the', 'ipad', 'headphone', 'connector', 'to', 'keep', 'track', 'of', 'it']
# it=960000
# 970000 / 4206662
# ['he', 'says', 'they', 'are', 'the', 'best', 'value', 'for', 'money', 'in', 'the', 'market', 'and', 'he', 'has', 'done', 'his', 'research']
# it=970000
# 980000 / 4248785
# ['thanks', 'amazon']
# it=980000
# 990000 / 4288002
# []
# it=990000
# 1000000 / 4328284
# ['so', 'it', 'was', 'waste', 'of', 'money']
# it=0
# 10000 / 4364600
# ['like', 'my', 'product', 'but', 'delivery', 'was', 'terrible', 'they', 'just', 'throw', 'my', 'package', 'on', 'the', 'steps', 'will', 'never', 'want', 'any', 'of', 'my', 'packages', 'coming', 'from', 'them', 'try', 'not', 'to', 'use', 'prestige', 'delivery']
# it=10000
# 20000 / 4422714
# ['the', 'only', 'complaint', 'have', 'is', 'it', 'could', 'be', 'louder', 'but', 'it', 'serves', 'my', 'purpose']
# it=20000
# 30000 / 4474924
# ['but', 'the', 'first', 'two', 'issues', 'are', 'reasons', 'would', 'not', 'recommend', 'these', 'even', 'if', 'the', 'malfunction', 'is', 'just', 'bad', 'unit']
# it=30000
# 40000 / 4526152
# ['excellent', 'and', 'about', 'time']
# it=40000
# 50000 / 4583272
# ['thanks']
# it=50000
# 60000 / 4636283
# ['the', 'clip', 'itself', 'is', 'sturdy', 'buy', 'find', 'that', 'it', 'does', 'not', 'open', 'as', 'far', 'as', 'like', 'it', 'to']
# it=60000
# 70000 / 4681858
# ['had', 'hard', 'time', 'finding', 'one', 'but', 'it', 'was', 'worth', 'the', 'wait']
# it=70000
# 80000 / 4728628
# ['quality', 'seems', 'ok', 'no', 'problems', 'so', 'far']
# it=80000
# 90000 / 4775521
# ['still', 'worth', 'the', 'price', 'for', 'the', 'protection']
# it=90000
# 100000 / 4821120
# ['it', 'even', 'comes', 'with', 'miniature', 'clip', 'that', 'can', 'be', 'used', 'to', 'tie', 'up', 'the', 'extra', 'slack', 'which', 'happens', 'all', 'the', 'time', 'to', 'me', 'while', 'driving', 'go', 'ahead', 'and', 'grab', 'one', 'you', 'won', 'be', 'disappointed']
# it=100000
# 110000 / 4865590
# ['ie', 'sometimes', 'when', 'grab', 'for', 'the', 'phone', 'pull', 'it', 'out', 'of', 'the', 'case', 'rather', 'than', 'pull', 'the', 'case', 'too']
# it=110000
# 120000 / 4912858
# ['it', 'makes', 'my', 'calendar', 'activities', 'easy', 'to', 'keep', 'up', 'with', 'keeps', 'me', 'in', 'touch', 'via', 'email', 'and', 'can', 'use', 'it', 'as', 'an', 'external', 'hdd']
# it=120000
# 130000 / 4962564
# ['haven', 'done', 'this', 'yet', 'as', 'family', 'medical', 'emergency', 'took', 'priority']
# it=130000
# 140000 / 5003277
# ['the', 'cable', 'worked', 'fine', 'at', 'first', 'but', 'within', 'two', 'weeks', 'it', 'came', 'loose', 'and', 'stopped', 'working', 'the', 'white', 'tube', 'covering', 'the', 'wires', 'was', 'already', 'loose', 'when', 'it', 'arrived', 'then', 'it', 'completely', 'opened', 'and', 'broke']
# it=140000
# 150000 / 5047328
# ['thanks', 'again']
# it=150000
# 160000 / 5095096
# ['right', 'handed', 'like', 'the', 'design', 'so', 'much', 'll', 'still', 'buy', 'another']
# it=160000
# 170000 / 5141826
# ['it', 'seems', 'to', 'be', 'more', 'scratch', 'resistant', 'or', 'atleast', 'hides', 'the', 'scratches', 'better']
# it=170000
# 180000 / 5189358
# ['the', 'last', 'unit', 'only', 'lasted', 'months']
# it=180000
# 190000 / 5237890
# ['looking', 'for', 'replacement', 'earpiece', 'now']
# it=190000
# 200000 / 5284121
# ['my', 'sons', 'now', 'have', 'my', 'wife', 'and', 'my', 'old', 'iphone', 'gs', 'and', 'they', 'have', 'the', 'otterbox', 'defender', 'on', 'them', 'lot', 'of', 'you', 'out', 'there', 'while', 'know', 'why', 'some', 'may', 'even', 'find', 'out', 'later', 'what', 'great', 'case', 'this', 'is', 'with', 'kids', 'always', 'wanting', 'to', 'borrow', 'the', 'phone', 'trust', 'me', 'buy', 'any', 'otterbox', 'case', 'they', 'are', 'well', 'worth', 'the', 'money']
# it=200000
# 210000 / 5327812
# ['oh', 'well']
# it=210000
# 220000 / 5374282
# ['these', 'are', 'brand', 'new', 'and', 'are', 'working', 'like', 'charm']
# it=220000
# 230000 / 5413467
# ['my', 'phone', 'is', 'new', 'again']
# it=230000
# 240000 / 5455752
# ['would', 'not', 'recommend']
# it=240000
# 250000 / 5502654
# ['do', 'not', 'recommend', 'this', 'phone', 'this', 'phone', 'sucks', 'version', 'spanish', 'no', 'le', 'compres', 'este', 'telefono', 'al', 'vendedor', 'yo', 'se', 'lo', 'compre', 'porque', 'me', 'parecio', 'que', 'su', 'dise', 'ntilde', 'era', 'muy', 'lindo', 'femenino', 'ademas', 'yo', 'amo', 'los', 'blackberrys', 'recientemente', 'tuve', 'uno', 'el', 'vendedor', 'me', 'envio', 'el', 'telefono', 'con', 'una', 'bateria', 'erronea', 'no', 'encendia', 'cuando', 'lo', 'recibi', 'luego', 'yo', 'compre', 'la', 'bateria', 'adecuada', 'me', 'encendio', 'sin', 'problemas', 'pero', 'cuando', 'intente', 'activar', 'el', 'servicio', 'bis', 'de', 'blackberry', 'el', 'telefono', 'nunca', 'levanto', 'la', 'se', 'ntilde', 'al', 'en', 'edge', 'yo', 'se', 'lo', 'comente', 'al', 'vendedor', 'el', 'me', 'dijo', 'que', 'si', 'quitaba', 'el', 'comentario', 'negativo', 'que', 'hice', 'hacia', 'el', 'el', 'me', 'resolveria', 'el', 'problema', 'hasta', 'me', 'enviaria', 'una', 'bateria', 'nueva', 'pero', 'no', 'fue', 'asi', 'una', 'vez', 'que', 'quite', 'el', 'comentario', 'pocas', 'veces', 'me', 'respondio', 'no', 'resolvio', 'mi', 'problema', 'solo', 'me', 'dijo', 'que', 'tenia', 'que', 'enviar', 'el', 'telefono', 'estados', 'unidos', 'yo', 'soy', 'de', 'venezuela', 'enviarlo', 'estados', 'unidos', 'me', 'saldria', 'muy', 'costoso', 'por', 'lo', 'cual', 'solo', 'le', 'dije', 'que', 'se', 'encargara', 'de', 'liberar', 'el', 'imei', 'del', 'telefono', 'cosa', 'que', 'tampoco', 'hizo', 'fui', 'estafada', 'robada', 'por', 'este', 'vendedor', 'realmente', 'quitando', 'todo', 'eso', 'las', 'caracteristicas', 'del', 'telefono', 'son', 'muy', 'pobres', 'la', 'camara', 'es', 'malisima', 'tiene', 'mal', 'enfoque', 'de', 'lejos', 'el', 'sonido', 'es', 'bueno', 'pero', 'de', 'resto', 'es', 'un', 'telefono', 'inservible', 'no', 'recomiendo', 'este', 'telefono', 'mucho', 'menos', 'para', 'la', 'gente', 'latina', 'ya', 'que', 'se', 'nos', 'hace', 'imposible', 'hacer', 'cubrir', 'la', 'garantia', 'este', 'es', 'el', 'unico', 'modelo', 'que', 'no', 'se', 'puede', 'reparar', 'odio', 'este', 'telefono', 'es', 'la', 'peor', 'compra', 'que', 'he', 'hecho', 'en', 'amazon']
# it=250000
# 260000 / 5552469
# ['works', 'fine', 'now', 'just', 'kind', 'of', 'long', 'wait', 'to', 'get', 'it']
# it=260000
# 270000 / 5595467
# ['it', 'installed', 'easily', 'and', 'didn', 'give', 'it', 'second', 'thought', 'until', 'now']
# it=270000
# 280000 / 5641591
# ['thank', 'you', 'very', 'much']
# it=280000
# 290000 / 5683458
# ['dont', 'know', 'how', 'it', 'works', 'on', 'cases', 'as', 'just', 'carry', 'mine', 'in', 'my', 'pocket', 'but', 'the', 'larger', 'battery', 'does', 'slightly', 'increase', 'the', 'width', 'of', 'the', 'phone']
# it=290000
# 300000 / 5725667
# ['works']
# it=300000
# 310000 / 5769507
# ['of', 'course', 'this', 'doesn', 'offer', 'the', 'most', 'protection', 'but', 'it', 'does', 'offer', 'some', 'and', 'it', 'made', 'little', 'boy', 'very', 'happy']
# it=310000
# 320000 / 5816754
# ['although', 'great', 'concept', 'with', 'good', 'combination', 'of', 'features', 'the', 'samsung', 'flight', 'barely', 'coasts', 'in', 'performance', 'and', 'usability', 'for', 'the', 'full', 'review', 'go', 'to']
# it=320000
# 330000 / 5863340
# ['very', 'pleased']
# it=330000
# 340000 / 5908015
# ['bought', 'in', 'july', 'this', 'year', 'and', 'am', 'buying', 'one', 'more', 'for', 'our', 'other', 'car', 'because', 'it', 'is', 'great', 'if', 'you', 'use', 'the', 'voice', 'dial', 'you', 'just', 'need', 'to', 'press', 'button', 'to', 'make', 'any', 'call', 'and', 'when', 'you', 'receive', 'one', 'call', 'it', 'informs', 'you', 'from', 'what', 'number', 'they', 'are', 'calling', 'you', 'by', 'voice', 'also', 'tried', 'the', 'fm', 'transmitter', 'and', 'it', 'works', 'great', 'with', 'the', 'plus', 'that', 'if', 'call', 'comes', 'it', 'pauses', 'the', 'music', 'so', 'you', 'do', 'not', 'have', 'to', 'turn', 'off', 'your', 'radio', 'it', 'is', 'easy', 'to', 'operate', 'will', 'probably', 'buy', 'third', 'one', 'for', 'my', 'father']
# it=340000
# 350000 / 5949951
# ['saved', 'ton', 'of', 'money', 'by', 'purchasing', 'this', 'package', 'verses', 'buying', 'from', 'local', 'retail', 'or', 'cell', 'phone', 'store']
# it=350000
# 360000 / 5991860
# ['it', 'was', 'cheap', 'and', 'would', 'have', 'cost', 'to', 'much', 'to', 'return', 'it']
# it=360000
# 370000 / 6034326
# ['headphones', 'sound', 'surprisingly', 'better', 'than', 'was', 'expecting', 'for', 'such', 'low', 'price', 'have', 'motorola', 'droid', 'and', 'it', 'works', 'perfectly', 'you', 'can', 'also', 'skip', 'songs', 'by', 'pressing', 'the', 'button', 'on', 'the', 'microphone', 'when', 'you', 're', 'listening', 'to', 'music', 'friends', 'say', 'microphone', 'sounds', 'bit', 'tin', 'canny', 'but', 'they', 'can', 'understand', 'me', 'just', 'fine', 'it', 'not', 'problem', 'can', 'say', 'yet', 'how', 'long', 'they', 're', 'going', 'to', 'last', 'without', 'breaking', 'happy', 'so', 'far']
# it=370000
# 380000 / 6075671
# ['find', 'that', 'sometimes', 'products', 'like', 'this', 'made', 'in', 'china', 'lack', 'quality', 'control', 'so', 'some', 'are', 'good', 'and', 'others', 'not', 'so', 'much']
# it=380000
# 390000 / 6127207
# ['it', 'performs', 'exactly', 'as', 'it', 'should', 'and', 'holds', 'an', 'excellent', 'charge', 'for', 'as', 'long', 'or', 'longer', 'than', 'the', 'original']
# it=390000
# 400000 / 6169604
# ['its', 'cant', 'beat', 'it']
# it=400000
# 410000 / 6208494
# ['highly', 'recommend']
# it=410000
# 420000 / 6256260
# ['would', 'suggest', 'this', 'item', 'and', 'would', 'buy', 'again']
# it=420000
# 430000 / 6298477
# ['would', 'recommend', 'and', 'wish', 'could', 'find', 'for', 'my', 'note', 'ii']
# it=430000
# 440000 / 6343886
# ['at', 'the', 'price', 'of', 'this', 'is', 'great', 'case']
# it=440000
# 450000 / 6386835
# ['did', 'not', 'work', 'in', 'my', 'car', 'could', 'not', 'get', 'it', 'to', 'power', 'up', 'at', 'all', 'do', 'not', 'buy', 'this', 'product']
# it=450000
# 460000 / 6423358
# ['hope', 'someone', 'else', 'has', 'better', 'luck', 'with', 'this', 'thing', 'than', 'did']
# it=460000
# 470000 / 6464625
# ['great', 'case', 'great', 'price']
# it=470000
# 480000 / 6510300
# ['still', 'working', 'great', 'months', 'later']
# it=480000
# 490000 / 6551472
# ['pode', 'comprar']
# it=490000
# 500000 / 6590955
# ['the', 'headphones', 'have', 'great', 'fit', 'sound', 'clear', 'so', 'for', 'listening', 'to', 'music', 'it', 'is', 'nice', 'buy', 'liked', 'it']
# it=500000
# 510000 / 6633338
# ['would', 'suggest', 'that', 'you', 'not', 'buy', 'this', 'item']
# it=510000
# 520000 / 6674325
# ['do', 'not', 'have', 'to', 'worry', 'about', 'carrying', 'an', 'outlet', 'adapter', 'with', 'me', 'and', 'get', 'full', 'charges', 'to', 'both', 'my', 'ipad', 'and', 'iphone', 'at', 'the', 'same', 'time', 'great', 'safety', 'backup', 'battery', 'to', 'have', 'for', 'any', 'reason']
# it=520000
# 530000 / 6729342
# ['liked', 'the', 'phone']
# it=530000
# 540000 / 6771811
# ['co', 'worker', 'saw', 'mine', 'and', 'was', 'impressed', 'enough', 'to', 'buy', 'one', 'also']
# it=540000
# 550000 / 6816920
# ['bought', 'something', 'else', 'at', 'another', 'store']
# it=550000
# 560000 / 6858525
# ['love', 'it', 'because', 'it', 'was', 'in', 'expensive']
# it=560000
# 570000 / 6895947
# ['also', 'this', 'review', 'had', 'to', 'be', 'letters', 'long']
# it=570000
# 580000 / 6938360
# ['this', 'one', 'the', 'light', 'just', 'turns', 'off', 'but', 'at', 'least', 'it', 'holds', 'charge', 'all', 'day', 'without', 'dying', 'or', 'needing', 'to', 'be', 'plugged', 'in', 'again']
# it=580000
# 590000 / 6983447
# ['highly', 'recommend', 'it']
# it=590000
# 600000 / 7023745
# ['you', 'll', 'need', 'decent', 'micro', 'tool', 'set', 'to', 'get', 'the', 'job', 'done', 'right']
# it=600000
# 610000 / 7066522
# ['nice', 'item', 'and', 'used', 'often']
# it=610000
# 620000 / 7108044
# ['we', 'got', 'black', 'case', 'for', 'my', 'husband', 'phone', 'it', 'arrived', 'fine', 'and', 'we', 'like', 'them', 'both']
# it=620000
# 630000 / 7153195
# ['had', 'little', 'difficulty', 'with', 'peeling', 'the', 'screen', 'protector', 'from', 'the', 'paper', 'and', 'keeping', 'my', 'finger', 'prints', 'off', 'the', 'inside', 'trying', 'to', 'place', 'it', 'on', 'the', 'phone', 'correctly', 'but', 'other', 'than', 'that', 'found', 'this', 'to', 'be', 'great', 'product']
# it=630000
# 640000 / 7193274
# ['everyone', 'thinks', 'got', 'an', 'iphone', 'because', 'it', 'has', 'its', 'similarities', 'but', 'dont', 'want', 'an', 'iphone', 'for', 'reason', 'pros', 'love', 'all', 'the', 'featuressmall', 'cutecons', 'drains', 'battery', 'fast', 'most', 'androids', 'do']
# it=640000
# 650000 / 7235815
# ['so', 'if', 'you', 'have', 'the', 'normal', 'tab', 'recommend', 'this']
# it=650000
# 660000 / 7276302
# ['get', 'hissing', 'sound', 'on', 'my', 'jeep', 'the', 'double', 'tap', 'to', 'skip', 'wont', 'work', 'disappointed', 'rather', 'connect', 'my', 'iphone', 'directly', 'waste', 'of', 'money']
# it=660000
# 670000 / 7315144
# ['glued', 'the', 'face', 'plate', 'on', 'my', 'blackberry', 'which', 'doesn', 'concern', 'me', 'much', 'either', 'considering', 'the', 'box', 'will', 'probably', 'outlast', 'the', 'phone']
# it=670000
# 680000 / 7361173
# ['my', 'whole', 'family', 'use', 'them']
# it=680000
# 690000 / 7401843
# ['then', 'again', 'would', 'really', 'fall', 'in', 'love', 'with', 'it', 'if', 'they', 'did', 'new', 'version', 'for', 'left', 'handed', 'folks', 'like', 'me']
# it=690000
# 700000 / 7442049
# ['this', 'is', 'not', 'cellpnone', 'received', 'another', 'cheaper', 'model', 'this', 'is', 'theft']
# it=700000
# 710000 / 7482424
# ['if', 'you', 'need', 'charger', 'case', 'and', 'data', 'cable', 'for', 'cheap', 'price', 'definitely', 'get', 'this', 'one', 'they', 're', 'not', 'cheap', 'at', 'all', 'high', 'quality', 'in', 'my', 'opinion', 'the', 'only', 'reason', 'didn', 'give', 'it', 'five', 'stars', 'is', 'because', 'the', 'case', 'is', 'kind', 'of', 'snug', 'fit', 'so', 'when', 'sliding', 'the', 'keyboard', 'out', 'and', 'back', 'you', 'kinda', 'feel', 'the', 'resistance', 'but', 'barely', 'noticeable', 'so']
# it=710000
# 720000 / 7521838
# ['had', 'to', 'arrange', 'product', 'return', 'with', 'amazon']
# it=720000
# 730000 / 7557987
# ['comfortable', 'and', 'good', 'sound', 'quality', 'recommended', 'purchase']
# it=730000
# 740000 / 7599065
# ['sleek', 'smooth', 'not', 'bulky', 'and', 'offers', 'very', 'good', 'protection', 'with', 'cushioned', 'liner', 'from', 'accidental', 'drops', 'on', 'hard', 'surfaces']
# it=740000
# 750000 / 7644393
# ['also', 'would', 'fit', 'the', 'htc', 'droid', 'eris', 'they', 'both', 'use', 'the', 'same', 'battery']
# it=750000
# 760000 / 7694094
# ['it', 'good', 'for', 'while', 'but', 'after', 'months', 'start', 'do', 'enlarge', 'the', 'rubber', 'protect', 'very', 'good', 'better', 'not', 'to', 'drop', 'your', 'phone', 'give', 'only', 'stars', 'because', 'it', 'look', 'good', 'but', 'the', 'material', 'not', 'really', 'high', 'quality', 'for', 'the', 'money', 'spend', 'maybe', 'different', 'otter', 'box', 'work', 'better', 'not', 'for', 'iphone', 'really', 'sorry', 'not', 'really', 'happy', 'with', 'this']
# it=760000
# 770000 / 7739003
# ['the', 'otterbox', 'iphone', 'red', 'case', 'is', 'as', 'described', 'with', 'the', 'only', 'possible', 'con', 'being', 'that', 'the', 'tone', 'of', 'red', 'is', 'as', 'other', 'reviews', 'have', 'indicated', 'it', 'is', 'more', 'an', 'off', 'red', 'hint', 'of', 'orange', 'rather', 'than', 'full', 'rich', 'red', 'color']
# it=770000
# 780000 / 7776214
# ['muy', 'bueno', 'el', 'tlf', 'cumplio', 'mis', 'expectativas', 'tanto', 'del', 'sistema', 'operativo', 'como', 'de', 'las', 'funciones', 'del', 'telefono', 'lo', 'recomiendo']
# it=780000
# 790000 / 7817197
# ['ve', 'bought', 'another', 'kind', 'of', 'cover', 'and', 'if', 'have', 'no', 'luck', 'with', 'this', 'next', 'one', 'll', 'probably', 'just', 'consider', 'not', 'getting', 'slide', 'out', 'keyboard', 'on', 'my', 'next', 'phone']
# it=790000
# 800000 / 7859279
# ['bought', 'them', 'as', 'disposable', 'because', 'was', 'tired', 'of', 'breaking', 'more', 'expensive', 'products']
# it=800000
# 810000 / 7898476
# ['so', 'am', 'very', 'happy', 'with', 'it']
# it=810000
# 820000 / 7937430
# ['great', 'idea', 'and', 'really', 'like', 'the', 'otterbox', 'case', 'but', 'these', 'things', 'shoulf', 'be', 'stronger', 'or', 'designed', 'differently']
# it=820000
# 830000 / 7975871
# ['will', 'not', 'recommend', 'it', 'to', 'anyone']
# it=830000
# 840000 / 8014684
# ['the', 'digitizer', 'arrived', 'very', 'good', 'and', 'it', 'worked', 'perfectly', 'in', 'htc', 'desire', 'am', 'satisfied', 'with', 'the', 'product', 'and', 'recommend', 'it']
# it=840000
# 850000 / 8055068
# ['got', 'this', 'for', 'my', 'brother', 'and', 'he', 'loved', 'it', 'the', 'band', 'fits', 'great', 'around', 'his', 'arm', 'and', 'his', 'smart', 'phone', 'fits', 'perfectly']
# it=850000
# 860000 / 8095871
# ['they', 'function', 'as', 'you', 'would', 'expect']
# it=860000
# 870000 / 8136694
# ['heat', 'generated', 'from', 'the', 'screen', 'help', 'workout', 'the', 'bubbles', 'and', 'streaks', 'formed', 'from', 'the', 'installation', 'process']
# it=870000
# 880000 / 8177036
# ['cheap', 'cons', 'none']
# it=880000
# 890000 / 8216978
# ['it', 'was', 'cool', 'while', 'it', 'lasted', 'but', 'it', 'didnt', 'last', 'long', 'and', 'the', 'tail', 'would', 'not', 'stay', 'on', 'at', 'all']
# it=890000
# 900000 / 8255844
# ['would', 'recommend', 'to', 'family', 'and', 'friends']
# it=900000
# 910000 / 8306509
# ['very', 'good', 'product']
# it=910000
# 920000 / 8347262
# ['would', 'definitely', 'recommend']
# it=920000
# 930000 / 8384479
# ['all', 'came', 'as', 'it', 'shows', 'no', 'problems', 'with', 'this', 'and', 'works', 'fine', 'easy', 'to', 'install', 'and', 'no', 'need', 'to', 'purchase', 'the', 'tape', 'because', 'its', 'already', 'attached', 'the', 'glass', 'and', 'the', 'lcd']
# it=930000
# 940000 / 8422500
# ['you', 'can', 'slide', 'it', 'into', 'pocket', 'but', 'if', 'you', 'like', 'the', 'otter', 'boxes', 'you', 'll', 'love', 'this', 'because', 'it', 'not', 'as', 'large', 'but', 'protects', 'just', 'as', 'well']
# it=940000
# 950000 / 8465279
# ['it', 'works', 'really', 'well']
# it=950000
# 960000 / 8498392
# ['it', 'sturdy', 'and', 'connects', 'to', 'the', 'ipad', 'headphone', 'connector', 'to', 'keep', 'track', 'of', 'it']
# it=960000
# 970000 / 8534950
# ['he', 'says', 'they', 'are', 'the', 'best', 'value', 'for', 'money', 'in', 'the', 'market', 'and', 'he', 'has', 'done', 'his', 'research']
# it=970000
# 980000 / 8577073
# ['thanks', 'amazon']
# it=980000
# 990000 / 8616290
# []
# it=990000
# 1000000 / 8656572
# ['so', 'it', 'was', 'waste', 'of', 'money']
# it=0
# 10000 / 8692888
# ['like', 'my', 'product', 'but', 'delivery', 'was', 'terrible', 'they', 'just', 'throw', 'my', 'package', 'on', 'the', 'steps', 'will', 'never', 'want', 'any', 'of', 'my', 'packages', 'coming', 'from', 'them', 'try', 'not', 'to', 'use', 'prestige', 'delivery']
# it=10000
# 20000 / 8751002
# ['the', 'only', 'complaint', 'have', 'is', 'it', 'could', 'be', 'louder', 'but', 'it', 'serves', 'my', 'purpose']
# it=20000
# 30000 / 8803212
# ['but', 'the', 'first', 'two', 'issues', 'are', 'reasons', 'would', 'not', 'recommend', 'these', 'even', 'if', 'the', 'malfunction', 'is', 'just', 'bad', 'unit']
# it=30000
# 40000 / 8854440
# ['excellent', 'and', 'about', 'time']
# it=40000
# 50000 / 8911560
# ['thanks']
# it=50000
# 60000 / 8964571
# ['the', 'clip', 'itself', 'is', 'sturdy', 'buy', 'find', 'that', 'it', 'does', 'not', 'open', 'as', 'far', 'as', 'like', 'it', 'to']
# it=60000
# 70000 / 9010146
# ['had', 'hard', 'time', 'finding', 'one', 'but', 'it', 'was', 'worth', 'the', 'wait']
# it=70000
# 80000 / 9056916
# ['quality', 'seems', 'ok', 'no', 'problems', 'so', 'far']
# it=80000
# 90000 / 9103809
# ['still', 'worth', 'the', 'price', 'for', 'the', 'protection']
# it=90000
# 100000 / 9149408
# ['it', 'even', 'comes', 'with', 'miniature', 'clip', 'that', 'can', 'be', 'used', 'to', 'tie', 'up', 'the', 'extra', 'slack', 'which', 'happens', 'all', 'the', 'time', 'to', 'me', 'while', 'driving', 'go', 'ahead', 'and', 'grab', 'one', 'you', 'won', 'be', 'disappointed']
# it=100000
# 110000 / 9193878
# ['ie', 'sometimes', 'when', 'grab', 'for', 'the', 'phone', 'pull', 'it', 'out', 'of', 'the', 'case', 'rather', 'than', 'pull', 'the', 'case', 'too']
# it=110000
# 120000 / 9241146
# ['it', 'makes', 'my', 'calendar', 'activities', 'easy', 'to', 'keep', 'up', 'with', 'keeps', 'me', 'in', 'touch', 'via', 'email', 'and', 'can', 'use', 'it', 'as', 'an', 'external', 'hdd']
# it=120000
# 130000 / 9290852
# ['haven', 'done', 'this', 'yet', 'as', 'family', 'medical', 'emergency', 'took', 'priority']
# it=130000
# 140000 / 9331565
# ['the', 'cable', 'worked', 'fine', 'at', 'first', 'but', 'within', 'two', 'weeks', 'it', 'came', 'loose', 'and', 'stopped', 'working', 'the', 'white', 'tube', 'covering', 'the', 'wires', 'was', 'already', 'loose', 'when', 'it', 'arrived', 'then', 'it', 'completely', 'opened', 'and', 'broke']
# it=140000
# 150000 / 9375616
# ['thanks', 'again']
# it=150000
# 160000 / 9423384
# ['right', 'handed', 'like', 'the', 'design', 'so', 'much', 'll', 'still', 'buy', 'another']
# it=160000
# 170000 / 9470114
# ['it', 'seems', 'to', 'be', 'more', 'scratch', 'resistant', 'or', 'atleast', 'hides', 'the', 'scratches', 'better']
# it=170000
# 180000 / 9517646
# ['the', 'last', 'unit', 'only', 'lasted', 'months']
# it=180000
# 190000 / 9566178
# ['looking', 'for', 'replacement', 'earpiece', 'now']
# it=190000
# 200000 / 9612409
# ['my', 'sons', 'now', 'have', 'my', 'wife', 'and', 'my', 'old', 'iphone', 'gs', 'and', 'they', 'have', 'the', 'otterbox', 'defender', 'on', 'them', 'lot', 'of', 'you', 'out', 'there', 'while', 'know', 'why', 'some', 'may', 'even', 'find', 'out', 'later', 'what', 'great', 'case', 'this', 'is', 'with', 'kids', 'always', 'wanting', 'to', 'borrow', 'the', 'phone', 'trust', 'me', 'buy', 'any', 'otterbox', 'case', 'they', 'are', 'well', 'worth', 'the', 'money']
# it=200000
# 210000 / 9656100
# ['oh', 'well']
# it=210000
# 220000 / 9702570
# ['these', 'are', 'brand', 'new', 'and', 'are', 'working', 'like', 'charm']
# it=220000
# 230000 / 9741755
# ['my', 'phone', 'is', 'new', 'again']
# it=230000
# 240000 / 9784040
# ['would', 'not', 'recommend']
# it=240000
# 250000 / 9830942
# ['do', 'not', 'recommend', 'this', 'phone', 'this', 'phone', 'sucks', 'version', 'spanish', 'no', 'le', 'compres', 'este', 'telefono', 'al', 'vendedor', 'yo', 'se', 'lo', 'compre', 'porque', 'me', 'parecio', 'que', 'su', 'dise', 'ntilde', 'era', 'muy', 'lindo', 'femenino', 'ademas', 'yo', 'amo', 'los', 'blackberrys', 'recientemente', 'tuve', 'uno', 'el', 'vendedor', 'me', 'envio', 'el', 'telefono', 'con', 'una', 'bateria', 'erronea', 'no', 'encendia', 'cuando', 'lo', 'recibi', 'luego', 'yo', 'compre', 'la', 'bateria', 'adecuada', 'me', 'encendio', 'sin', 'problemas', 'pero', 'cuando', 'intente', 'activar', 'el', 'servicio', 'bis', 'de', 'blackberry', 'el', 'telefono', 'nunca', 'levanto', 'la', 'se', 'ntilde', 'al', 'en', 'edge', 'yo', 'se', 'lo', 'comente', 'al', 'vendedor', 'el', 'me', 'dijo', 'que', 'si', 'quitaba', 'el', 'comentario', 'negativo', 'que', 'hice', 'hacia', 'el', 'el', 'me', 'resolveria', 'el', 'problema', 'hasta', 'me', 'enviaria', 'una', 'bateria', 'nueva', 'pero', 'no', 'fue', 'asi', 'una', 'vez', 'que', 'quite', 'el', 'comentario', 'pocas', 'veces', 'me', 'respondio', 'no', 'resolvio', 'mi', 'problema', 'solo', 'me', 'dijo', 'que', 'tenia', 'que', 'enviar', 'el', 'telefono', 'estados', 'unidos', 'yo', 'soy', 'de', 'venezuela', 'enviarlo', 'estados', 'unidos', 'me', 'saldria', 'muy', 'costoso', 'por', 'lo', 'cual', 'solo', 'le', 'dije', 'que', 'se', 'encargara', 'de', 'liberar', 'el', 'imei', 'del', 'telefono', 'cosa', 'que', 'tampoco', 'hizo', 'fui', 'estafada', 'robada', 'por', 'este', 'vendedor', 'realmente', 'quitando', 'todo', 'eso', 'las', 'caracteristicas', 'del', 'telefono', 'son', 'muy', 'pobres', 'la', 'camara', 'es', 'malisima', 'tiene', 'mal', 'enfoque', 'de', 'lejos', 'el', 'sonido', 'es', 'bueno', 'pero', 'de', 'resto', 'es', 'un', 'telefono', 'inservible', 'no', 'recomiendo', 'este', 'telefono', 'mucho', 'menos', 'para', 'la', 'gente', 'latina', 'ya', 'que', 'se', 'nos', 'hace', 'imposible', 'hacer', 'cubrir', 'la', 'garantia', 'este', 'es', 'el', 'unico', 'modelo', 'que', 'no', 'se', 'puede', 'reparar', 'odio', 'este', 'telefono', 'es', 'la', 'peor', 'compra', 'que', 'he', 'hecho', 'en', 'amazon']
# it=250000
# 260000 / 9880757
# ['works', 'fine', 'now', 'just', 'kind', 'of', 'long', 'wait', 'to', 'get', 'it']
# it=260000
# 270000 / 9923755
# ['it', 'installed', 'easily', 'and', 'didn', 'give', 'it', 'second', 'thought', 'until', 'now']
# it=270000
# 280000 / 9969879
# ['thank', 'you', 'very', 'much']
# it=280000
# 290000 / 10011746
# ['dont', 'know', 'how', 'it', 'works', 'on', 'cases', 'as', 'just', 'carry', 'mine', 'in', 'my', 'pocket', 'but', 'the', 'larger', 'battery', 'does', 'slightly', 'increase', 'the', 'width', 'of', 'the', 'phone']
# it=290000
# 300000 / 10053955
# ['works']
# it=300000
# 310000 / 10097795
# ['of', 'course', 'this', 'doesn', 'offer', 'the', 'most', 'protection', 'but', 'it', 'does', 'offer', 'some', 'and', 'it', 'made', 'little', 'boy', 'very', 'happy']
# it=310000
# 320000 / 10145042
# ['although', 'great', 'concept', 'with', 'good', 'combination', 'of', 'features', 'the', 'samsung', 'flight', 'barely', 'coasts', 'in', 'performance', 'and', 'usability', 'for', 'the', 'full', 'review', 'go', 'to']
# it=320000
# 330000 / 10191628
# ['very', 'pleased']
# it=330000
# 340000 / 10236303
# ['bought', 'in', 'july', 'this', 'year', 'and', 'am', 'buying', 'one', 'more', 'for', 'our', 'other', 'car', 'because', 'it', 'is', 'great', 'if', 'you', 'use', 'the', 'voice', 'dial', 'you', 'just', 'need', 'to', 'press', 'button', 'to', 'make', 'any', 'call', 'and', 'when', 'you', 'receive', 'one', 'call', 'it', 'informs', 'you', 'from', 'what', 'number', 'they', 'are', 'calling', 'you', 'by', 'voice', 'also', 'tried', 'the', 'fm', 'transmitter', 'and', 'it', 'works', 'great', 'with', 'the', 'plus', 'that', 'if', 'call', 'comes', 'it', 'pauses', 'the', 'music', 'so', 'you', 'do', 'not', 'have', 'to', 'turn', 'off', 'your', 'radio', 'it', 'is', 'easy', 'to', 'operate', 'will', 'probably', 'buy', 'third', 'one', 'for', 'my', 'father']
# it=340000
# 350000 / 10278239
# ['saved', 'ton', 'of', 'money', 'by', 'purchasing', 'this', 'package', 'verses', 'buying', 'from', 'local', 'retail', 'or', 'cell', 'phone', 'store']
# it=350000
# 360000 / 10320148
# ['it', 'was', 'cheap', 'and', 'would', 'have', 'cost', 'to', 'much', 'to', 'return', 'it']
# it=360000
# 370000 / 10362614
# ['headphones', 'sound', 'surprisingly', 'better', 'than', 'was', 'expecting', 'for', 'such', 'low', 'price', 'have', 'motorola', 'droid', 'and', 'it', 'works', 'perfectly', 'you', 'can', 'also', 'skip', 'songs', 'by', 'pressing', 'the', 'button', 'on', 'the', 'microphone', 'when', 'you', 're', 'listening', 'to', 'music', 'friends', 'say', 'microphone', 'sounds', 'bit', 'tin', 'canny', 'but', 'they', 'can', 'understand', 'me', 'just', 'fine', 'it', 'not', 'problem', 'can', 'say', 'yet', 'how', 'long', 'they', 're', 'going', 'to', 'last', 'without', 'breaking', 'happy', 'so', 'far']
# it=370000
# 380000 / 10403959
# ['find', 'that', 'sometimes', 'products', 'like', 'this', 'made', 'in', 'china', 'lack', 'quality', 'control', 'so', 'some', 'are', 'good', 'and', 'others', 'not', 'so', 'much']
# it=380000
# 390000 / 10455495
# ['it', 'performs', 'exactly', 'as', 'it', 'should', 'and', 'holds', 'an', 'excellent', 'charge', 'for', 'as', 'long', 'or', 'longer', 'than', 'the', 'original']
# it=390000
# 400000 / 10497892
# ['its', 'cant', 'beat', 'it']
# it=400000
# 410000 / 10536782
# ['highly', 'recommend']
# it=410000
# 420000 / 10584548
# ['would', 'suggest', 'this', 'item', 'and', 'would', 'buy', 'again']
# it=420000
# 430000 / 10626765
# ['would', 'recommend', 'and', 'wish', 'could', 'find', 'for', 'my', 'note', 'ii']
# it=430000
# 440000 / 10672174
# ['at', 'the', 'price', 'of', 'this', 'is', 'great', 'case']
# it=440000
# 450000 / 10715123
# ['did', 'not', 'work', 'in', 'my', 'car', 'could', 'not', 'get', 'it', 'to', 'power', 'up', 'at', 'all', 'do', 'not', 'buy', 'this', 'product']
# it=450000
# 460000 / 10751646
# ['hope', 'someone', 'else', 'has', 'better', 'luck', 'with', 'this', 'thing', 'than', 'did']
# it=460000
# 470000 / 10792913
# ['great', 'case', 'great', 'price']
# it=470000
# 480000 / 10838588
# ['still', 'working', 'great', 'months', 'later']
# it=480000
# 490000 / 10879760
# ['pode', 'comprar']
# it=490000
# 500000 / 10919243
# ['the', 'headphones', 'have', 'great', 'fit', 'sound', 'clear', 'so', 'for', 'listening', 'to', 'music', 'it', 'is', 'nice', 'buy', 'liked', 'it']
# it=500000
# 510000 / 10961626
# ['would', 'suggest', 'that', 'you', 'not', 'buy', 'this', 'item']
# it=510000
# 520000 / 11002613
# ['do', 'not', 'have', 'to', 'worry', 'about', 'carrying', 'an', 'outlet', 'adapter', 'with', 'me', 'and', 'get', 'full', 'charges', 'to', 'both', 'my', 'ipad', 'and', 'iphone', 'at', 'the', 'same', 'time', 'great', 'safety', 'backup', 'battery', 'to', 'have', 'for', 'any', 'reason']
# it=520000
# 530000 / 11057630
# ['liked', 'the', 'phone']
# it=530000
# 540000 / 11100099
# ['co', 'worker', 'saw', 'mine', 'and', 'was', 'impressed', 'enough', 'to', 'buy', 'one', 'also']
# it=540000
# 550000 / 11145208
# ['bought', 'something', 'else', 'at', 'another', 'store']
# it=550000
# 560000 / 11186813
# ['love', 'it', 'because', 'it', 'was', 'in', 'expensive']
# it=560000
# 570000 / 11224235
# ['also', 'this', 'review', 'had', 'to', 'be', 'letters', 'long']
# it=570000
# 580000 / 11266648
# ['this', 'one', 'the', 'light', 'just', 'turns', 'off', 'but', 'at', 'least', 'it', 'holds', 'charge', 'all', 'day', 'without', 'dying', 'or', 'needing', 'to', 'be', 'plugged', 'in', 'again']
# it=580000
# 590000 / 11311735
# ['highly', 'recommend', 'it']
# it=590000
# 600000 / 11352033
# ['you', 'll', 'need', 'decent', 'micro', 'tool', 'set', 'to', 'get', 'the', 'job', 'done', 'right']
# it=600000
# 610000 / 11394810
# ['nice', 'item', 'and', 'used', 'often']
# it=610000
# 620000 / 11436332
# ['we', 'got', 'black', 'case', 'for', 'my', 'husband', 'phone', 'it', 'arrived', 'fine', 'and', 'we', 'like', 'them', 'both']
# it=620000
# 630000 / 11481483
# ['had', 'little', 'difficulty', 'with', 'peeling', 'the', 'screen', 'protector', 'from', 'the', 'paper', 'and', 'keeping', 'my', 'finger', 'prints', 'off', 'the', 'inside', 'trying', 'to', 'place', 'it', 'on', 'the', 'phone', 'correctly', 'but', 'other', 'than', 'that', 'found', 'this', 'to', 'be', 'great', 'product']
# it=630000
# 640000 / 11521562
# ['everyone', 'thinks', 'got', 'an', 'iphone', 'because', 'it', 'has', 'its', 'similarities', 'but', 'dont', 'want', 'an', 'iphone', 'for', 'reason', 'pros', 'love', 'all', 'the', 'featuressmall', 'cutecons', 'drains', 'battery', 'fast', 'most', 'androids', 'do']
# it=640000
# 650000 / 11564103
# ['so', 'if', 'you', 'have', 'the', 'normal', 'tab', 'recommend', 'this']
# it=650000
# 660000 / 11604590
# ...
# it=130000
# 140000 / 22316429
# ['the', 'cable', 'worked', 'fine', 'at', 'first', 'but', 'within', 'two', 'weeks', 'it', 'came', 'loose', 'and', 'stopped', 'working', 'the', 'white', 'tube', 'covering', 'the', 'wires', 'was', 'already', 'loose', 'when', 'it', 'arrived', 'then', 'it', 'completely', 'opened', 'and', 'broke']
# it=140000
# 150000 / 22360480
# ['thanks', 'again']
# it=150000
# 160000 / 22408248
# ['right', 'handed', 'like', 'the', 'design', 'so', 'much', 'll', 'still', 'buy', 'another']
# it=160000
# 170000 / 22454978
# ['it', 'seems', 'to', 'be', 'more', 'scratch', 'resistant', 'or', 'atleast', 'hides', 'the', 'scratches', 'better']
# it=170000
# 180000 / 22502510
# ['the', 'last', 'unit', 'only', 'lasted', 'months']
# it=180000
# 190000 / 22551042
# ['looking', 'for', 'replacement', 'earpiece', 'now']
# it=190000
# 200000 / 22597273
# ['my', 'sons', 'now', 'have', 'my', 'wife', 'and', 'my', 'old', 'iphone', 'gs', 'and', 'they', 'have', 'the', 'otterbox', 'defender', 'on', 'them', 'lot', 'of', 'you', 'out', 'there', 'while', 'know', 'why', 'some', 'may', 'even', 'find', 'out', 'later', 'what', 'great', 'case', 'this', 'is', 'with', 'kids', 'always', 'wanting', 'to', 'borrow', 'the', 'phone', 'trust', 'me', 'buy', 'any', 'otterbox', 'case', 'they', 'are', 'well', 'worth', 'the', 'money']
# it=200000
# 210000 / 22640964
# ['oh', 'well']
# it=210000
# 220000 / 22687434
# ['these', 'are', 'brand', 'new', 'and', 'are', 'working', 'like', 'charm']
# it=220000
# 230000 / 22726619
# ['my', 'phone', 'is', 'new', 'again']
# it=230000
# 240000 / 22768904
# ['would', 'not', 'recommend']
# it=240000
# 250000 / 22815806
# ['do', 'not', 'recommend', 'this', 'phone', 'this', 'phone', 'sucks', 'version', 'spanish', 'no', 'le', 'compres', 'este', 'telefono', 'al', 'vendedor', 'yo', 'se', 'lo', 'compre', 'porque', 'me', 'parecio', 'que', 'su', 'dise', 'ntilde', 'era', 'muy', 'lindo', 'femenino', 'ademas', 'yo', 'amo', 'los', 'blackberrys', 'recientemente', 'tuve', 'uno', 'el', 'vendedor', 'me', 'envio', 'el', 'telefono', 'con', 'una', 'bateria', 'erronea', 'no', 'encendia', 'cuando', 'lo', 'recibi', 'luego', 'yo', 'compre', 'la', 'bateria', 'adecuada', 'me', 'encendio', 'sin', 'problemas', 'pero', 'cuando', 'intente', 'activar', 'el', 'servicio', 'bis', 'de', 'blackberry', 'el', 'telefono', 'nunca', 'levanto', 'la', 'se', 'ntilde', 'al', 'en', 'edge', 'yo', 'se', 'lo', 'comente', 'al', 'vendedor', 'el', 'me', 'dijo', 'que', 'si', 'quitaba', 'el', 'comentario', 'negativo', 'que', 'hice', 'hacia', 'el', 'el', 'me', 'resolveria', 'el', 'problema', 'hasta', 'me', 'enviaria', 'una', 'bateria', 'nueva', 'pero', 'no', 'fue', 'asi', 'una', 'vez', 'que', 'quite', 'el', 'comentario', 'pocas', 'veces', 'me', 'respondio', 'no', 'resolvio', 'mi', 'problema', 'solo', 'me', 'dijo', 'que', 'tenia', 'que', 'enviar', 'el', 'telefono', 'estados', 'unidos', 'yo', 'soy', 'de', 'venezuela', 'enviarlo', 'estados', 'unidos', 'me', 'saldria', 'muy', 'costoso', 'por', 'lo', 'cual', 'solo', 'le', 'dije', 'que', 'se', 'encargara', 'de', 'liberar', 'el', 'imei', 'del', 'telefono', 'cosa', 'que', 'tampoco', 'hizo', 'fui', 'estafada', 'robada', 'por', 'este', 'vendedor', 'realmente', 'quitando', 'todo', 'eso', 'las', 'caracteristicas', 'del', 'telefono', 'son', 'muy', 'pobres', 'la', 'camara', 'es', 'malisima', 'tiene', 'mal', 'enfoque', 'de', 'lejos', 'el', 'sonido', 'es', 'bueno', 'pero', 'de', 'resto', 'es', 'un', 'telefono', 'inservible', 'no', 'recomiendo', 'este', 'telefono', 'mucho', 'menos', 'para', 'la', 'gente', 'latina', 'ya', 'que', 'se', 'nos', 'hace', 'imposible', 'hacer', 'cubrir', 'la', 'garantia', 'este', 'es', 'el', 'unico', 'modelo', 'que', 'no', 'se', 'puede', 'reparar', 'odio', 'este', 'telefono', 'es', 'la', 'peor', 'compra', 'que', 'he', 'hecho', 'en', 'amazon']
# it=250000
# 260000 / 22865621
# ['works', 'fine', 'now', 'just', 'kind', 'of', 'long', 'wait', 'to', 'get', 'it']
# it=260000
# 270000 / 22908619
# ['it', 'installed', 'easily', 'and', 'didn', 'give', 'it', 'second', 'thought', 'until', 'now']
# it=270000
# 280000 / 22954743
# ['thank', 'you', 'very', 'much']
# it=280000
# 290000 / 22996610
# ['dont', 'know', 'how', 'it', 'works', 'on', 'cases', 'as', 'just', 'carry', 'mine', 'in', 'my', 'pocket', 'but', 'the', 'larger', 'battery', 'does', 'slightly', 'increase', 'the', 'width', 'of', 'the', 'phone']
# it=290000
# 300000 / 23038819
# ['works']
# it=300000
# 310000 / 23082659
# ['of', 'course', 'this', 'doesn', 'offer', 'the', 'most', 'protection', 'but', 'it', 'does', 'offer', 'some', 'and', 'it', 'made', 'little', 'boy', 'very', 'happy']
# it=310000
# 320000 / 23129906
# ['although', 'great', 'concept', 'with', 'good', 'combination', 'of', 'features', 'the', 'samsung', 'flight', 'barely', 'coasts', 'in', 'performance', 'and', 'usability', 'for', 'the', 'full', 'review', 'go', 'to']
# it=320000
# 330000 / 23176492
# ['very', 'pleased']
# it=330000
# 340000 / 23221167
# ['bought', 'in', 'july', 'this', 'year', 'and', 'am', 'buying', 'one', 'more', 'for', 'our', 'other', 'car', 'because', 'it', 'is', 'great', 'if', 'you', 'use', 'the', 'voice', 'dial', 'you', 'just', 'need', 'to', 'press', 'button', 'to', 'make', 'any', 'call', 'and', 'when', 'you', 'receive', 'one', 'call', 'it', 'informs', 'you', 'from', 'what', 'number', 'they', 'are', 'calling', 'you', 'by', 'voice', 'also', 'tried', 'the', 'fm', 'transmitter', 'and', 'it', 'works', 'great', 'with', 'the', 'plus', 'that', 'if', 'call', 'comes', 'it', 'pauses', 'the', 'music', 'so', 'you', 'do', 'not', 'have', 'to', 'turn', 'off', 'your', 'radio', 'it', 'is', 'easy', 'to', 'operate', 'will', 'probably', 'buy', 'third', 'one', 'for', 'my', 'father']
# it=340000
# 350000 / 23263103
# ['saved', 'ton', 'of', 'money', 'by', 'purchasing', 'this', 'package', 'verses', 'buying', 'from', 'local', 'retail', 'or', 'cell', 'phone', 'store']
# it=350000
# 360000 / 23305012
# ['it', 'was', 'cheap', 'and', 'would', 'have', 'cost', 'to', 'much', 'to', 'return', 'it']
# it=360000
# 370000 / 23347478
# ['headphones', 'sound', 'surprisingly', 'better', 'than', 'was', 'expecting', 'for', 'such', 'low', 'price', 'have', 'motorola', 'droid', 'and', 'it', 'works', 'perfectly', 'you', 'can', 'also', 'skip', 'songs', 'by', 'pressing', 'the', 'button', 'on', 'the', 'microphone', 'when', 'you', 're', 'listening', 'to', 'music', 'friends', 'say', 'microphone', 'sounds', 'bit', 'tin', 'canny', 'but', 'they', 'can', 'understand', 'me', 'just', 'fine', 'it', 'not', 'problem', 'can', 'say', 'yet', 'how', 'long', 'they', 're', 'going', 'to', 'last', 'without', 'breaking', 'happy', 'so', 'far']
# it=370000
# 380000 / 23388823
# ['find', 'that', 'sometimes', 'products', 'like', 'this', 'made', 'in', 'china', 'lack', 'quality', 'control', 'so', 'some', 'are', 'good', 'and', 'others', 'not', 'so', 'much']
# it=380000
# 390000 / 23440359
# ['it', 'performs', 'exactly', 'as', 'it', 'should', 'and', 'holds', 'an', 'excellent', 'charge', 'for', 'as', 'long', 'or', 'longer', 'than', 'the', 'original']
# it=390000
# 400000 / 23482756
# ['its', 'cant', 'beat', 'it']
# it=400000
# 410000 / 23521646
# ['highly', 'recommend']
# it=410000
# 420000 / 23569412
# ['would', 'suggest', 'this', 'item', 'and', 'would', 'buy', 'again']
# it=420000
# 430000 / 23611629
# ['would', 'recommend', 'and', 'wish', 'could', 'find', 'for', 'my', 'note', 'ii']
# it=430000
# 440000 / 23657038
# ['at', 'the', 'price', 'of', 'this', 'is', 'great', 'case']
# it=440000
# 450000 / 23699987
# ['did', 'not', 'work', 'in', 'my', 'car', 'could', 'not', 'get', 'it', 'to', 'power', 'up', 'at', 'all', 'do', 'not', 'buy', 'this', 'product']
# it=450000
# 460000 / 23736510
# ['hope', 'someone', 'else', 'has', 'better', 'luck', 'with', 'this', 'thing', 'than', 'did']
# it=460000
# 470000 / 23777777
# ['great', 'case', 'great', 'price']
# it=470000
# 480000 / 23823452
# ['still', 'working', 'great', 'months', 'later']
# it=480000
# 490000 / 23864624
# ['pode', 'comprar']
# it=490000
# 500000 / 23904107
# ['the', 'headphones', 'have', 'great', 'fit', 'sound', 'clear', 'so', 'for', 'listening', 'to', 'music', 'it', 'is', 'nice', 'buy', 'liked', 'it']
# it=500000
# 510000 / 23946490
# ['would', 'suggest', 'that', 'you', 'not', 'buy', 'this', 'item']
# it=510000
# 520000 / 23987477
# ['do', 'not', 'have', 'to', 'worry', 'about', 'carrying', 'an', 'outlet', 'adapter', 'with', 'me', 'and', 'get', 'full', 'charges', 'to', 'both', 'my', 'ipad', 'and', 'iphone', 'at', 'the', 'same', 'time', 'great', 'safety', 'backup', 'battery', 'to', 'have', 'for', 'any', 'reason']
# it=520000
# 530000 / 24042494
# ['liked', 'the', 'phone']
# it=530000
# 540000 / 24084963
# ['co', 'worker', 'saw', 'mine', 'and', 'was', 'impressed', 'enough', 'to', 'buy', 'one', 'also']
# it=540000
# 550000 / 24130072
# ['bought', 'something', 'else', 'at', 'another', 'store']
# it=550000
# 560000 / 24171677
# ['love', 'it', 'because', 'it', 'was', 'in', 'expensive']
# it=560000
# 570000 / 24209099
# ['also', 'this', 'review', 'had', 'to', 'be', 'letters', 'long']
# it=570000
# 580000 / 24251512
# ['this', 'one', 'the', 'light', 'just', 'turns', 'off', 'but', 'at', 'least', 'it', 'holds', 'charge', 'all', 'day', 'without', 'dying', 'or', 'needing', 'to', 'be', 'plugged', 'in', 'again']
# it=580000
# 590000 / 24296599
# ['highly', 'recommend', 'it']
# it=590000
# 600000 / 24336897
# ['you', 'll', 'need', 'decent', 'micro', 'tool', 'set', 'to', 'get', 'the', 'job', 'done', 'right']
# it=600000
# 610000 / 24379674
# ['nice', 'item', 'and', 'used', 'often']
# it=610000
# 620000 / 24421196
# ['we', 'got', 'black', 'case', 'for', 'my', 'husband', 'phone', 'it', 'arrived', 'fine', 'and', 'we', 'like', 'them', 'both']
# it=620000
# 630000 / 24466347
# ['had', 'little', 'difficulty', 'with', 'peeling', 'the', 'screen', 'protector', 'from', 'the', 'paper', 'and', 'keeping', 'my', 'finger', 'prints', 'off', 'the', 'inside', 'trying', 'to', 'place', 'it', 'on', 'the', 'phone', 'correctly', 'but', 'other', 'than', 'that', 'found', 'this', 'to', 'be', 'great', 'product']
# it=630000
# 640000 / 24506426
# ['everyone', 'thinks', 'got', 'an', 'iphone', 'because', 'it', 'has', 'its', 'similarities', 'but', 'dont', 'want', 'an', 'iphone', 'for', 'reason', 'pros', 'love', 'all', 'the', 'featuressmall', 'cutecons', 'drains', 'battery', 'fast', 'most', 'androids', 'do']
# it=640000
# 650000 / 24548967
# ['so', 'if', 'you', 'have', 'the', 'normal', 'tab', 'recommend', 'this']
# it=650000
# 660000 / 24589454
# ['get', 'hissing', 'sound', 'on', 'my', 'jeep', 'the', 'double', 'tap', 'to', 'skip', 'wont', 'work', 'disappointed', 'rather', 'connect', 'my', 'iphone', 'directly', 'waste', 'of', 'money']
# it=660000
# 670000 / 24628296
# ['glued', 'the', 'face', 'plate', 'on', 'my', 'blackberry', 'which', 'doesn', 'concern', 'me', 'much', 'either', 'considering', 'the', 'box', 'will', 'probably', 'outlast', 'the', 'phone']
# it=670000
# 680000 / 24674325
# ['my', 'whole', 'family', 'use', 'them']
# it=680000
# 690000 / 24714995
# ['then', 'again', 'would', 'really', 'fall', 'in', 'love', 'with', 'it', 'if', 'they', 'did', 'new', 'version', 'for', 'left', 'handed', 'folks', 'like', 'me']
# it=690000
# 700000 / 24755201
# ['this', 'is', 'not', 'cellpnone', 'received', 'another', 'cheaper', 'model', 'this', 'is', 'theft']
# it=700000
# 710000 / 24795576
# ['if', 'you', 'need', 'charger', 'case', 'and', 'data', 'cable', 'for', 'cheap', 'price', 'definitely', 'get', 'this', 'one', 'they', 're', 'not', 'cheap', 'at', 'all', 'high', 'quality', 'in', 'my', 'opinion', 'the', 'only', 'reason', 'didn', 'give', 'it', 'five', 'stars', 'is', 'because', 'the', 'case', 'is', 'kind', 'of', 'snug', 'fit', 'so', 'when', 'sliding', 'the', 'keyboard', 'out', 'and', 'back', 'you', 'kinda', 'feel', 'the', 'resistance', 'but', 'barely', 'noticeable', 'so']
# it=710000
# 720000 / 24834990
# ['had', 'to', 'arrange', 'product', 'return', 'with', 'amazon']
# it=720000
# 730000 / 24871139
# ['comfortable', 'and', 'good', 'sound', 'quality', 'recommended', 'purchase']
# it=730000
# 740000 / 24912217
# ['sleek', 'smooth', 'not', 'bulky', 'and', 'offers', 'very', 'good', 'protection', 'with', 'cushioned', 'liner', 'from', 'accidental', 'drops', 'on', 'hard', 'surfaces']
# it=740000
# 750000 / 24957545
# ['also', 'would', 'fit', 'the', 'htc', 'droid', 'eris', 'they', 'both', 'use', 'the', 'same', 'battery']
# it=750000
# 760000 / 25007246
# ['it', 'good', 'for', 'while', 'but', 'after', 'months', 'start', 'do', 'enlarge', 'the', 'rubber', 'protect', 'very', 'good', 'better', 'not', 'to', 'drop', 'your', 'phone', 'give', 'only', 'stars', 'because', 'it', 'look', 'good', 'but', 'the', 'material', 'not', 'really', 'high', 'quality', 'for', 'the', 'money', 'spend', 'maybe', 'different', 'otter', 'box', 'work', 'better', 'not', 'for', 'iphone', 'really', 'sorry', 'not', 'really', 'happy', 'with', 'this']
# it=760000
# 770000 / 25052155
# ['the', 'otterbox', 'iphone', 'red', 'case', 'is', 'as', 'described', 'with', 'the', 'only', 'possible', 'con', 'being', 'that', 'the', 'tone', 'of', 'red', 'is', 'as', 'other', 'reviews', 'have', 'indicated', 'it', 'is', 'more', 'an', 'off', 'red', 'hint', 'of', 'orange', 'rather', 'than', 'full', 'rich', 'red', 'color']
# it=770000
# 780000 / 25089366
# ['muy', 'bueno', 'el', 'tlf', 'cumplio', 'mis', 'expectativas', 'tanto', 'del', 'sistema', 'operativo', 'como', 'de', 'las', 'funciones', 'del', 'telefono', 'lo', 'recomiendo']
# it=780000
# 790000 / 25130349
# ['ve', 'bought', 'another', 'kind', 'of', 'cover', 'and', 'if', 'have', 'no', 'luck', 'with', 'this', 'next', 'one', 'll', 'probably', 'just', 'consider', 'not', 'getting', 'slide', 'out', 'keyboard', 'on', 'my', 'next', 'phone']
# it=790000
# 800000 / 25172431
# ['bought', 'them', 'as', 'disposable', 'because', 'was', 'tired', 'of', 'breaking', 'more', 'expensive', 'products']
# it=800000
# 810000 / 25211628
# ['so', 'am', 'very', 'happy', 'with', 'it']
# it=810000
# 820000 / 25250582
# ['great', 'idea', 'and', 'really', 'like', 'the', 'otterbox', 'case', 'but', 'these', 'things', 'shoulf', 'be', 'stronger', 'or', 'designed', 'differently']
# it=820000
# 830000 / 25289023
# ['will', 'not', 'recommend', 'it', 'to', 'anyone']
# it=830000
# 840000 / 25327836
# ['the', 'digitizer', 'arrived', 'very', 'good', 'and', 'it', 'worked', 'perfectly', 'in', 'htc', 'desire', 'am', 'satisfied', 'with', 'the', 'product', 'and', 'recommend', 'it']
# it=840000
# 850000 / 25368220
# ['got', 'this', 'for', 'my', 'brother', 'and', 'he', 'loved', 'it', 'the', 'band', 'fits', 'great', 'around', 'his', 'arm', 'and', 'his', 'smart', 'phone', 'fits', 'perfectly']
# it=850000
# 860000 / 25409023
# ['they', 'function', 'as', 'you', 'would', 'expect']
# it=860000
# 870000 / 25449846
# ['heat', 'generated', 'from', 'the', 'screen', 'help', 'workout', 'the', 'bubbles', 'and', 'streaks', 'formed', 'from', 'the', 'installation', 'process']
# it=870000
# 880000 / 25490188
# ['cheap', 'cons', 'none']
# it=880000
# 890000 / 25530130
# ['it', 'was', 'cool', 'while', 'it', 'lasted', 'but', 'it', 'didnt', 'last', 'long', 'and', 'the', 'tail', 'would', 'not', 'stay', 'on', 'at', 'all']
# it=890000
# 900000 / 25568996
# ['would', 'recommend', 'to', 'family', 'and', 'friends']
# it=900000
# 910000 / 25619661
# ['very', 'good', 'product']
# it=910000
# 920000 / 25660414
# ['would', 'definitely', 'recommend']
# it=920000
# 930000 / 25697631
# ['all', 'came', 'as', 'it', 'shows', 'no', 'problems', 'with', 'this', 'and', 'works', 'fine', 'easy', 'to', 'install', 'and', 'no', 'need', 'to', 'purchase', 'the', 'tape', 'because', 'its', 'already', 'attached', 'the', 'glass', 'and', 'the', 'lcd']
# it=930000
# 940000 / 25735652
# ['you', 'can', 'slide', 'it', 'into', 'pocket', 'but', 'if', 'you', 'like', 'the', 'otter', 'boxes', 'you', 'll', 'love', 'this', 'because', 'it', 'not', 'as', 'large', 'but', 'protects', 'just', 'as', 'well']
# it=940000
# 950000 / 25778431
# ['it', 'works', 'really', 'well']
# it=950000
# 960000 / 25811544
# ['it', 'sturdy', 'and', 'connects', 'to', 'the', 'ipad', 'headphone', 'connector', 'to', 'keep', 'track', 'of', 'it']
# it=960000
# 970000 / 25848102
# ['he', 'says', 'they', 'are', 'the', 'best', 'value', 'for', 'money', 'in', 'the', 'market', 'and', 'he', 'has', 'done', 'his', 'research']
# it=970000
# 980000 / 25890225
# ['thanks', 'amazon']
# it=980000
# 990000 / 25929442
# []
# it=990000
# 1000000 / 25969724
# ['so', 'it', 'was', 'waste', 'of', 'money']

# %%
model.save('../../download/myamazonmodel.word2vec')
