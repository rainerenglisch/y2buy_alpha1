# %%
import gensim
model = gensim.models.Doc2Vec.load('../../download/myamazon_doc2vec_model')

# %%
print(model.wv.vocab.keys())
# Out:
# dict_keys(['the', 'case', 'pictured', 'is', 'soft', 'violet', 'color', 'but', 'cover', 'received', 'was', 'dark', 'purple', 'while', 'sure', 'quality', 'of', 'product', 'fine', 'very', 'different', 'saw', 'this', 'same', 'at', 'theme', 'park', 'store', 'for', 'dollars', 'good', 'great', 'price', 'fits', 'perfectly', 'and', 'always', 'gets', 'compliments', 'on', 'it', 'its', 'hasn', 'cracked', 'when', 'dropped', 'wonderful', 'protective', 'best', 'phone', 'ever', 'everywhere', 'go', 'get', 'ton', 'in', 'perfect', 'condition', 'as', 'well', 'may', 'look', 'cute', 'started', 'off', 'pretty', 'first', 'couple', 'weeks', 'then', 'to', 'slide', 'slid', 'one', 'day', 'parking', 'lot', 'fell', 'face', 'down', 'my', 'glass', 'shattered', 'terrible', 'item', 'not', 'sent', 'from', 'blue', 'top', 'company', 'hong', 'kong', 'been', 'over', 'two', 'months', 'will', 'report', 'do', 'use', 'happy', 'all', 'bought', 'wife', 'really', 'hard', 'take', 'considering', 'way', 'too', 'tight', 'put', 'her', 'caused', 'screen', 'protector', 'bubble', 'up', 'thought', 'gonna', 'end', 'breaking', 'trying', 'remove', 'she', 'liked', 'that', 'about', 'came', 'ok', 'there', 'crack', 'left', 'side', 'also', 'slides', 'apart', 'easily', 'pieces', 'fit', 'together', 'slightly', 'no', 'matter', 'how', 'much', 'tried', 'even', 'shaving', 'little', 'wouldn', 'into', 'each', 'other', 'gap', 'you', 'can', 'barley', 'notice', 'bottom', 'has', 'never', 'so', 'deal', 'with', 'got', 'year', 'old', 'sister', 'loves', 'don', 'have', 'any', 'complaints', 'yeah', 'super', 'durable', 'conversation', 'starter', 'delivery', 'before', 'estimated', 'date', 'self', 'made', 'since', 'separate', 'isn', 'snug', 'slip', 'piece', 'paper', 'dripping', 'part', 'if', 'arrives', 'just', 'try', 'using', 'method', 'colors', 'are', 'exactly', 'pictures', 'neat', 'white', 'texture', 'than', 'pink', 'overall', 'stars', 'had', 'glue', 'parts', 'because', 'would', 'come', 'out', 'fall', 'more', 'bland', 'picture', 'extremely', 've', 'atleast', 'ten', 'times', 'clumsy', 'still', 'cracks', 'favorite', 'switcheasy', 'plastic', 'goes', 'front', 'many', 'drops', 'protected', 'cracking', 'ordered', 'birthday', 'present', 'arrived', 'quickly', 'disappointed', 'loose', 'slipped', 'whenever', 'lock', 'didn', 'doesn', 'match', 'worst', 'items', 'see', 'reason', 'sale', 'completely', 'useless', 'within', 'snugly', 'whole', 'does', 'definitely', 'buy', 'again', 'like', 'lower', 'where', 'should', 'snap', 'onto', 'upper', 'comes', 'excited', 'purchase', 'me', 'cloud', 'worrying', 'potentially', 'dropping', 'however', 'sadly', 'worth', 'money', 'invested', 'did', 'sad', 'disneyland', 'upon', 'retrieving', 'right', 'remaining', 'hands', 'iphone', 'hit', 'asphalt', 'middle', 'clearly', 'purchasing', 'huge', 'mistake', 'quick', 'expected', 'easy', 'concrete', 'scratch', 'better', 'an', 'otterbox', 'slips', 'almost', 'broke', 'instead', 'nice', 'details', 'expecting', 'verizon', 'mail', 'barely', 'button', 'holes', 'buttons', 'high', 'another', 'thing', 'melt', 'thingies', 'near', 'fromt', 'canera', 'stuff', 'kept', 'peeling', 'head', 'heels', 'upset', 'beware', 'cool', 'totally', 'order', 'recommend', 'anyone', 'who', 'wants', 'cheap', 'stay', 'waste', 'falling', 'hole', 'camara', 'kind', 'small', 'looking', 'bad', 'fort', 'he', 'took', 'month', 'half', 'be', 'delivered', 'only', 'once', 'melting', 'indent', 'quite', 'annoying', 'after', 'some', 'time', 'sorta', 'grip', 'although', 'mine', 'seems', 'dud', 'place', 'anyway', 'shot', 'street', 'such', 'gotten', 'tons', 'what', 'paid', 'couldn', 'falls', 'complements', 'guess', 'love', 'few', 'years', 'now', 'problems', 'snaps', 'stuck', 'removing', 'amazing', 'wanted', 'extra', 'things', 'didnt', 'know', 'were', 'coming', 'impressed', 'loved', 'combination', 'design', 'showed', 'unfortunately', 'drip', 'portion', 'makes', 'unfortunate', 'click', 'keep', 'wanna', 'risk', 'having', 'giant', 'due', 'doubt', 'going', 'bummer', 'light', 'weight', 'big', 'drawback',  ...

# %%
print(model.most_similar("great"))
# Out:
# [('fantastic', 0.8792886734008789), ('good', 0.8402195572853088), ('wonderful', 0.8278414011001587), ('perfect', 0.8006229400634766), ('awesome', 0.7910783886909485), ('terrific', 0.7773942947387695), ('nice', 0.764876127243042), ('excellent', 0.7603861093521118), ('fabulous', 0.7281359434127808), ('amazing', 0.720199465751648)]

# %% [markdown]
# model.docvecs[10]

# %% [markdown]
# #label = review_item["asin"] + "_" + review_item["reviewerID"] + "_" + str(s_i)
# print(model.most_similar("0110400550_ANG01NK4RXCI9_1"))

# %%
model.infer_vector(['only', 'you', 'can', 'prevent', 'forrest', 'fires'])
# Out:
# array([-0.00993392,  0.08546808, -0.06766386,  0.0345526 , -0.01023685,
#         0.01198716, -0.09724786,  0.04868638, -0.04153052, -0.07577998,
#        -0.04579892, -0.00894399, -0.06802212, -0.08749409, -0.02436841,
#         0.05246739,  0.03501596, -0.0500764 , -0.02587125, -0.01992729,
#         0.0399108 ,  0.02775571, -0.03239815, -0.11803614, -0.01122004,
#         0.08763951, -0.03164814,  0.01439303, -0.03671197,  0.02644717,
#        -0.06794085, -0.01129118,  0.00429168,  0.05182005, -0.04630462,
#         0.04253078, -0.11963835, -0.02973804, -0.03769583,  0.02972791,
#        -0.02810809,  0.01887232, -0.00055521,  0.0182408 ,  0.00060937,
#        -0.00955613,  0.03989339, -0.00405308,  0.09583925, -0.07993392,
#        -0.00885948, -0.04497883, -0.02012692, -0.00314048, -0.09934285,
#        -0.11998561,  0.03602133,  0.00831788,  0.03750511, -0.03442443,
#        -0.12275914,  0.07997653, -0.02380002,  0.02878741, -0.08203089,
#        -0.02013432, -0.07686595, -0.01440959,  0.05890916, -0.00079775,
#        -0.03815589, -0.14197981, -0.08899669,  0.03146737,  0.07227261,
#         0.03938162, -0.02341247,  0.05746921, -0.00199898, -0.00875981,
#         0.05661486,  0.00585735, -0.01526359, -0.02729119,  0.02125123,
#        -0.00658453,  0.06453138,  0.09204796, -0.04489787, -0.07332554,
#        -0.05682164,  0.02463312,  0.00591227,  0.05386467, -0.01491428,
#         0.02103548, -0.03818294,  0.00927415, -0.01200829,  0.01725842], dtype=float32)

# %% [markdown]
# Read 100 sentences from amazon reviews and cluster them into 10 topics

# %%
import json 
import gzip 
def parse(path): 
    g = gzip.open(path, 'r') 
    for l in g: 
        yield eval(l)

# %%
import nltk
import gensim

sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
review_item_iterator = iter(parse("../../download/reviews_Cell_Phones_and_Accessories.json.gz"))

def sentences():
    
    for review_item in review_item_iterator:
#        print(review_item)
#        if "Cell Phones" in review_item["categories"]:
            
        reviewText = review_item["reviewText"]
        for sentence in sent_detector.tokenize(reviewText):
            preprocess_sentence = gensim.utils.simple_preprocess(sentence)
            yield preprocess_sentence

# %% [markdown]
# import nltk
# #from nltk.stem.wordnet import WordNetLemmatizer
# #from nltk import word_tokenize
# #import string
# #from nltk.corpus import stopwords
# import gensim
#
#
# class MySentences():
#     def __init__(self):
#         #self.reviews_cursor = my_amazon_product_reviews.find()
#         self.sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
#         #self.stop = set(stopwords.words('english'))
#         #self.exclude = set(string.punctuation)
#         #self.lemma = WordNetLemmatizer()
#         self.i = 0
#
#
#     def __iter__(self):
#
#         r_i = 0
#         review_item_iterator = iter(parse("../../download/reviews_Cell_Phones_and_Accessories.json.gz"))
#         #for review_item in parse("../../download/reviews_Cell_Phones_and_Accessories.json.gz"):
#         for it in range(1000000):
#             if it%10000==0:
#                 print("it="+str(it))
#             review_item = next(review_item_iterator)
#         #for review_item in self.reviews_cursor:
#             r_i = r_i + 1
#             if r_i%10000==0:
#                 print(str(r_i)+ " / " + str(self.i))
#                 print(preprocess_sentence)
#             reviewText = review_item["reviewText"]
#             s_i = 0
#             for sentence in self.sent_detector.tokenize(reviewText):
#                 self.i = self.i + 1
#                 s_i = s_i + 1
#
#                 #tokens = nltk.word_tokenize(sentence.lower())
#                 #normalized_tokens = [self.lemma.lemmatize(token)
#                 #                     for token in tokens
#                 #                     if token not in self.exclude
#                 #                    ]
#
#                 label = review_item["asin"] + "_" + review_item["reviewerID"] + "_" + str(s_i)
#                 preprocess_sentence = gensim.utils.simple_preprocess(sentence)
#
#                 #yield gensim.models.doc2vec.LabeledSentence(words=normalized_tokens, tags=[label])
#                 yield gensim.models.doc2vec.LabeledSentence(words=preprocess_sentence, tags=[label])

# %%
#sentences = MySentences()
for it in range(10):
    sentence = next(sentences())
    print(" ".join(sentence))
# Out:
# {'reviewerID': 'A1EWN6KZ4HMLT7', 'asin': '011040047X', 'reviewerName': 'S. Prescott', 'helpful': [2, 2], 'reviewText': "The case pictured is a soft violet color, but the case cover I received was a dark purple. While I'm sure the quality of the product is fine, the color is very different.", 'overall': 1.0, 'summary': 'Wrong color', 'unixReviewTime': 1344902400, 'reviewTime': '08 14, 2012'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-4e18423e392e> in <module>()
#       1 #sentences = MySentences()
#       2 for it in range(10):
# ----> 3     sentence = next(sentences())
#       4     print(" ".join(sentence))
#       5
#
# <ipython-input-15-1eebafc56290> in sentences()
#       9     for review_item in review_item_iterator:
#      10         print(review_item)
# ---> 11         if "Cell Phones" in review_item["categories"]:
#      12
#      13             reviewText = review_item["reviewText"]
#
# KeyError: 'categories'

# %%
import numpy as np
cluster_sentences = [next(sentences()) for it in range(10000)]
cluster_sentences_vec = [model.infer_vector(s) for s in cluster_sentences]
#print(sentence_vec)
np_array = np.asarray(cluster_sentences_vec)
print(len(np_array))
# Out:
# 1000

# %%
import nltk
from nltk.cluster.kmeans import KMeansClusterer
nc = 10
data = np_array

kclusterer = KMeansClusterer(nc, distance=nltk.cluster.util.cosine_distance, repeats=25)
assigned_clusters = kclusterer.cluster(data, assign_clusters=True)

# %%
print(assigned_clusters)
np_assigned_clusters = np.asarray(assigned_clusters)
# Out:
# [7, 8, 8, 7, 7, 6, 0, 3, 3, 1, 8, 8, 6, 7, 7, 8, 7, 8, 7, 4, 7, 7, 7, 1, 7, 7, 8, 2, 7, 1, 3, 2, 8, 7, 4, 6, 2, 7, 9, 8, 8, 2, 7, 2, 8, 7, 5, 5, 2, 3, 2, 7, 8, 8, 7, 7, 7, 7, 5, 7, 9, 6, 7, 7, 7, 7, 7, 8, 7, 7, 7, 7, 1, 7, 7, 7, 7, 2, 7, 6, 7, 3, 6, 2, 7, 8, 7, 7, 2, 7, 7, 8, 8, 8, 7, 7, 7, 8, 1, 7, 7, 1, 7, 6, 0, 7, 8, 7, 7, 7, 7, 0, 7, 8, 7, 0, 8, 2, 7, 8, 7, 7, 7, 8, 8, 2, 7, 6, 8, 7, 8, 0, 8, 8, 8, 7, 8, 1, 8, 7, 2, 8, 7, 7, 6, 8, 8, 7, 1, 7, 2, 7, 8, 7, 2, 7, 8, 7, 7, 0, 7, 0, 7, 0, 7, 1, 7, 1, 7, 7, 0, 0, 8, 3, 7, 8, 7, 7, 7, 2, 7, 4, 8, 8, 8, 6, 0, 8, 1, 7, 1, 7, 7, 0, 8, 8, 6, 7, 7, 7, 7, 1, 1, 7, 7, 7, 7, 7, 8, 7, 2, 1, 8, 7, 7, 6, 7, 0, 8, 7, 7, 2, 7, 7, 0, 7, 0, 5, 2, 7, 9, 7, 8, 6, 7, 5, 5, 9, 8, 7, 1, 9, 5, 8, 5, 7, 1, 7, 5, 8, 7, 7, 2, 2, 6, 6, 7, 2, 7, 7, 8, 3, 7, 8, 8, 7, 7, 7, 6, 5, 7, 7, 8, 2, 4, 7, 5, 7, 2, 7, 6, 8, 6, 7, 2, 8, 7, 7, 8, 5, 7, 7, 7, 1, 5, 2, 4, 2, 5, 7, 8, 7, 8, 1, 7, 7, 7, 0, 8, 8, 7, 8, 6, 7, 7, 9, 7, 7, 3, 1, 8, 8, 0, 7, 7, 6, 7, 7, 7, 7, 7, 7, 7, 1, 1, 7, 2, 8, 7, 7, 3, 7, 7, 6, 1, 9, 3, 9, 7, 8, 8, 8, 8, 7, 7, 5, 7, 7, 3, 8, 7, 6, 8, 9, 9, 9, 8, 7, 8, 7, 7, 8, 7, 8, 7, 8, 7, 7, 7, 7, 8, 6, 8, 8, 8, 8, 8, 5, 7, 1, 7, 2, 8, 7, 2, 6, 7, 7, 8, 7, 8, 5, 7, 7, 6, 7, 7, 7, 5, 7, 8, 7, 7, 8, 7, 5, 9, 7, 7, 8, 7, 8, 7, 7, 7, 7, 8, 7, 7, 7, 7, 5, 1, 8, 3, 0, 7, 1, 7, 1, 7, 1, 7, 8, 7, 7, 6, 7, 7, 7, 7, 8, 6, 7, 8, 8, 7, 7, 6, 7, 7, 7, 7, 1, 7, 8, 8, 7, 1, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 0, 7, 7, 7, 7, 6, 7, 2, 7, 7, 7, 2, 5, 2, 7, 7, 7, 7, 1, 8, 5, 7, 6, 7, 6, 7, 2, 7, 9, 2, 8, 7, 7, 7, 7, 7, 7, 9, 7, 7, 9, 7, 7, 7, 5, 7, 2, 7, 8, 4, 5, 9, 7, 1, 7, 2, 6, 5, 7, 6, 7, 7, 7, 7, 2, 6, 7, 6, 2, 8, 2, 7, 7, 7, 7, 7, 2, 7, 7, 7, 5, 7, 7, 6, 1, 7, 7, 7, 7, 7, 7, 1, 7, 7, 7, 7, 7, 7, 7, 7, 8, 7, 7, 6, 1, 2, 7, 5, 7, 7, 7, 4, 0, 7, 2, 7, 7, 7, 6, 9, 7, 5, 7, 6, 7, 6, 2, 7, 9, 6, 5, 2, 7, 6, 7, 5, 7, 8, 7, 7, 5, 2, 7, 5, 3, 7, 3, 5, 7, 6, 7, 6, 7, 9, 7, 1, 7, 9, 1, 8, 9, 7, 7, 4, 7, 9, 7, 8, 5, 4, 9, 7, 7, 7, 7, 7, 7, 7, 7, 9, 8, 8, 4, 5, 1, 7, 7, 7, 7, 8, 7, 1, 4, 8, 7, 7, 7, 7, 1, 7, 7, 1, 1, 7, 7, 5, 1, 7, 5, 8, 7, 8, 7, 2, 7, 7, 7, 8, 8, 1, 7, 7, 2, 8, 7, 6, 7, 7, 1, 4, 7, 3, 4, 6, 4, 7, 8, 2, 5, 1, 5, 7, 7, 7, 7, 7, 7, 7, 7, 5, 9, 6, 8, 6, 9, 1, 5, 8, 2, 9, 7, 2, 7, 7, 9, 5, 6, 5, 6, 7, 7, 6, 7, 7, 7, 7, 7, 2, 5, 7, 7, 7, 7, 7, 8, 5, 1, 3, 7, 5, 6, 7, 7, 7, 9, 7, 7, 8, 2, 2, 6, 7, 6, 7, 7, 8, 7, 7, 7, 7, 7, 7, 7, 7, 8, 7, 6, 7, 2, 5, 2, 7, 4, 5, 5, 5, 7, 7, 1, 6, 9, 8, 6, 5, 7, 1, 7, 0, 9, 7, 7, 2, 8, 0, 7, 6, 7, 0, 7, 3, 7, 8, 8, 7, 7, 8, 7, 7, 7, 7, 7, 5, 7, 0, 7, 8, 7, 7, 7, 6, 6, 7, 5, 7, 6, 7, 0, 7, 2, 6, 4, 7, 6, 7, 7, 7, 7, 7, 1, 7, 6, 8, 7, 7, 7, 4, 7, 7, 8, 4, 7, 6, 1, 2, 7, 7, 8, 8, 8, 7, 6, 6, 7, 7, 7, 7, 7, 8, 6, 7, 1, 7, 7, 7, 8, 7, 7, 7, 7, 8, 7, 7, 8, 7, 7, 8, 7, 6, 6, 7, 2, 7, 7, 1, 2, 1, 6, 7, 7, 6, 7, 7, 7, 7, 6, 2, 7, 7, 7, 7, 8, 7, 6, 8, 7, 1, 7, 1, 7, 2, 7, 1, 7, 2, 7, 7, 7, 7, 7, 7, 1, 6, 8, 7, 7, 7, 8, 7, 7, 1, 6, 8, 7, 8, 1, 8, 7, 8, 7, 1, 1, 7, 7, 7, 7, 7, 6, 7, 8, 9, 6, 7, 8, 0, 1, 7, 8, 8, 7, 8, 6]

# %%
#result = np.vstack((np.asarray(cluster_sentences)[np_assigned_clusters == 1]))
import pandas as pd
cluster_sentences_join = [" ".join(s_list) for s_list in cluster_sentences]
result = pd.DataFrame({ 'cluster' : assigned_clusters,   'sentence' : cluster_sentences_join})
print(result.head())
# Out:
#    cluster                                           sentence
# 0        7  the case is super cute durable and conversatio...
# 1        8  had to super glue the two parts together becau...
# 2        8  this case is extremely durabl ve dropped my ph...
# 3        7     ordered this as birthday present for my sister
# 4        7      ordered this and received it within two weeks

# %%
writer = pd.ExcelWriter('output.xlsx')
result.to_excel(writer,'Sheet1')
writer.save()

# %% [markdown]
# for label in range(nc):
# #    print(np.asarray(features)[kmeans.labels_ == label])
#     print(label)
#     print(np.asarray(cluster_sentences)[np_assigned_clusters == label])
