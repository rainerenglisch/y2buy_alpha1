# %% [markdown]
# https://stackoverflow.com/questions/43776572/visualise-word2vec-generated-from-gensim

# %%
import gensim
word2vec_model = "amazon" #"wikipedia" "amazon"

if word2vec_model == "wikipedia":
# Load Google's pre-trained Word2Vec model.
    model = gensim.models.KeyedVectors.load_word2vec_format('../../download/GoogleNews-vectors-negative300.bin', binary=True, limit=400000) 
else:
    model = gensim.models.Word2Vec.load("myamazonmodel")

# %%
similar = model.wv.most_similar_cosmul(positive=[ 'smartphone', "feature"],topn=100)
vocab = [w for (w,s) in similar]
print(vocab)
# Out:
# ['smart-phone', 'smartphones', 'platform', 'capability', 'smart', 'device', 'pedometer', 'pda', 'aps', 'apps', 'gadget', 'productivity', 'option', 'computing', 'webtop', 'system', 'wp7', 'android', 'devise', 'customizations', 'sip', 'pim', 'program', 'natively', 'java', 'optimization', 'tasker', 'non-smartphone', 'o/s', 'multitasking', 'os', 'api', 'navigator', 'firefox', 'linux', 'applet', 'interface', 'blinkfeed', 'multi-media', 'interactive', 'telephony', 'device-', 'speaktoit', 'a2dp', 'app', 'codecs', 'vlingo', 'motoblur', 'maemo', 'enhancement', 'joikuspot', 'web-browsing', 'widget', 'wm', 's60', 'customization', 'apps.the', 'googlemaps', 'midp', 'phablet', 'capabilites', 'smart-phones', 'enabler', 'javascript', 'wp8', 'webos', 'hotspot', 'scheduler', 'peripheral', 'technology', 'wlan', 'exploit', 'motospeak', 'j2me', 'gui', 'accessory', 'pocketpc', 'a-gps', 'voice-dialing', 's-cover', 'qwerty', 'tethering', 'multi-tasking', 'games/apps', 'gamepad', 'apps.i', 'bluetooth', 'codec', 'chipset', 'expandability', 'walkie-talkie', 'flasher', 'o', 'advanced', 'brew', 'phone/text', 'apps.-', 'protocol', 'timescape', 'win8']

# %%
#vocab = list(model.wv.vocab)
X = model[vocab]

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)

# %%
import pandas as pd
df = pd.concat([pd.DataFrame(X_tsne),
                pd.Series(vocab)],
               axis=1)

df.columns = ['x', 'y', 'word']

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.scatter(df['x'], df['y'])

# %%
for i, txt in enumerate(df['word']):
    ax.annotate(txt, (df['x'].iloc[i], df['y'].iloc[i]))

# %% [markdown]
# Then do plt.show() or fig.savefig(). Depending on your data, you'll probably have to mess with ax.set_xlim and ax.set_ylim to see into a dense cloud. This is the newsgroup example without any tweaking:

# %%
plt.show()
