# %%
import gensim
model = gensim.models.Doc2Vec.load('../../download/myamazon_doc2vec_model')

# %%
print(model.wv.vocab.keys())
# Out:
# dict_keys(['the', 'case', 'pictured', 'is', 'a', 'soft', 'violet', 'color', 'but', 'cover', 'i', 'received', 'wa', 'dark', 'purple', 'while', "'m", 'sure', 'quality', 'of', 'product', 'fine', 'very', 'different', 'saw', 'this', 'same', 'at', 'theme', 'park', 'store', 'for', '25', 'dollar', 'good', 'great', 'price', 'fit', 'perfectly', 'and', 'always', 'get', 'compliment', 'on', 'it', 'ha', "n't", 'cracked', 'when', 'dropped', 'wonderful', 'protective', 'best', 'phone', 'ever', 'everywhere', 'go', 'ton', 'in', 'perfect', 'condition', 'well', 'may', 'look', 'cute', 'started', 'off', 'pretty', 'first', 'couple', 'week', 'then', 'to', 'slide', 'slid', 'one', 'day', 'parking', 'lot', 'fell', 'face', 'down', 'my', 'glass', 'shattered', 'terrible', 'item', 'not', 'sent', 'from', 'blue', 'top', 'company', 'hong', 'kong', "'s", 'been', 'over', 'two', 'month', 'will', 'report', 'do', 'use', 'happy', 'all', 'bought', 'wife', 'really', 'hard', 'take', 'considering', 'way', 'too', 'tight', 'put', 'her', 'caused', 'screen', 'protector', 'bubble', 'up', 'thought', 'gon', 'na', 'end', 'breaking', 'trying', 'remove', 'she', 'liked', 'that', 'about', 'came', 'ok', 'there', 'crack', 'left', 'side', 'also', 'apart', 'easily', 'piece', 'together', 'slightly', 'no', 'matter', 'how', 'much', 'tried', 'even', 'shaving', 'little', 'would', 'into', 'each', 'other', 'gap', 'you', 'can', 'barley', 'notice', 'bottom', 'never', 'so', 'deal', 'with', 'got', '14', 'year', 'old', 'sister', 'love', 'have', 'any', 'complaint', 'yeah', 'super', 'durable', 'conversation', 'starter', 'delivery', 'before', 'estimated', 'date', 'self', '2', 'separate', 'snug', 'slip', 'paper', 'dripping', 'part', 'if', 'arrives', 'just', 'try', 'using', 'are', 'exactly', 'picture', 'neat', 'since', 'white', 'texture', 'than', 'pink', '4/5', 'star', 'had', 'glue', 'because', 'come', 'out', 'fall', 'more', 'bland', 'extremely', 'e.', "'ve", 'atleast', 'ten', 'time', 'clumsy', 'still', 'favorite', 'switcheasy', 'plastic', 'front', 'many', 'drop', 'protected', 'cracking', 'ordered', 'birthday', 'present', 'arrived', 'quickly', 'disappointed', 'loose', 'slipped', 'whenever', 'lock', 'did', 'doe', 'match', 'worst', 'see', 'reason', 'sale', 'completely', 'useless', 'within', 'snugly', 'whole', 'definitely', 'buy', 'again', 'like', 'lower', 'where', 'should', 'snap', 'onto', 'upper', 'excited', 'purchase', 'me', 'cloud', '9', 'worrying', 'potentially', 'dropping', 'however', 'sadly', 'worth', 'money', 'invested', 'sad', 'disneyland', 'upon', 'retrieving', 'right', 'remaining', 'hand', 'iphone', 'hit', 'asphalt', 'middle', 'clearly', 'purchasing', 'huge', 'mistake', 'quick', 'expected', 'easy', 'concrete', 'scratch', 'better', 'an', 'otterbox', 'almost', 'broke', 'instead', '...', 'nice', 'detail', 'expecting', 'verizon', '4', 'mail', 'barely', 'button', 'hole', 'high', 'another', 'thing', 'melt', 'thingies', 'near', 'fromt', 'canera', 'stuff', 'kept', 'peeling', 'head', 'heel', 'upset', 'right..', 'beware..', 'cool', '3', 'totally', 'order', 'recommend', 'anyone', 'who', 'want', 'cheap', 'stay', 'waste', 'falling', 'camara', 'kind', 'small', 'looking', 'bad', 'fort', 'he', 'took', 'half', 'be', 'delivered', 'only', 'once', 'melting', 'indent', 'quite', 'annoying', 'after', 'some', 'sorta', 'grip', 'although', 'mine', 'seems', 'dud', 'place', 'anyway', 'shot', 'street', 'such', 'gotten', 'what', 'paid', 'could', 'complement', 'guess', 'few', 'now', 'problem', 'stuck', 'removing', 'amazing', 'wanted', 'extra', 'didnt', 'know', 'were', 'coming', 'impressed', 'loved', 'combination', 'design', 'showed', 'unfortunately', 'drip', 'portion', 'make', 'unfortunate', 'click', 'keep', 'wan', 'risk', 'having', 'giant', 'due', 'doubt', 'going', 'bummer', 'light', 'weight', 'big', 'drawback', 'block', 'wifi', 'signal', 'work', 'am', 'back', 'yard', 'house', 'router', 'living', 'room', 'used', '3g', 'learned', 'improved', 'bar', 'or', 'tested', 'convinced', 'photo', 'scratched', 'flimsy', '8', 'needle', 's ...

# %%
print(model.most_similar("great"))
# Out:
# [('good', 0.8627834916114807), ('fantastic', 0.8539923429489136), ('wonderful', 0.8260943293571472), ('perfect', 0.7886239290237427), ('nice', 0.7666363716125488), ('awesome', 0.7574908137321472), ('terrific', 0.7479586601257324), ('excellent', 0.7325628399848938), ('decent', 0.7073140144348145), ('fabulous', 0.7056616544723511)]

# %%
model.docvecs[10]
# Out:
# array([-0.00389711,  0.03177835, -0.10148595,  0.00623841, -0.01412118,
#         0.00301223, -0.00072138, -0.06939933, -0.00922375, -0.00906138,
#         0.01274887,  0.0436364 ,  0.01243891, -0.01110376, -0.00457976,
#        -0.00561838,  0.02912212,  0.00076354,  0.0358208 ,  0.02809888,
#         0.02201419,  0.02491736, -0.01489113, -0.0123414 ,  0.00918744,
#        -0.04794484,  0.07279362,  0.03511505,  0.01625002, -0.00052628,
#        -0.02790631,  0.00382959, -0.01714755, -0.02376331, -0.07235019,
#         0.01673598,  0.00887846, -0.0140644 , -0.04524854,  0.01696644,
#         0.03575039, -0.00757047,  0.07980016,  0.00143545, -0.01658825,
#         0.01875018,  0.01840384,  0.01195005,  0.04747029,  0.03157228,
#        -0.02081366,  0.03955229,  0.00054426,  0.02871459, -0.039247  ,
#        -0.02150177,  0.00408737, -0.04490192,  0.00637196,  0.00928293,
#        -0.00862893,  0.0274141 ,  0.01455551,  0.03056748,  0.01188036,
#        -0.03975293, -0.05438398, -0.00082905, -0.06335633,  0.03334038,
#         0.00896574,  0.0074907 , -0.03254393, -0.00072887,  0.00214633,
#         0.0090205 , -0.02199842,  0.0311193 ,  0.04176609, -0.00431073,
#        -0.05553202, -0.02865214, -0.02074305, -0.01745981,  0.00719542,
#         0.00266722, -0.04680494, -0.03378016,  0.00298298, -0.01611728,
#         0.02618056, -0.01123402, -0.03145699,  0.05595824, -0.04386693,
#        -0.01116659,  0.03115987, -0.03239355, -0.02901331, -0.00583493], dtype=float32)

# %%
#label = review_item["asin"] + "_" + review_item["reviewerID"] + "_" + str(s_i)
print(model.most_similar("0110400550_ANG01NK4RXCI9_1"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-a8d67f6adb6a> in <module>()
#       1 #label = review_item["asin"] + "_" + review_item["reviewerID"] + "_" + str(s_i)
# ----> 2 print(model.most_similar("0110400550_ANG01NK4RXCI9_1"))
#
# /media/mister/Extension/anaconda3/lib/python3.6/site-packages/gensim/models/word2vec.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#    1237         Refer to the documentation for `gensim.models.KeyedVectors.most_similar`
#    1238         """
# -> 1239         return self.wv.most_similar(positive, negative, topn, restrict_vocab, indexer)
#    1240
#    1241     def wmdistance(self, document1, document2):
#
# /media/mister/Extension/anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     333                 mean.append(weight * word)
#     334             else:
# --> 335                 mean.append(weight * self.word_vec(word, use_norm=True))
#     336                 if word in self.vocab:
#     337                     all_words.add(self.vocab[word].index)
#
# /media/mister/Extension/anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     286                 return self.syn0[self.vocab[word].index]
#     287         else:
# --> 288             raise KeyError("word '%s' not in vocabulary" % word)
#     289
#     290     def most_similar(self, positive=[], negative=[], topn=10, restrict_vocab=None, indexer=None):
#
# KeyError: "word '0110400550_ANG01NK4RXCI9_1' not in vocabulary"

# %%
model.infer_vector(['only', 'you', 'can', 'prevent', 'forrest', 'fires'])
# Out:
# array([ 0.01148677,  0.00974892, -0.03129805, -0.02541509,  0.03375502,
#         0.01739781, -0.0225173 , -0.02790258,  0.02710397, -0.02764737,
#         0.02078649,  0.0144633 ,  0.05260472, -0.00778722,  0.06442109,
#        -0.02214546, -0.02526941, -0.01647141,  0.02111194, -0.12490232,
#        -0.02464427, -0.00815313,  0.02093728,  0.09856375, -0.04851935,
#        -0.05953223,  0.03319296,  0.0039489 ,  0.04332436, -0.0501505 ,
#        -0.06632873,  0.04321746,  0.04598175, -0.06171952, -0.00687202,
#         0.00154023,  0.01058102,  0.01785216, -0.0022744 ,  0.00037962,
#         0.07575189, -0.00906658,  0.01475217,  0.04722477,  0.02745622,
#         0.08145253, -0.06724358,  0.06024912, -0.01911501, -0.02212666,
#        -0.02067514,  0.00096358,  0.02446651, -0.06716246,  0.00129709,
#         0.03064769,  0.08747534, -0.0707948 ,  0.01131219, -0.01435646,
#         0.00149015,  0.052731  , -0.01607771,  0.02453048,  0.03039572,
#        -0.04566304, -0.0387639 , -0.09489872,  0.03590872,  0.05074635,
#        -0.00727585,  0.0188756 ,  0.08643838,  0.00438834,  0.00703611,
#         0.02757008,  0.0116151 ,  0.00432303,  0.00782242, -0.0016186 ,
#         0.03932726,  0.00540788,  0.03851186,  0.01402249,  0.04157016,
#        -0.03794525, -0.04975932,  0.01778257,  0.03647015, -0.01329863,
#         0.04988133,  0.02322228,  0.01294292,  0.05310114, -0.01022696,
#        -0.03754207,  0.09749623, -0.01761727,  0.00490749,  0.00723024], dtype=float32)
