# %%
import pymongo
client = pymongo.MongoClient()
mydb = client['y2buy_1']
product_ids = mydb.reviews.distinct("productId")
print(product_ids)
my_collection = mydb['feature_sentiment']
result = mydb.feature_sentiment.create_index([('productId', pymongo.ASCENDING)],unique=True)
# Out:
# [32611785137, 32662806201, 32721716490, 32763320059, 32766086429, 32769974242, 32790980431, 32792320034, 32796300206]

# %%
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()
def clean(doc):
    #stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    #punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    tokens = word_tokenize(doc.lower())
    normalized = " ".join(lemma.lemmatize(token) for token in tokens if token not in stop and token not in exclude
                         )
    return normalized

# %%
def traverse(t,noun,phrases):
    try:
        t.label()
    except AttributeError:
        n=0
    else:
        if t.label() == 'NOUN_PHRASE': 
            phrase = " ".join([word for (word,pos) in t.leaves()])
            if noun in phrase.split():
                phrases.append(phrase)
                #print(phrase)
        for child in t:
            traverse(child,noun,phrases)
    return phrases

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import numpy

sid =  SentimentIntensityAnalyzer()
doc_complete = []
sentiments = {}
# iterate all products
for product_id in product_ids:
    print()
    print("Product: "+str(product_id))
    sentiments.clear()
    sentiments["productId"] = str(product_id)
    sentiments["features"] = {}
    # iterate reviews for product
    for review in mydb.reviews.find({ "productId" : product_id}):
        print(".", end ="")
        if "buyerTranslationFeedback" in review.keys():
            # clean review_text
            clean_review_text = clean(review["buyerTranslationFeedback"])
            # do POS tagging
            tokens = nltk.word_tokenize(clean_review_text)
            tagged = nltk.pos_tag(tokens)
            # do noun phrase tagging
            grammar = r"""
                          NOUN_PHRASE:  {<CD|IN|DT|JJ|PP|RB|\$>*<N.*>+<V.*>*<CD|IN|DT|JJ|PP|RB|\$>*<N.*>*}  
                        """
            cp = nltk.RegexpParser(grammar)
            noun_phrase_tagged = cp.parse(tagged)
            #print(noun_phrase_tagged)
            
            for feature in mydb.review_features.distinct("feature"):
                #print(feature, end = "")
                if feature not in sentiments["features"].keys():
                    sentiments["features"][feature] = { "average_sentiment": 0, "review_snippets": []  }
                feature_array = sentiments["features"][feature] 
                for feature_record in mydb.review_features.find({"feature" : feature}):
                    for noun in feature_record["terms"]:
                        #print(noun)
                        phrases=[]
                        phrases=traverse(noun_phrase_tagged,noun,phrases)
                        #print(phrases)
                        if len(phrases)!=0:
                            #print(noun)
                            [feature_array["review_snippets"].append({"sentiment": sid.polarity_scores(phrase)["compound"],  "reviewId": review["_id"],"snippet": phrase,}) for phrase in phrases]
    # after iterating over all reviews for product
    #average sentiments of feature
    for feature in sentiments["features"]:
        feature_array = sentiments["features"][feature]
        #print(feature_array)
        if len(feature_array["review_snippets"])!=0:
            sentiments["features"][feature]["average_sentiment"]= numpy.mean([snippet["sentiment"] for snippet in feature_array["review_snippets"]])
        else:
            sentiments["features"][feature]["average_sentiment"] = 0
    print(sentiments)
    mydb.feature_sentiment.insert_one(sentiments)
# Out:
# Product: 32611785137
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................{'productId': '32611785137', 'features': {'adapter': {'average_sentiment': 0.26040731707317072, 'review_snippets': [{'sentiment': 0.3089, 'snippet': 'adapter without problem foto spread', 'reviewId': ObjectId('596a7888d60bcd0f3b109fc0')}, {'sentiment': 0.0, 'snippet': 'adapter outlet chose silicone case piece glass', 'reviewId': ObjectId('596a7888d60bcd0f3b109fc3')}, {'sentiment': 0.4215, 'snippet': 'nice way asked eu adapter outlet', 'reviewId': ObjectId('596a7888d60bcd0f3b109fc6')}, {'sentiment': 0.4404, 'snippet': 'gift high quality adapter phone', 'reviewId': ObjectId('596a7888d60bcd0f3b109fc6')}, {'sentiment': 0.4404, 'snippet': 'adapter russian outlet set firmware gift', 'reviewId': ObjectId('596a7889d60bcd0f3b109fe0')}, {'sentiment': 0.4404, 'snippet': 'euro adapter russian federation shnye outlet film gift', 'reviewId': ObjectId('596a7889d60bcd0f3b109fe1')}, {'sentiment': 0.0, 'snippet': 'adapter outlet russian federation', 'reviewId': ObjectId('596a7889d60bcd0f3b109fe5')}, {'sentiment': 0.0, 'snippet': 'undamaged packing accordance description european adapter', 'reviewId': ObjectId('596a7889d60bcd0f3b109fe7')}, {'sentiment': 0.0, 'snippet': 'undamaged package described european adapter', 'reviewId': ObjectId('596a7889d60bcd0f3b109fe7')}, {'sentiment': 0.0, 'snippet': 'right plug adapter phone ota firmware box box way film phone included verification everything', 'reviewId': ObjectId('596a7889d60bcd0f3b109fee')}, {'sentiment': 0.0, 'snippet': 'adapter 8.1.2 version instead 8.2 air', 'reviewId': ObjectId('596a7889d60bcd0f3b109fef')}, {'sentiment': 0.0, 'snippet': 'sim card protective film yusb cord adapter power outlet box glue smell', 'reviewId': ObjectId('596a7889d60bcd0f3b109ff2')}, {'sentiment': 0.4404, 'snippet': 'чекалась gift wrap put adapter phone', 'reviewId': ObjectId('596a788ad60bcd0f3b109ff7')}, {'sentiment': 0.0, 'snippet': 'russian language addition seller added adapter protective film предусматривалась package', 'reviewId': ObjectId('596a788ad60bcd0f3b10a008')}, {'sentiment': 0.7906, 'snippet': 'great phone money gift seller put film adapter earthing-pin', 'reviewId': ObjectId('596a788ad60bcd0f3b10a016')}, {'sentiment': 0.0, 'snippet': 'glass silicone case adapter everything work camera 10 point', 'reviewId': ObjectId('596a788ad60bcd0f3b10a018')}, {'sentiment': 0.6486, 'snippet': 'complete film adapter commodity satisfied recommend', 'reviewId': ObjectId('596a788ad60bcd0f3b10a019')}, {'sentiment': 0.0, 'snippet': 'battery american outlet put adapter rule', 'reviewId': ObjectId('596a788bd60bcd0f3b10a021')}, {'sentiment': 0.7906, 'snippet': 'phone adapter socket euro film display film thanks seller great phone antutu', 'reviewId': ObjectId('596a788bd60bcd0f3b10a049')}, {'sentiment': 0.0, 'snippet': 'adapter film', 'reviewId': ObjectId('596a788cd60bcd0f3b10a068')}, {'sentiment': 0.7783, 'snippet': '11 day moscow everything super gift adapter sticker glass', 'reviewId': ObjectId('596a788cd60bcd0f3b10a071')}, {'sentiment': 0.0, 'snippet': 'protective film screen adapter charger use phone ...
#
# Product: 32662806201
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................{'productId': '32662806201', 'features': {'adapter': {'average_sentiment': -0.1779, 'review_snippets': [{'sentiment': -0.1779, 'snippet': 'like photo scratch damage box charging cable adapter socket', 'reviewId': ObjectId('596a78c7d60bcd0f3b10a936')}]}, 'battery': {'average_sentiment': 0.076989430894308944, 'review_snippets': [{'sentiment': 0.4404, 'snippet': 'белебей 10 day quality good battery', 'reviewId': ObjectId('596a78bbd60bcd0f3b10a73c')}, {'sentiment': -0.3182, 'snippet': '4000 mah seller advise phone also battery critical remove кэшбэком gap link', 'reviewId': ObjectId('596a78bbd60bcd0f3b10a73c')}, {'sentiment': 0.0, 'snippet': '8 hour basis selection capacious battery', 'reviewId': ObjectId('596a78bbd60bcd0f3b10a73e')}, {'sentiment': 0.0, 'snippet': 'count phone-wifi eating half battery', 'reviewId': ObjectId('596a78bbd60bcd0f3b10a73e')}, {'sentiment': 0.0, 'snippet': 'full charge regular charger', 'reviewId': ObjectId('596a78bbd60bcd0f3b10a73e')}, {'sentiment': 0.0, 'snippet': 'full charge regular charger', 'reviewId': ObjectId('596a78bbd60bcd0f3b10a73e')}, {'sentiment': 0.0, 'snippet': 'every day although charge', 'reviewId': ObjectId('596a78bbd60bcd0f3b10a740')}, {'sentiment': 0.0, 'snippet': '3 phone need charge every day', 'reviewId': ObjectId('596a78bbd60bcd0f3b10a740')}, {'sentiment': -0.2263, 'snippet': '5000 smart battery hold day inside normal android shit', 'reviewId': ObjectId('596a78bbd60bcd0f3b10a74a')}, {'sentiment': 0.0, 'snippet': 'бюджетников battery le reality three half', 'reviewId': ObjectId('596a78bbd60bcd0f3b10a74b')}, {'sentiment': 0.2023, 'snippet': 'fine androyd fly charge last 2 day', 'reviewId': ObjectId('596a78bbd60bcd0f3b10a74e')}, {'sentiment': 0.0, 'snippet': 'without headset battery really big heavy capacity measure charge', 'reviewId': ObjectId('596a78bcd60bcd0f3b10a765')}, {'sentiment': 0.0, 'snippet': 'without headset battery really big heavy capacity measure charge', 'reviewId': ObjectId('596a78bcd60bcd0f3b10a765')}, {'sentiment': 0.3182, 'snippet': 'sticker battery looked original', 'reviewId': ObjectId('596a78bcd60bcd0f3b10a76c')}, {'sentiment': -0.34, 'snippet': 'unfortunately tester battery', 'reviewId': ObjectId('596a78bcd60bcd0f3b10a76c')}, {'sentiment': 0.0, 'snippet': 'logical thinking battery 15 le', 'reviewId': ObjectId('596a78bcd60bcd0f3b10a76c')}, {'sentiment': 0.0, 'snippet': 'battery налейтесь overheating habit hang', 'reviewId': ObjectId('596a78bcd60bcd0f3b10a76c')}, {'sentiment': 0.6486, 'snippet': 'well hand light slippery battery', 'reviewId': ObjectId('596a78bcd60bcd0f3b10a770')}, {'sentiment': 0.3818, 'snippet': 'phone work shustrenko scanner clear pull toy battery', 'reviewId': ObjectId('596a78bdd60bcd0f3b10a77e')}, {'sentiment': -0.5574, 'snippet': 'average several time hanged remove battery sin', 'reviewId': ObjectId('596a78bdd60bcd0f3b10a77e')}, {'sentiment': 0.0, 'snippet': 'long time charge phone fall almost complete zero second short circuit camera', 'reviewId': ObjectId('596a78bdd60bcd0f3b10a77e')}, {'sentiment': 0.4019, 'snippet': 'definitely capacious battery real capacity nothing let', 'reviewId': ObjectId ...
#
# Product: 32721716490
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................{'productId': '32721716490', 'features': {'adapter': {'average_sentiment': 0.16489859154929579, 'review_snippets': [{'sentiment': 0.0, 'snippet': 'background european plug adapter included', 'reviewId': ObjectId('596a786cd60bcd0f3b109b0c')}, {'sentiment': 0.0, 'snippet': 'near power adapter', 'reviewId': ObjectId('596a786dd60bcd0f3b109b20')}, {'sentiment': 0.5719, 'snippet': 'adapter russian outlet packaging opened global 8.1.6.0 stable firmware thank', 'reviewId': ObjectId('596a786dd60bcd0f3b109b33')}, {'sentiment': 0.4404, 'snippet': 'third phone seller irkutsk ordering 15 day adapter gift plenochka screen', 'reviewId': ObjectId('596a786ed60bcd0f3b109b54')}, {'sentiment': 0.0, 'snippet': 'inflatable set phone adapter film', 'reviewId': ObjectId('596a786ed60bcd0f3b109b5e')}, {'sentiment': 0.0, 'snippet': 'cable charging adapter 220 fact', 'reviewId': ObjectId('596a786ed60bcd0f3b109b64')}, {'sentiment': 0.5719, 'snippet': '12 day work fine gift film adapter socket', 'reviewId': ObjectId('596a786ed60bcd0f3b109b66')}, {'sentiment': 0.6124, 'snippet': 'gift film well thrown adapter case', 'reviewId': ObjectId('596a786ed60bcd0f3b109b6d')}, {'sentiment': 0.0, 'snippet': 'simple additional adapter euro complete phone parcel film screen', 'reviewId': ObjectId('596a786ed60bcd0f3b109b70')}, {'sentiment': 0.3612, 'snippet': 'adapter film recommend seller', 'reviewId': ObjectId('596a786fd60bcd0f3b109b83')}, {'sentiment': 0.0, 'snippet': 'screen network adapter adapter cord key sim box packed thick section dutuyu film', 'reviewId': ObjectId('596a7870d60bcd0f3b109bb0')}, {'sentiment': 0.0, 'snippet': 'adapter put present protective film', 'reviewId': ObjectId('596a7870d60bcd0f3b109bbb')}, {'sentiment': 0.0, 'snippet': 'sim card film silicone bumper charger cord length little meter adapter', 'reviewId': ObjectId('596a7870d60bcd0f3b109bc4')}, {'sentiment': 0.0, 'snippet': 'complete adapter charge last time', 'reviewId': ObjectId('596a7870d60bcd0f3b109bce')}, {'sentiment': 0.0, 'snippet': 'euro adapter charging film everything work', 'reviewId': ObjectId('596a7870d60bcd0f3b109bcf')}, {'sentiment': 0.0, 'snippet': 'adapter russian outlet protective film', 'reviewId': ObjectId('596a7871d60bcd0f3b109bf8')}, {'sentiment': 0.4019, 'snippet': 'adapter earthing-pin film screen ordered cover silicone support', 'reviewId': ObjectId('596a7873d60bcd0f3b109c4e')}, {'sentiment': 0.0, 'snippet': 'phone came parcel adapter wali', 'reviewId': ObjectId('596a7874d60bcd0f3b109c63')}, {'sentiment': 0.0, 'snippet': 'cheap cost blue one send adapter', 'reviewId': ObjectId('596a7875d60bcd0f3b109c90')}, {'sentiment': 0.5574, 'snippet': 'adapter outlet box positive end', 'reviewId': ObjectId('596a7875d60bcd0f3b109c9d')}, {'sentiment': 0.0, 'snippet': 'euro adapter even though ask box', 'rev ...
#
# Product: 32763320059
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................{'productId': '32763320059', 'features': {'adapter': {'average_sentiment': 0.22276846846846848, 'review_snippets': [{'sentiment': 0.0, 'snippet': 'parcel adapter charging shipping milking yaroslavl 10 day order seller', 'reviewId': ObjectId('596a77cfd60bcd0f3b10820c')}, {'sentiment': 0.6908, 'snippet': 'adapter film glass useful safety glass', 'reviewId': ObjectId('596a77cfd60bcd0f3b108211')}, {'sentiment': 0.5106, 'snippet': 'texture pleasant 3 adapter plug', 'reviewId': ObjectId('596a77cfd60bcd0f3b108217')}, {'sentiment': 0.0, 'snippet': 'adapter work accurately настрлйкам update need', 'reviewId': ObjectId('596a77cfd60bcd0f3b108218')}, {'sentiment': 0.6249, 'snippet': 'adapter film great phone', 'reviewId': ObjectId('596a77cfd60bcd0f3b10821d')}, {'sentiment': -0.5423, 'snippet': 'visible dark complete bad film scratched day pocket le cover adapter', 'reviewId': ObjectId('596a77d0d60bcd0f3b10822c')}, {'sentiment': -0.5423, 'snippet': 'visible dark complete bad film scratched day pocket le cover adapter', 'reviewId': ObjectId('596a77d0d60bcd0f3b10822d')}, {'sentiment': 0.7845, 'snippet': 'adapter russia phone see распаковывался satisfied great seller', 'reviewId': ObjectId('596a77d0d60bcd0f3b108235')}, {'sentiment': 0.0, 'snippet': 'protective film seller put euro adapter', 'reviewId': ObjectId('596a77d0d60bcd0f3b108238')}, {'sentiment': 0.0, 'snippet': 'protective film seller supplied adapter euro', 'reviewId': ObjectId('596a77d0d60bcd0f3b108238')}, {'sentiment': 0.4404, 'snippet': 'present protective film adapter outlet quality adapter good phone', 'reviewId': ObjectId('596a77d0d60bcd0f3b108241')}, {'sentiment': -0.3182, 'snippet': 'loose 24 gb memory seller put adapter socket film glass', 'reviewId': ObjectId('596a77d1d60bcd0f3b10824b')}, {'sentiment': 0.0, 'snippet': 'ordered standard ...
#
# Product: 32766086429
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................{'productId': '32766086429', 'features': {'adapter': {'average_sentiment': 0.23648837209302326, 'review_snippets': [{'sentiment': 0.4404, 'snippet': 'promptly track russia included adapter gift', 'reviewId': ObjectId('596a782cd60bcd0f3b109135')}, {'sentiment': 0.0, 'snippet': 'also adapter plug 1 protective film yesterday received phone', 'reviewId': ObjectId('596a782cd60bcd0f3b109143')}, {'sentiment': 0.6124, 'snippet': 'well ordered standard package seller gift put charging adapter film screen zakazyvayu seller', 'reviewId': ObjectId('596a782cd60bcd0f3b109144')}, {'sentiment': 0.5719, 'snippet': 'intact seller put gift protective film adapter network', 'reviewId': ObjectId('596a782dd60bcd0f3b109148')}, {'sentiment': 0.7269, 'snippet': 'pretty good quality russian included charger adapter film', 'reviewId': ObjectId('596a782dd60bcd0f3b109153')}, {'sentiment': 0.2732, 'snippet': 'well packed case included zakvzyvala film adapter', 'reviewId': ObjectId('596a782dd60bcd0f3b109160')}, {'sentiment': 0.0, 'snippet': 'seller put adapter socket', 'reviewId': ObjectId('596a782dd60bcd0f3b10916e')}, {'sentiment': 0.2732, 'snippet': 'protective film transport-without pattern matte well adapter adapter charger', 'reviewId': ObjectId('596a782dd60bcd0f3b109172')}, {'sentiment': 0.4404, 'snippet': 'good russian complete protective film adapter russian outlet application', 'reviewId': ObjectId('596a782dd60bcd0f3b10917c')}, {'sentiment': 0.0, 'snippet': 'adapter came 16 day phone test write', 'reviewId': ObjectId('596a782ed60bcd0f3b109184')}, {'sentiment': 0.3612, 'snippet': 'silicone case protective film adapter socket prodavtsa recommend', 'reviewId': ObjectId('596a782ed60bcd0f3b10918d')}, {'sentiment': 0.2732, 'snippet': 'inside lay film adapter outlet packaged well', 'reviewId': ObjectId('596a782ed60bcd0f3b109198')}, {'sentiment': 0.0, 'snippet': 'phone seller put adapter socket film screen phone', 'reviewId': ObjectId('596a782fd60bcd0f3b1091b7')}, {'sentiment': 0.0, 'snippet': 'football box wrinkled inside right con charger adapter', 'reviewId': ObjectId('596a782fd60bcd0f3b1091ca')}, {'sentiment': 0.0, 'snippet': 'film glued second box adapter plug euro zaryadka rabotaet', 'reviewId': ObjectId('596a7830d60bcd0f3b1091ed')}, {'sentiment': 0.6597, 'snippet': 'good write everything phone came informed put adapter thank', 'reviewId': ObjectId('596a7833d60bcd0f3b109240')}, {'sentiment': 0.0, 'snippet': 'addition phone embedded adapter film phone state', 'reviewId': ObjectId('596a7833d60bcd0f3b109241')}, {'sentiment': 0.0, 'snippet': 'adapter earthing-pin film glass', 'reviewId': ObjectId('596 ...
#
# Product: 32769974242
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................{'productId': '32769974242', 'features': {'adapter': {'average_sentiment': 0.0, 'review_snippets': [{'sentiment': 0.0, 'snippet': 'гермично included headphone usd cable adapter', 'reviewId': ObjectId('596a789fd60bcd0f3b10a3b6')}, {'sentiment': 0.0, 'snippet': '10гб kit includes phone headphone adapter cable', 'reviewId': ObjectId('596a78a8d60bcd0f3b10a4ee')}]}, 'battery': {'average_sentiment': 0.098563541666666657, 'review_snippets': [{'sentiment': 0.0, 'snippet': 'first price second battery', 'reviewId': ObjectId('596a789ed60bcd0f3b10a369')}, {'sentiment': 0.2732, 'snippet': 'unit-three ruble market day well edge-two thousand photo grainy video battery average use', 'reviewId': ObjectId('596a789ed60bcd0f3b10a369')}, {'sentiment': 0.0, 'snippet': 'charge holding phone mother', 'reviewId': ObjectId('596a789ed60bcd0f3b10a36d')}, {'sentiment': 0.0, 'snippet': 'another battery gregarious salesman', 'reviewId': ObjectId('596a789ed60bcd0f3b10a376')}, {'sentiment': 0.7003, 'snippet': 'though sometimes tupit well important zvuk phone good music speaking battery', 'reviewId': ObjectId('596a789ed60bcd0f3b10a379')}, {'sentiment': 0.2263, 'snippet': 'surprised charge indicator sat phone', 'reviewId': ObjectId('596a789ed60bcd0f3b10a379')}, {'sentiment': 0.0, 'snippet': 'charge zero emotion', 'reviewId': ObjectId('596a789ed60bcd0f3b10a379')}, {'sentiment': -0.3612, 'snippet': 'difficult understand charge money stuffing phone', 'reviewId': ObjectId('596a789ed60bcd0f3b10a379')}, {'sentiment': 0.2732, 'snippet': '3500 battery screen well principle normally', 'reviewId': ObjectId('596a789ed60bcd0f3b10a37e')}, {'sentiment': 0.0, 'snippet': '2 week battery hold normal use', 'reviewId': ObjectId('596a789ed60bcd0f3b10a382')}, {'sentiment': 0.0, 'snippet': '16 available 10 fingerprint quality screen big battery camera principle', 'reviewId': ObjectId('596a789ed60bcd0f3b10a385')}, {'sentiment': -0.2023, 'snippet': 'third day battery charged 50 enough sit', 'reviewId': ObjectId('596a789ed60bcd0f3b10a38b')}, {'sentiment': 0.0, 'snippet': 'battery last long time', 'reviewId': ObjectId('596a789fd60bcd0f3b10a393')}, {'sentiment': 0.2732, 'snippet': 'matter habit charge holding well-this main advantage', 'reviewId': ObjectId('596a789fd60bcd0f3b10a395')}, {'sentiment': 0.0, 'snippet': 'iphone every day charge listen music phone', 'reviewId': ObjectId('596a789fd60bcd0f3b10a396')}, {'sentiment': 0.2023, 'snippet': 'plenochku battery removed everything fine', 'reviewId': ObjectId('596a789fd60bcd0f3b10a397')}, {'sentiment': -0.2263, 'snippet': 'krasnodar 18 day everything fine except inadequate monitoring battery charge', 'reviewId': ObjectId('596a789fd60bcd0f3b10a398')}, {'sentiment': -0.2263, 'snippet': 'krasnodar 18 day everything fine except inadequate monitoring battery charge', 'reviewId': ObjectId('596a789fd60bcd0f3b10a398')}, {'sentiment': 0.0, 'snippet': 'already 22 thing full charge show', 'reviewId': ObjectId('596a789fd60bcd0f3b10a398')}, {'sentiment': 0.2023, 'snippet': 'fine stock found  ...
#
# Product: 32790980431
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................{'productId': '32790980431', 'features': {'adapter': {'average_sentiment': 0.18581818181818183, 'review_snippets': [{'sentiment': -0.5267, 'snippet': 'charger wire adapter lying separately outside box', 'reviewId': ObjectId('596a7853d60bcd0f3b10969e')}, {'sentiment': 0.3612, 'snippet': 'additional adapter eu socket film glass actually like film', 'reviewId': ObjectId('596a7853d60bcd0f3b10969f')}, {'sentiment': 0.3182, 'snippet': 'original xiaomi put protective film adapter', 'reviewId': ObjectId('596a7853d60bcd0f3b1096a4')}, {'sentiment': 0.0, 'snippet': 'adapter earthing-pin bulletproof ordered cover little podglyuchivaet-sometimes hang screen turn', 'reviewId': ObjectId('596a7853d60bcd0f3b1096ac')}, {'sentiment': 0.0, 'snippet': 'film adapter socket', 'reviewId': ObjectId('596a7853d60bcd0f3b1096bc')}, {'sentiment': 0.0, 'snippet': 'complete charger adapter usb-шнур headphone phone work', 'reviewId': ObjectId('596a7854d60bcd0f3b1096c2')}, {'sentiment': -0.5106, 'snippet': 'headphone bad good packaging track track adapter charging 3,5 point seller greed', 'reviewId': ObjectId('596a7854d60bcd0f3b1096c3')}, {'sentiment': -0.5106, 'snippet': 'headphone bad good packaging track track adapter charging 3,5 point seller greed', 'reviewId': ObjectId('596a7854d60bcd0f3b1096c4')}, {'sentiment': -0.5106, 'snippet': 'headphone bad good packaging track track adapter charging 3,5 point seller greed', 'reviewId': ObjectId('596a7854d60bcd0f3b1096c5')}, {'sentiment': 0.0, 'snippet': 'track seller put film adapter', 'reviewId': ObjectId('596a7854d60bcd0f3b1096c7')}, {'sentiment': 0.0, 'snippet': 'adapter outlet charging 0 \\\\ 100 fast tested authenticity', 'reviewId': ObjectId('596a7854d60bcd0f3b1096cd')}, {'sentiment': 0.0, 'snippet': 'adapter euro plug silicone case protective film phone', 'reviewId': ObjectId('596a7854d60bcd0f3b1096d5')}, {'sentiment': 0.0, 'snippet': 'adapter euro plug protective film phone', 'reviewId': ObjectId('596a7854d60bcd0f3b1096da')}, {'sentiment': 0.5719, 'snippet': 'complete protective film glass case adapter outlet happy time', 'reviewId': ObjectId('596a7854d60bcd0f3b1096dc')}, {'sentiment': 0.0, 'snippet': 'already 8th хамами different seller general always chinese version ccc adapter box', 'reviewId': ObjectId('596a7855d60bcd0f3b109701')}, {'sentiment': 0.4215, 'snippet': 'little thing adapter seller liked', 'reviewId': ObjectId('596a7855d60bcd0f3b109701')}, {'sentiment': 0.3612, 'snippet': 'plyonochku adapter outlet recommend seller', 'reviewId': ObjectId('596a7855d60bcd0f3b10970d')}, {'sentiment': 0.0, 'snippet': 'air mattress included adapter socket euro date manufacture phone', 'reviewId': ObjectId('596a7855d60bcd0f3b10971a')}, {'sentiment': 0.6124, 'snippet': 'protective film adapter outlet adapter simkarty 10 gorgeous machine battery', 'reviewId': ObjectId('596a7856d60bcd0f3b109728')},  ...
#
# Product: 32792320034
# ..............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................Warning: parsing empty text
# ......{'productId': '32792320034', 'features': {'adapter': {'average_sentiment': 0.23616153846153848, 'review_snippets': [{'sentiment': 0.0, 'snippet': 'level complete film phone adapter', 'reviewId': ObjectId('596a7803d60bcd0f3b108a8f')}, {'sentiment': 0.3612, 'snippet': 'additional glass screen adapter euro socket say thank delivery kaluga region', 'reviewId': ObjectId('596a7803d60bcd0f3b108a93')}, {'sentiment': 0.7003, 'snippet': '4 happy socket came adapter well film', 'reviewId': ObjectId('596a7803d60bcd0f3b108a96')}, {'sentiment': 0.3612, 'snippet': 'additional protective film adapter charger recommend seller', 'reviewId': ObjectId('596a7803d60bcd0f3b108a9d')}, {'sentiment': -0.25, 'snippet': 'cord charging/usb adapter film screen wanted put 5 star downside', 'reviewId': ObjectId('596a7803d60bcd0f3b108a9e')}, {'sentiment': 0.0, 'snippet': 'seller put eu adapter', 'reviewId': ObjectId('596a7803d60bcd0f3b108aa1')}, {'sentiment': 0.0, 'snippet': 'parcel addition adapter charging seller', 'reviewId': ObjectId('596a7803d60bcd0f3b108ab0')}, {'sentiment': 0.0, 'snippet': 'extra film euro adapter socket', 'reviewId': ObjectId('596a7804d60bcd0f3b108ac6')}, {'sentiment': 0.7506, 'snippet': 'good silicone case glass well certainly adapter glass glue', 'reviewId': ObjectId('596a7804d60bcd0f3b108acc')}, {'sentiment': 0.0, 'snippet': 'second purchase seller packaging invested adapter outlet film screen', 'reviewId': ObjectId('596a7805d60bcd0f3b108ae9')}, {'sentiment': 0.0, 'snippet': '100. seller put euro outlet adapter film', 'reviewId': ObjectId('596a7805d60bcd0f3b108af1')}, {'sentiment': 0.0, 'snippet': 'barnaul 12 day corresponds description present film screen adapter earthing-pin', 'reviewId': ObjectId('596a7805d60bcd0f3b108af2')}, {'sentiment': 0.0, 'snippet': 'throughout entire journey outlet adapter put film addition rekomenduyu seller product', 'reviewId': ObjectId('596a7805d60bcd0f3b108afb')}, {'sentiment': 0.0, 'snippet': 'throughout entire journey outlet adapter put film addition rekomenduyu seller product', 'reviewId': ObjectId('596a7805d60bcd0f3b108afc')}, {'sentiment': 0.0, 'snippet': '20 day payment seller put protective film adapter trifle', 'reviewId': ObjectId('596a7806d60bcd0f3b108b28')}, {'sentiment': 0.0, 'snippet': 'complete adapter euro wire charging headphone jack need typo work', 'reviewId': ObjectId('596a7807d60bcd0f3b108b38')}, {'sentiment': 0.0, 'snippet': 'complete adapter euro wire charging headphone jack need typo work', 'reviewId': ObjectId('596a7807d60bcd0f3b108b39')}, {'sentiment': 0.4404, 'snippet': 'level film adapter gift choose 4 pro model husband', 'reviewId': ObjectId('596a7807d60bcd0f3b108b3e')}, {'sentiment': 0.0, 'snippet': 'plastic box present film screen adapter socket', 'reviewId': ObjectId('596a7807d60bcd0f3b108b43')}, {'sentiment': 0.8807, 'snippet': 'well special thanks seller bonus silicone bumper film adapter outlet custom', 'reviewId': ObjectId('596a7807d60bcd0f3b108b4d')}, {'sentiment': 0.0, 'snippet': 'uk adapter -send protection screen quality', 'reviewId': ObjectId('596a7807d60bcd0f3b108b50')}, {'sentiment': 0.5719, 'snippet': 'european adapter phone-all like come global stable firmware', 'reviewId': ObjectId('596a7808d60bcd0f3b108b60')}, {'sentiment': 0.2732, 'snippet': 'well present protective film adapter socket passed custom', 'reviewId': ObjectId('596a7808d60bcd0f3b108b68')}, {'sentiment': 0.0, 'snippet': 'adapter euro outlet global firmware', 'reviewId': ObjectId('596a780ad60bcd0f3b108baf')}, {'sentiment': 0.4404, 'snippet': 'film gift bumper adapter', 'reviewId': ObjectId('596a780ad60bcd0f3b108bb3')}, {'sentiment': 0.6124, 'snippet': 'gorgeous money prodavets put adapter', 'reviewId': ObjectId('596a780ad60bcd0f3b108bbf')}, {'sentiment': 0.4404, 'snippet': 'body russian language gift film adapter plug', 'reviewId': ObjectId('596a780ad60bcd0f3b108bc8')}, {'sentiment': 0.0, 'snippet': '100 ruble adapter nanosim 2 slot-inet разгонялся', 'reviewId': ObjectId('596a780ad60bcd0f ...
# Product: 32796300206
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................{'productId': '32796300206', 'features': {'adapter': {'average_sentiment': 0.29216249999999999, 'review_snippets': [{'sentiment': 0.7783, 'snippet': 'value 18 description android phone film adapter socket gift thank box', 'reviewId': ObjectId('596a77a5d60bcd0f3b107c21')}, {'sentiment': 0.0, 'snippet': 'package air included adapter russian', 'reviewId': ObjectId('596a77a5d60bcd0f3b107c29')}, {'sentiment': 0.0, 'snippet': 'package air included adapter russian', 'reviewId': ObjectId('596a77a5d60bcd0f3b107c2a')}, {'sentiment': 0.4404, 'snippet': 'gift silicone case film adapter charging came', 'reviewId': ObjectId('596a77a5d60bcd0f3b107c2e')}, {'sentiment': 0.0, 'snippet': 'put adapter outlet ordinary film screen box', 'reviewId': ObjectId('596a77a5d60bcd0f3b107c32')}, {'sentiment': 0.0, 'snippet': 'manually tool phone seller sent adapter socket', 'reviewId': ObjectId('596a77a5d60bcd0f3b107c3b')}, {'sentiment': 0.4404, 'snippet': 'budget smartphone metal case came quickly gift film adapter plug', 'reviewId': ObjectId('596a77a6d60bcd0f3b107c46')}, {'sentiment': 0.4404, 'snippet': 'gift plenochku adapter russian standard phone', 'reviewId': ObjectId('596a77a6d60bcd0f3b107c48')}, {'sentiment': 0.4404, 'snippet': 'first time useful adapter', 'reviewId': ObjectId('596a77a6d60bcd0f3b107c49')}, {'sentiment': 0.4404, 'snippet': 'gift bag adapter outlet film screen color quite gold', 'reviewId': ObjectId('596a77a6d60bcd0f3b107c4e')}, {'sentiment': 0.4939, 'snippet': 'adapter evrorazetku took care phone', 'reviewId': ObjectId('596a77a6d60bcd0f3b107c54')}, {'sentiment': 0.0, 'snippet': 'complete euro adapter russian outlet film screen headphone', 'reviewId': ObjectId('596a77a7d60bcd0f3b107c5b')}, {'sentiment': 0.4404, 'snippet': 'adapter outlet gift put film phone', 'reviewId': ObjectId('596a77a7d60bcd0f3b107c60')}, {'sentiment': 0.4404, 'snippet': 'standard phone charger adapter film screen gift order sent delivered quickly', 'reviewId': ObjectId('596a77a7d60bcd0f3b107c6b')}, {'sentiment': 0.0, 'snippet': 'silicone case seller gave soviet outlet adapter charger', 'reviewId': ObjectId('596a77a7d60bcd0f3b107c6c')}, {'sentiment': 0.7351, 'snippet': 'fine gift wrap put adapter seller communicate recommend', 'reviewId': ObjectId('596a77a7d60bcd0f3b107c6d')}, {'sentiment': 0.0, 'snippet': 'adapter plug euro protective film screen gregarious salesman', 'reviewId': ObjectId('596a77a7d60bcd0f3b107c6e')}, {'sentiment': 0.0, 'snippet': '10.07 ярославскию area p ...
